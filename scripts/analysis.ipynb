# %%
import json
import pandas as pd
import numpy as np

def load_events(path):
    with open(path) as f:
        data = json.load(f)
    return data["traceEvents"]

def flatten_event(e, source):
    """展开 args，仅保留 name, ts, args.xxx，并增加 from 字段"""

    out = {
        "name": e.get("name"),
        "ts": e.get("ts"),
        "from": source, 
    }

    args = e.get("args", {})
    if isinstance(args, dict):
        for k, v in args.items():
            out[f"args.{k}"] = v

    return out

def preprocess_events(events):
    tmp = pd.DataFrame(events)
    args_uint64 = tmp.dtypes[tmp.dtypes == "float64"]
    print(args_uint64.index.tolist())
    for e in events:
        for arg in args_uint64.index.tolist():
            if arg not in e:
                e[arg] = 0

path_sender = "expr/trace_sender.json"
path_receiver = "expr/trace_receiver.json"

# 读取原始数据
events_sender = load_events(path_sender)
events_receiver = load_events(path_receiver)

# 展开 + 加 from 字段
flat_sender = [flatten_event(e, "sender") for e in events_sender]
flat_receiver = [flatten_event(e, "receiver") for e in events_receiver]

# 合并两个列表
all_events = flat_sender + flat_receiver

preprocess_events(all_events)

df = pd.DataFrame(all_events)

df.dtypes
df["name"].unique().tolist()
# Out:
# ['args.last_target_bps', 'args.last_stable_target_bps', 'args.last_fraction_loss_', 'args.last_rtt_ms', 'args.value', 'args.update_target_bitrate_bps', 'args.encoder_target_rate_bps', 'args.protection_bitrate_bps', 'args.encoder_overhead_rate_bps', 'args.post_encode_overhead_bps', 'args.rtp_ts_capture', 'args.rtp_ts', 'args.capture_time_ms', 'args.frame_size', 'args.packet_count', 'args.seq', 'args.transport_seq', 'args.is_received', 'args.last_rtp_ts', 'args.num_media_packets', 'args.num_fec_packets', 'args.param_fec_rate', 'args.fec_payload_type', 'args.fec_ssrc', 'args.protected_frame_rtp_ts', 'args.rtt_ms', 'args.total_delta', 'args.lost_delta', 'args.payload_type', 'args.is_recovered', 'args.picture_id', 'args.render_time_ms', 'args.fec_seq', 'args.scheduled_decode_time_ms']
# ['BitrateAllocator:OnChanged',
#  'rtt_ms',
#  'loss',
#  'bwe_bps',
#  'Sender:AllocateBitrate',
#  'Frame:Captured',
#  'Frame:Start Encode',
#  'Frame:Encoded',
#  'Frame:Packetization',
#  'Frame:Dropped',
#  'Packet:Sent',
#  'RTCP:TransportPacketFeedback',
#  'Frame:Generate FEC',
#  'FlexFEC:GetFecPackets',
#  'RTCP:RTT',
#  'RTCP:ReportBlocksTransportLossReport',
#  'Packet:Received RTP',
#  'FlexFEC:Receive RTP Packet',
#  'Frame:Received EncodedFrame',
#  'Frame:ToFrameBuffer',
#  'Frame:ReadytoDecode',
#  'Frame:Start Decode',
#  'FEC:Receive FEC Packet',
#  'Frame:Decoded',
#  'Frame:Scheduled for Decode']

# %%
all_frame_rtp_ts_capture = df[df["name"] == "Frame:Captured"]["args.rtp_ts_capture"].unique()
all_frame_rtp_ts_capture.sort()

for rtp_ts_capture in all_frame_rtp_ts_capture:
    print("")
    print("Frame rtp_ts_capture =", rtp_ts_capture)
    event_frame_captured = df[(df["name"] == "Frame:Captured") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    event_frame_start_encode = df[(df["name"] == "Frame:Start Encode") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    
    if event_frame_start_encode.empty:
        event_frame_dropped = df[(df["name"] == "Frame:Dropped") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        reason = event_frame_dropped["args.reason"].values[0] 
        print(f"    dropped before encoding, reason={reason}!")
        continue
    else:
        event_frame_encoded = df[(df["name"] == "Frame:Encoded") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        
        if event_frame_encoded.empty:
            print(f"    dropped by encoder!")
            continue
        
        ts_captured = event_frame_captured["ts"].values[0]
        ts_encoded = event_frame_encoded["ts"].values[0]
        rtp_ts = event_frame_encoded["args.rtp_ts"].values[0]
        frame_type = event_frame_encoded["args.frame_type"].values[0]
        frame_size = event_frame_encoded["args.frame_size"].values[0]
        event_frame_packetization = df[(df["name"] == "Frame:Packetization") & (df["args.rtp_ts"] == rtp_ts)]
        packet_count = event_frame_packetization["args.packet_count"].values[0]
        event_frame_generate_fec = df[(df["name"] == "Frame:Generate FEC") & (df["args.last_rtp_ts"] == rtp_ts)]
        num_media_packets = event_frame_generate_fec["args.num_media_packets"].values[0] if not event_frame_generate_fec.empty else 0 
        num_fec_packets = event_frame_generate_fec["args.num_fec_packets"].values[0] if not event_frame_generate_fec.empty else 0
        
        events_packet_sent = df[(df["name"] == "Packet:Sent") & ((df["args.rtp_ts"] == rtp_ts) | (df["args.protected_frame_rtp_ts"] == rtp_ts))] 
        events_packet_sent = events_packet_sent.sort_values(by="ts")
         
        last_packet_sent_ts = events_packet_sent["ts"].values[-1] if not events_packet_sent.empty else None
        
        encoding_delay = ts_encoded - ts_captured
        pacing_delay = last_packet_sent_ts - ts_encoded if last_packet_sent_ts is not None else 0
        sender_side_delay = last_packet_sent_ts - ts_captured if last_packet_sent_ts is not None else None
        
        print(f"rtp_ts={rtp_ts}, frame_type={frame_type}, frame_size={frame_size} bytes, packet_count={packet_count}")
        
        
        for _, packet_event in events_packet_sent.iterrows():
            seq = packet_event["args.seq"]
            packet_type = packet_event["args.packet_type"]
            transport_seq = packet_event["args.transport_seq"]
            print(f"    Packet seq_num={seq}, packet_type={packet_type}, transport_seq={transport_seq}, delay_since_capture={(packet_event['ts'] - ts_captured)/1000} ms")
        
        if last_packet_sent_ts is None:
            print(f"    During sending!")
            continue 
        
        print(f"num_media_packets={num_media_packets}, num_fec_packets={num_fec_packets}")
        print(f"sender_side_delay={sender_side_delay/1000} ms, encoding_delay = {encoding_delay/1000} ms, pacing delay = {pacing_delay/1000} ms")
# Out:
# Frame rtp_ts_capture = 3669601574
# rtp_ts=1477715563, frame_type=key, frame_size=52321 bytes, packet_count=48, num_media_packets=48, num_fec_packets=1
# sender_side_delay=361.062 ms, encoding_delay = 70.996 ms, pacing delay = 290.066 ms
#     Packet seq_num=23666, packet_type=video, transport_seq=2, delay_since_capture=74.025 ms
#     Packet seq_num=23667, packet_type=video, transport_seq=3, delay_since_capture=85.738 ms
#     Packet seq_num=23668, packet_type=video, transport_seq=4, delay_since_capture=95.345 ms
#     Packet seq_num=23669, packet_type=video, transport_seq=5, delay_since_capture=105.672 ms
#     Packet seq_num=23670, packet_type=video, transport_seq=7, delay_since_capture=116.262 ms
#     Packet seq_num=23671, packet_type=video, transport_seq=8, delay_since_capture=122.665 ms
#     Packet seq_num=23672, packet_type=video, transport_seq=9, delay_since_capture=128.06 ms
#     Packet seq_num=23673, packet_type=video, transport_seq=10, delay_since_capture=133.495 ms
#     Packet seq_num=23674, packet_type=video, transport_seq=11, delay_since_capture=137.853 ms
#     Packet seq_num=23675, packet_type=video, transport_seq=12, delay_since_capture=177.287 ms
#     Packet seq_num=23676, packet_type=video, transport_seq=13, delay_since_capture=177.338 ms
#     Packet seq_num=23677, packet_type=video, transport_seq=14, delay_since_capture=182.628 ms
#     Packet seq_num=23678, packet_type=video, transport_seq=15, delay_since_capture=187.85 ms
#     Packet seq_num=23679, packet_type=video, transport_seq=16, delay_since_capture=192.128 ms
#     Packet seq_num=23680, packet_type=video, transport_seq=17, delay_since_capture=197.833 ms
#     Packet seq_num=23681, packet_type=video, transport_seq=18, delay_since_capture=203.302 ms
#     Packet seq_num=23682, packet_type=video, transport_seq=19, delay_since_capture=208.837 ms
#     Packet seq_num=23683, packet_type=video, transport_seq=20, delay_since_capture=214.302 ms
#     Packet seq_num=23684, packet_type=video, transport_seq=21, delay_since_capture=214.357 ms
#     Packet seq_num=23685, packet_type=video, transport_seq=22, delay_since_capture=219.799 ms
#     Packet seq_num=23686, packet_type=video, transport_seq=23, delay_since_capture=225.323 ms
#     Packet seq_num=23687, packet_type=video, transport_seq=24, delay_since_capture=230.032 ms
#     Packet seq_num=23688, packet_type=video, transport_seq=25, delay_since_capture=234.29 ms
#     Packet seq_num=23689, packet_type=video, transport_seq=26, delay_since_capture=240.677 ms
#     Packet seq_num=23690, packet_type=video, transport_seq=27, delay_since_capture=242.725 ms
#     Packet seq_num=23691, packet_type=video, transport_seq=28, delay_since_capture=251.134 ms
#     Packet seq_num=23692, packet_type=video, transport_seq=29, delay_since_capture=256.374 ms
#     Packet seq_num=23693, packet_type=video, transport_seq=30, delay_since_capture=256.421 ms
#     Packet seq_num=23694, packet_type=video, transport_seq=31, delay_since_capture=265.828 ms
#     Packet seq_num=23695, packet_type=video, transport_seq=32, delay_since_capture=265.874 ms
#     Packet seq_num=23696, packet_type=video, transport_seq=33, delay_since_capture=271.244 ms
#     Packet seq_num=23697, packet_type=video, transport_seq=34, delay_since_capture=276.776 ms
#     Packet seq_num=23698, packet_type=video, transport_seq=35, delay_since_capture=282.121 ms
#     Packet seq_num=23699, packet_type=video, transport_seq=36, delay_since_capture=284.652 ms
#     Packet seq_num=23700, packet_type=video, transport_seq=37, delay_since_capture=291.86 ms
#     Packet seq_num=23701, packet_type=video, transport_seq=38, delay_since_capture=296.991 ms
#     Packet seq_num=23702, packet_type=video, transport_seq=39, delay_since_capture=302.203 ms
#     Packet seq_num=23703, packet_type=video, transport_seq=40, delay_since_capture=307.583 ms
#     Packet seq_num=23704, packet_type=video, transport_seq=41, delay_since_capture=307.642 ms
#     Packet seq_num=23705, packet_type=video, transport_seq=42, delay_since_capture=313.286 ms
#     Packet seq_num=23706, packet_type=video, transport_seq=43, delay_since_capture=318.76 ms
#     Packet seq_num=23707, packet_type=video, transport_seq=44, delay_since_capture=323.514 ms
#     Packet seq_num=23708, packet_type=video, transport_seq=45, delay_since_capture=328.944 ms
#     Packet seq_num=23709, packet_type=video, transport_seq=46, delay_since_capture=334.279 ms
#     Packet seq_num=23710, packet_type=video, transport_seq=47, delay_since_capture=339.723 ms
#     Packet seq_num=23711, packet_type=video, transport_seq=48, delay_since_capture=342.021 ms
#     Packet seq_num=23712, packet_type=video, transport_seq=49, delay_since_capture=345.536 ms
#     Packet seq_num=23713, packet_type=video, transport_seq=50, delay_since_capture=350.21 ms
#     Packet seq_num=32107, packet_type=fec, transport_seq=52, delay_since_capture=361.062 ms
#
# Frame rtp_ts_capture = 3669604544
#     dropped before encoding, reason=encoder_blocked!
#
# Frame rtp_ts_capture = 3669607604
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669610574
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669613544
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669616604
# rtp_ts=1477730593, frame_type=delta, frame_size=30775 bytes, packet_count=28, num_media_packets=28, num_fec_packets=1
# sender_side_delay=327.716 ms, encoding_delay = 16.43 ms, pacing delay = 311.286 ms
#     Packet seq_num=23714, packet_type=video, transport_seq=51, delay_since_capture=188.907 ms
#     Packet seq_num=23715, packet_type=video, transport_seq=53, delay_since_capture=199.589 ms
#     Packet seq_num=23716, packet_type=video, transport_seq=54, delay_since_capture=205.012 ms
#     Packet seq_num=23717, packet_type=video, transport_seq=55, delay_since_capture=210.524 ms
#     Packet seq_num=23718, packet_type=video, transport_seq=56, delay_since_capture=210.574 ms
#     Packet seq_num=23719, packet_type=video, transport_seq=57, delay_since_capture=215.607 ms
#     Packet seq_num=23720, packet_type=video, transport_seq=58, delay_since_capture=220.921 ms
#     Packet seq_num=23721, packet_type=video, transport_seq=59, delay_since_capture=226.093 ms
#     Packet seq_num=23722, packet_type=video, transport_seq=60, delay_since_capture=230.988 ms
#     Packet seq_num=23723, packet_type=video, transport_seq=61, delay_since_capture=236.319 ms
#     Packet seq_num=23724, packet_type=video, transport_seq=62, delay_since_capture=241.565 ms
#     Packet seq_num=23725, packet_type=video, transport_seq=63, delay_since_capture=245.846 ms
#     Packet seq_num=23726, packet_type=video, transport_seq=64, delay_since_capture=251.129 ms
#     Packet seq_num=23727, packet_type=video, transport_seq=65, delay_since_capture=256.505 ms
#     Packet seq_num=23728, packet_type=video, transport_seq=66, delay_since_capture=261.997 ms
#     Packet seq_num=23729, packet_type=video, transport_seq=67, delay_since_capture=262.049 ms
#     Packet seq_num=23730, packet_type=video, transport_seq=68, delay_since_capture=266.515 ms
#     Packet seq_num=23731, packet_type=video, transport_seq=69, delay_since_capture=273.158 ms
#     Packet seq_num=23732, packet_type=video, transport_seq=70, delay_since_capture=277.073 ms
#     Packet seq_num=23733, packet_type=video, transport_seq=71, delay_since_capture=283.891 ms
#     Packet seq_num=23734, packet_type=video, transport_seq=72, delay_since_capture=289.307 ms
#     Packet seq_num=23735, packet_type=video, transport_seq=73, delay_since_capture=289.358 ms
#     Packet seq_num=23736, packet_type=video, transport_seq=74, delay_since_capture=295.025 ms
#     Packet seq_num=23737, packet_type=video, transport_seq=75, delay_since_capture=300.573 ms
#     Packet seq_num=23738, packet_type=video, transport_seq=76, delay_since_capture=306.078 ms
#     Packet seq_num=23739, packet_type=video, transport_seq=77, delay_since_capture=310.275 ms
#     Packet seq_num=23740, packet_type=video, transport_seq=78, delay_since_capture=316.592 ms
#     Packet seq_num=23741, packet_type=video, transport_seq=79, delay_since_capture=322.123 ms
#     Packet seq_num=32108, packet_type=fec, transport_seq=81, delay_since_capture=327.716 ms
#
# Frame rtp_ts_capture = 3669619574
# rtp_ts=1477733563, frame_type=delta, frame_size=31262 bytes, packet_count=29, num_media_packets=29, num_fec_packets=1
# sender_side_delay=430.44 ms, encoding_delay = 27.656 ms, pacing delay = 402.784 ms
#     Packet seq_num=23742, packet_type=video, transport_seq=80, delay_since_capture=288.979 ms
#     Packet seq_num=23743, packet_type=video, transport_seq=82, delay_since_capture=299.771 ms
#     Packet seq_num=23744, packet_type=video, transport_seq=83, delay_since_capture=305.206 ms
#     Packet seq_num=23745, packet_type=video, transport_seq=84, delay_since_capture=308.626 ms
#     Packet seq_num=23746, packet_type=video, transport_seq=85, delay_since_capture=315.563 ms
#     Packet seq_num=23747, packet_type=video, transport_seq=86, delay_since_capture=320.098 ms
#     Packet seq_num=23748, packet_type=video, transport_seq=87, delay_since_capture=325.627 ms
#     Packet seq_num=23749, packet_type=video, transport_seq=88, delay_since_capture=325.68 ms
#     Packet seq_num=23750, packet_type=video, transport_seq=89, delay_since_capture=331.149 ms
#     Packet seq_num=23751, packet_type=video, transport_seq=90, delay_since_capture=334.623 ms
#     Packet seq_num=23752, packet_type=video, transport_seq=91, delay_since_capture=341.296 ms
#     Packet seq_num=23753, packet_type=video, transport_seq=92, delay_since_capture=346.123 ms
#     Packet seq_num=23754, packet_type=video, transport_seq=93, delay_since_capture=351.074 ms
#     Packet seq_num=23755, packet_type=video, transport_seq=94, delay_since_capture=356.613 ms
#     Packet seq_num=23756, packet_type=video, transport_seq=95, delay_since_capture=356.679 ms
#     Packet seq_num=23757, packet_type=video, transport_seq=96, delay_since_capture=362.274 ms
#     Packet seq_num=23758, packet_type=video, transport_seq=97, delay_since_capture=367.781 ms
#     Packet seq_num=23759, packet_type=video, transport_seq=98, delay_since_capture=373.232 ms
#     Packet seq_num=23760, packet_type=video, transport_seq=99, delay_since_capture=378.572 ms
#     Packet seq_num=23761, packet_type=video, transport_seq=100, delay_since_capture=379.008 ms
#     Packet seq_num=23762, packet_type=video, transport_seq=101, delay_since_capture=383.444 ms
#     Packet seq_num=23763, packet_type=video, transport_seq=102, delay_since_capture=388.886 ms
#     Packet seq_num=23764, packet_type=video, transport_seq=103, delay_since_capture=394.184 ms
#     Packet seq_num=23765, packet_type=video, transport_seq=104, delay_since_capture=397.478 ms
#     Packet seq_num=23766, packet_type=video, transport_seq=105, delay_since_capture=405.213 ms
#     Packet seq_num=23767, packet_type=video, transport_seq=106, delay_since_capture=408.669 ms
#     Packet seq_num=23768, packet_type=video, transport_seq=107, delay_since_capture=410.347 ms
#     Packet seq_num=23769, packet_type=video, transport_seq=108, delay_since_capture=414.865 ms
#     Packet seq_num=23770, packet_type=video, transport_seq=109, delay_since_capture=420.452 ms
#     Packet seq_num=32109, packet_type=fec, transport_seq=111, delay_since_capture=430.44 ms
#
# Frame rtp_ts_capture = 3669622544
# rtp_ts=1477736533, frame_type=delta, frame_size=22363 bytes, packet_count=21, num_media_packets=21, num_fec_packets=1
# sender_side_delay=497.136 ms, encoding_delay = 22.903 ms, pacing delay = 474.233 ms
#     Packet seq_num=23771, packet_type=video, transport_seq=110, delay_since_capture=391.587 ms
#     Packet seq_num=23772, packet_type=video, transport_seq=112, delay_since_capture=400.408 ms
#     Packet seq_num=23773, packet_type=video, transport_seq=113, delay_since_capture=406.874 ms
#     Packet seq_num=23774, packet_type=video, transport_seq=114, delay_since_capture=410.931 ms
#     Packet seq_num=23775, packet_type=video, transport_seq=115, delay_since_capture=414.382 ms
#     Packet seq_num=23776, packet_type=video, transport_seq=116, delay_since_capture=417.916 ms
#     Packet seq_num=23777, packet_type=video, transport_seq=117, delay_since_capture=422.461 ms
#     Packet seq_num=23778, packet_type=video, transport_seq=118, delay_since_capture=426.025 ms
#     Packet seq_num=23779, packet_type=video, transport_seq=119, delay_since_capture=432.448 ms
#     Packet seq_num=23780, packet_type=video, transport_seq=120, delay_since_capture=437.928 ms
#     Packet seq_num=23781, packet_type=video, transport_seq=121, delay_since_capture=442.588 ms
#     Packet seq_num=23782, packet_type=video, transport_seq=122, delay_since_capture=448.162 ms
#     Packet seq_num=23783, packet_type=video, transport_seq=123, delay_since_capture=448.219 ms
#     Packet seq_num=23784, packet_type=video, transport_seq=124, delay_since_capture=453.765 ms
#     Packet seq_num=23785, packet_type=video, transport_seq=125, delay_since_capture=459.232 ms
#     Packet seq_num=23786, packet_type=video, transport_seq=126, delay_since_capture=464.609 ms
#     Packet seq_num=23787, packet_type=video, transport_seq=127, delay_since_capture=470.203 ms
#     Packet seq_num=23788, packet_type=video, transport_seq=128, delay_since_capture=470.268 ms
#     Packet seq_num=23789, packet_type=video, transport_seq=129, delay_since_capture=475.573 ms
#     Packet seq_num=23790, packet_type=video, transport_seq=130, delay_since_capture=480.991 ms
#     Packet seq_num=23791, packet_type=video, transport_seq=131, delay_since_capture=486.484 ms
#     Packet seq_num=32110, packet_type=fec, transport_seq=133, delay_since_capture=497.136 ms
#
# Frame rtp_ts_capture = 3669625604
# rtp_ts=1477739593, frame_type=delta, frame_size=14748 bytes, packet_count=14, num_media_packets=14, num_fec_packets=1
# sender_side_delay=526.927 ms, encoding_delay = 19.762 ms, pacing delay = 507.165 ms
#     Packet seq_num=23792, packet_type=video, transport_seq=132, delay_since_capture=458.592 ms
#     Packet seq_num=23793, packet_type=video, transport_seq=134, delay_since_capture=463.861 ms
#     Packet seq_num=23794, packet_type=video, transport_seq=135, delay_since_capture=469.249 ms
#     Packet seq_num=23795, packet_type=video, transport_seq=136, delay_since_capture=474.667 ms
#     Packet seq_num=23796, packet_type=video, transport_seq=137, delay_since_capture=476.662 ms
#     Packet seq_num=23797, packet_type=video, transport_seq=138, delay_since_capture=481.849 ms
#     Packet seq_num=23798, packet_type=video, transport_seq=139, delay_since_capture=485.201 ms
#     Packet seq_num=23799, packet_type=video, transport_seq=140, delay_since_capture=490.454 ms
#     Packet seq_num=23800, packet_type=video, transport_seq=141, delay_since_capture=495.818 ms
#     Packet seq_num=23801, packet_type=video, transport_seq=142, delay_since_capture=500.118 ms
#     Packet seq_num=23802, packet_type=video, transport_seq=143, delay_since_capture=505.397 ms
#     Packet seq_num=23803, packet_type=video, transport_seq=144, delay_since_capture=510.887 ms
#     Packet seq_num=23804, packet_type=video, transport_seq=145, delay_since_capture=511.666 ms
#     Packet seq_num=23805, packet_type=video, transport_seq=146, delay_since_capture=516.199 ms
#     Packet seq_num=32111, packet_type=fec, transport_seq=148, delay_since_capture=526.927 ms
#
# Frame rtp_ts_capture = 3669628574
# rtp_ts=1477742563, frame_type=delta, frame_size=10013 bytes, packet_count=10, num_media_packets=10, num_fec_packets=1
# sender_side_delay=540.279 ms, encoding_delay = 23.289 ms, pacing delay = 516.99 ms
#     Packet seq_num=23806, packet_type=video, transport_seq=147, delay_since_capture=488.177 ms
#     Packet seq_num=23807, packet_type=video, transport_seq=149, delay_since_capture=498.826 ms
#     Packet seq_num=23808, packet_type=video, transport_seq=150, delay_since_capture=504.16 ms
#     Packet seq_num=23809, packet_type=video, transport_seq=151, delay_since_capture=504.187 ms
#     Packet seq_num=23810, packet_type=video, transport_seq=152, delay_since_capture=509.486 ms
#     Packet seq_num=23811, packet_type=video, transport_seq=153, delay_since_capture=513.781 ms
#     Packet seq_num=23812, packet_type=video, transport_seq=154, delay_since_capture=519.192 ms
#     Packet seq_num=23813, packet_type=video, transport_seq=155, delay_since_capture=524.635 ms
#     Packet seq_num=23814, packet_type=video, transport_seq=156, delay_since_capture=524.692 ms
#     Packet seq_num=23815, packet_type=video, transport_seq=157, delay_since_capture=529.971 ms
#     Packet seq_num=32112, packet_type=fec, transport_seq=159, delay_since_capture=540.279 ms
#
# Frame rtp_ts_capture = 3669631544
# rtp_ts=1477745533, frame_type=delta, frame_size=4436 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=526.52 ms, encoding_delay = 10.806 ms, pacing delay = 515.714 ms
#     Packet seq_num=23816, packet_type=video, transport_seq=158, delay_since_capture=500.268 ms
#     Packet seq_num=23817, packet_type=video, transport_seq=160, delay_since_capture=507.018 ms
#     Packet seq_num=23818, packet_type=video, transport_seq=161, delay_since_capture=512.442 ms
#     Packet seq_num=23819, packet_type=video, transport_seq=162, delay_since_capture=516.263 ms
#     Packet seq_num=23820, packet_type=video, transport_seq=163, delay_since_capture=523.077 ms
#     Packet seq_num=32113, packet_type=fec, transport_seq=165, delay_since_capture=526.52 ms
#
# Frame rtp_ts_capture = 3669634604
# rtp_ts=1477748593, frame_type=delta, frame_size=4097 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=514.696 ms, encoding_delay = 11.504 ms, pacing delay = 503.192 ms
#     Packet seq_num=23821, packet_type=video, transport_seq=164, delay_since_capture=489.815 ms
#     Packet seq_num=23822, packet_type=video, transport_seq=166, delay_since_capture=499.796 ms
#     Packet seq_num=23823, packet_type=video, transport_seq=167, delay_since_capture=504.227 ms
#     Packet seq_num=23824, packet_type=video, transport_seq=168, delay_since_capture=509.687 ms
#     Packet seq_num=32114, packet_type=fec, transport_seq=170, delay_since_capture=514.696 ms
#
# Frame rtp_ts_capture = 3669637574
# rtp_ts=1477751563, frame_type=delta, frame_size=5130 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=508.315 ms, encoding_delay = 12.448 ms, pacing delay = 495.867 ms
#     Packet seq_num=23825, packet_type=video, transport_seq=169, delay_since_capture=476.445 ms
#     Packet seq_num=23826, packet_type=video, transport_seq=171, delay_since_capture=484.805 ms
#     Packet seq_num=23827, packet_type=video, transport_seq=172, delay_since_capture=491.307 ms
#     Packet seq_num=23828, packet_type=video, transport_seq=173, delay_since_capture=496.727 ms
#     Packet seq_num=23829, packet_type=video, transport_seq=174, delay_since_capture=496.826 ms
#     Packet seq_num=32115, packet_type=fec, transport_seq=176, delay_since_capture=508.315 ms
#
# Frame rtp_ts_capture = 3669640544
# rtp_ts=1477754533, frame_type=delta, frame_size=4808 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=500.112 ms, encoding_delay = 10.33 ms, pacing delay = 489.782 ms
#     Packet seq_num=23830, packet_type=video, transport_seq=175, delay_since_capture=469.522 ms
#     Packet seq_num=23831, packet_type=video, transport_seq=177, delay_since_capture=476.709 ms
#     Packet seq_num=23832, packet_type=video, transport_seq=178, delay_since_capture=479.605 ms
#     Packet seq_num=23833, packet_type=video, transport_seq=179, delay_since_capture=484.938 ms
#     Packet seq_num=23834, packet_type=video, transport_seq=180, delay_since_capture=490.132 ms
#     Packet seq_num=32116, packet_type=fec, transport_seq=182, delay_since_capture=500.112 ms
#
# Frame rtp_ts_capture = 3669643604
# rtp_ts=1477757593, frame_type=delta, frame_size=4181 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=483.907 ms, encoding_delay = 10.126 ms, pacing delay = 473.781 ms
#     Packet seq_num=23835, packet_type=video, transport_seq=181, delay_since_capture=461.14 ms
#     Packet seq_num=23836, packet_type=video, transport_seq=183, delay_since_capture=466.71 ms
#     Packet seq_num=23837, packet_type=video, transport_seq=184, delay_since_capture=471.17 ms
#     Packet seq_num=23838, packet_type=video, transport_seq=185, delay_since_capture=476.814 ms
#     Packet seq_num=32117, packet_type=fec, transport_seq=187, delay_since_capture=483.907 ms
#
# Frame rtp_ts_capture = 3669646574
# rtp_ts=1477760563, frame_type=delta, frame_size=8634 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=491.834 ms, encoding_delay = 9.093 ms, pacing delay = 482.741 ms
#     Packet seq_num=23839, packet_type=video, transport_seq=186, delay_since_capture=449.522 ms
#     Packet seq_num=23840, packet_type=video, transport_seq=188, delay_since_capture=459.621 ms
#     Packet seq_num=23841, packet_type=video, transport_seq=189, delay_since_capture=459.672 ms
#     Packet seq_num=23842, packet_type=video, transport_seq=190, delay_since_capture=465.094 ms
#     Packet seq_num=23843, packet_type=video, transport_seq=191, delay_since_capture=470.678 ms
#     Packet seq_num=23844, packet_type=video, transport_seq=192, delay_since_capture=476.382 ms
#     Packet seq_num=23845, packet_type=video, transport_seq=193, delay_since_capture=476.435 ms
#     Packet seq_num=23846, packet_type=video, transport_seq=194, delay_since_capture=480.944 ms
#     Packet seq_num=32118, packet_type=fec, transport_seq=196, delay_since_capture=491.834 ms
#
# Frame rtp_ts_capture = 3669649544
# rtp_ts=1477763533, frame_type=delta, frame_size=8179 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=495.344 ms, encoding_delay = 12.651 ms, pacing delay = 482.693 ms
#     Packet seq_num=23847, packet_type=video, transport_seq=195, delay_since_capture=453.049 ms
#     Packet seq_num=23848, packet_type=video, transport_seq=197, delay_since_capture=463.857 ms
#     Packet seq_num=23849, packet_type=video, transport_seq=198, delay_since_capture=468.416 ms
#     Packet seq_num=23850, packet_type=video, transport_seq=199, delay_since_capture=468.57 ms
#     Packet seq_num=23851, packet_type=video, transport_seq=200, delay_since_capture=474.217 ms
#     Packet seq_num=23852, packet_type=video, transport_seq=201, delay_since_capture=478.79 ms
#     Packet seq_num=23853, packet_type=video, transport_seq=202, delay_since_capture=484.478 ms
#     Packet seq_num=23854, packet_type=video, transport_seq=203, delay_since_capture=489.926 ms
#     Packet seq_num=32119, packet_type=fec, transport_seq=205, delay_since_capture=495.344 ms
#
# Frame rtp_ts_capture = 3669652604
# rtp_ts=1477766593, frame_type=delta, frame_size=7744 bytes, packet_count=7, num_media_packets=7, num_fec_packets=1
# sender_side_delay=500.122 ms, encoding_delay = 12.013 ms, pacing delay = 488.109 ms
#     Packet seq_num=23855, packet_type=video, transport_seq=204, delay_since_capture=456.589 ms
#     Packet seq_num=23856, packet_type=video, transport_seq=206, delay_since_capture=467.277 ms
#     Packet seq_num=23857, packet_type=video, transport_seq=207, delay_since_capture=472.707 ms
#     Packet seq_num=23858, packet_type=video, transport_seq=208, delay_since_capture=477.171 ms
#     Packet seq_num=23859, packet_type=video, transport_seq=209, delay_since_capture=480.514 ms
#     Packet seq_num=23860, packet_type=video, transport_seq=210, delay_since_capture=482.935 ms
#     Packet seq_num=23861, packet_type=video, transport_seq=211, delay_since_capture=489.085 ms
#     Packet seq_num=32120, packet_type=fec, transport_seq=213, delay_since_capture=500.122 ms
#
# Frame rtp_ts_capture = 3669655574
# rtp_ts=1477769563, frame_type=delta, frame_size=5004 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=487.477 ms, encoding_delay = 8.933 ms, pacing delay = 478.544 ms
#     Packet seq_num=23862, packet_type=video, transport_seq=212, delay_since_capture=458.211 ms
#     Packet seq_num=23863, packet_type=video, transport_seq=214, delay_since_capture=466.941 ms
#     Packet seq_num=23864, packet_type=video, transport_seq=215, delay_since_capture=472.351 ms
#     Packet seq_num=23865, packet_type=video, transport_seq=216, delay_since_capture=476.885 ms
#     Packet seq_num=23866, packet_type=video, transport_seq=217, delay_since_capture=482.478 ms
#     Packet seq_num=32121, packet_type=fec, transport_seq=219, delay_since_capture=487.477 ms
#
# Frame rtp_ts_capture = 3669658544
# rtp_ts=1477772533, frame_type=delta, frame_size=2552 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=469.3 ms, encoding_delay = 10.663 ms, pacing delay = 458.637 ms
#     Packet seq_num=23867, packet_type=video, transport_seq=218, delay_since_capture=449.51 ms
#     Packet seq_num=23868, packet_type=video, transport_seq=220, delay_since_capture=458.118 ms
#     Packet seq_num=23869, packet_type=video, transport_seq=221, delay_since_capture=463.582 ms
#     Packet seq_num=32122, packet_type=fec, transport_seq=223, delay_since_capture=469.3 ms
#
# Frame rtp_ts_capture = 3669661514
# rtp_ts=1477775503, frame_type=delta, frame_size=2771 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=451.794 ms, encoding_delay = 9.297 ms, pacing delay = 442.497 ms
#     Packet seq_num=23870, packet_type=video, transport_seq=222, delay_since_capture=435.891 ms
#     Packet seq_num=23871, packet_type=video, transport_seq=224, delay_since_capture=441.798 ms
#     Packet seq_num=23872, packet_type=video, transport_seq=225, delay_since_capture=441.891 ms
#     Packet seq_num=32123, packet_type=fec, transport_seq=227, delay_since_capture=451.794 ms
#
# Frame rtp_ts_capture = 3669664574
# rtp_ts=1477778563, frame_type=delta, frame_size=3311 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=433.996 ms, encoding_delay = 8.872 ms, pacing delay = 425.124 ms
#     Packet seq_num=23873, packet_type=video, transport_seq=226, delay_since_capture=413.912 ms
#     Packet seq_num=23874, packet_type=video, transport_seq=228, delay_since_capture=424.023 ms
#     Packet seq_num=23875, packet_type=video, transport_seq=229, delay_since_capture=429.548 ms
#     Packet seq_num=32124, packet_type=fec, transport_seq=231, delay_since_capture=433.996 ms
#
# Frame rtp_ts_capture = 3669667544
# rtp_ts=1477781533, frame_type=delta, frame_size=6061 bytes, packet_count=6, num_media_packets=6, num_fec_packets=1
# sender_side_delay=428.44 ms, encoding_delay = 9.934 ms, pacing delay = 418.506 ms
#     Packet seq_num=23876, packet_type=video, transport_seq=230, delay_since_capture=396.377 ms
#     Packet seq_num=23877, packet_type=video, transport_seq=232, delay_since_capture=407.422 ms
#     Packet seq_num=23878, packet_type=video, transport_seq=233, delay_since_capture=412.705 ms
#     Packet seq_num=23879, packet_type=video, transport_seq=234, delay_since_capture=412.771 ms
#     Packet seq_num=23880, packet_type=video, transport_seq=235, delay_since_capture=418.308 ms
#     Packet seq_num=23881, packet_type=video, transport_seq=236, delay_since_capture=422.559 ms
#     Packet seq_num=32125, packet_type=fec, transport_seq=238, delay_since_capture=428.44 ms
#
# Frame rtp_ts_capture = 3669670604
# rtp_ts=1477784593, frame_type=delta, frame_size=4987 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=421.116 ms, encoding_delay = 11.414 ms, pacing delay = 409.702 ms
#     Packet seq_num=23882, packet_type=video, transport_seq=237, delay_since_capture=392.485 ms
#     Packet seq_num=23883, packet_type=video, transport_seq=239, delay_since_capture=400.448 ms
#     Packet seq_num=23884, packet_type=video, transport_seq=240, delay_since_capture=405.963 ms
#     Packet seq_num=23885, packet_type=video, transport_seq=241, delay_since_capture=411.513 ms
#     Packet seq_num=23886, packet_type=video, transport_seq=242, delay_since_capture=411.6 ms
#     Packet seq_num=32126, packet_type=fec, transport_seq=244, delay_since_capture=421.116 ms
#
# Frame rtp_ts_capture = 3669673574
# rtp_ts=1477787563, frame_type=delta, frame_size=5608 bytes, packet_count=6, num_media_packets=6, num_fec_packets=1
# sender_side_delay=414.396 ms, encoding_delay = 13.922 ms, pacing delay = 400.474 ms
#     Packet seq_num=23887, packet_type=video, transport_seq=243, delay_since_capture=383.373 ms
#     Packet seq_num=23888, packet_type=video, transport_seq=245, delay_since_capture=393.428 ms
#     Packet seq_num=23889, packet_type=video, transport_seq=246, delay_since_capture=393.482 ms
#     Packet seq_num=23890, packet_type=video, transport_seq=247, delay_since_capture=398.868 ms
#     Packet seq_num=23891, packet_type=video, transport_seq=248, delay_since_capture=403.527 ms
#     Packet seq_num=23892, packet_type=video, transport_seq=249, delay_since_capture=408.605 ms
#     Packet seq_num=32127, packet_type=fec, transport_seq=251, delay_since_capture=414.396 ms
#
# Frame rtp_ts_capture = 3669676544
# rtp_ts=1477790533, frame_type=delta, frame_size=13921 bytes, packet_count=13, num_media_packets=13, num_fec_packets=1
# sender_side_delay=438.259 ms, encoding_delay = 13.544 ms, pacing delay = 424.715 ms
#     Packet seq_num=23893, packet_type=video, transport_seq=250, delay_since_capture=375.23 ms
#     Packet seq_num=23894, packet_type=video, transport_seq=252, delay_since_capture=386.146 ms
#     Packet seq_num=23895, packet_type=video, transport_seq=253, delay_since_capture=391.354 ms
#     Packet seq_num=23896, packet_type=video, transport_seq=254, delay_since_capture=396.559 ms
#     Packet seq_num=23897, packet_type=video, transport_seq=255, delay_since_capture=396.609 ms
#     Packet seq_num=23898, packet_type=video, transport_seq=256, delay_since_capture=400.916 ms
#     Packet seq_num=23899, packet_type=video, transport_seq=257, delay_since_capture=407.311 ms
#     Packet seq_num=23900, packet_type=video, transport_seq=258, delay_since_capture=412.531 ms
#     Packet seq_num=23901, packet_type=video, transport_seq=259, delay_since_capture=412.643 ms
#     Packet seq_num=23902, packet_type=video, transport_seq=260, delay_since_capture=417.858 ms
#     Packet seq_num=23903, packet_type=video, transport_seq=261, delay_since_capture=422.449 ms
#     Packet seq_num=23904, packet_type=video, transport_seq=262, delay_since_capture=427.818 ms
#     Packet seq_num=23905, packet_type=video, transport_seq=263, delay_since_capture=433.016 ms
#     Packet seq_num=32128, packet_type=fec, transport_seq=265, delay_since_capture=438.259 ms
#
# Frame rtp_ts_capture = 3669679604
# rtp_ts=1477793593, frame_type=delta, frame_size=8119 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=441.158 ms, encoding_delay = 11.195 ms, pacing delay = 429.963 ms
#     Packet seq_num=23906, packet_type=video, transport_seq=264, delay_since_capture=404.926 ms
#     Packet seq_num=23907, packet_type=video, transport_seq=266, delay_since_capture=410.139 ms
#     Packet seq_num=23908, packet_type=video, transport_seq=267, delay_since_capture=415.276 ms
#     Packet seq_num=23909, packet_type=video, transport_seq=268, delay_since_capture=420.622 ms
#     Packet seq_num=23910, packet_type=video, transport_seq=269, delay_since_capture=425.796 ms
#     Packet seq_num=23911, packet_type=video, transport_seq=270, delay_since_capture=425.843 ms
#     Packet seq_num=23912, packet_type=video, transport_seq=271, delay_since_capture=430.086 ms
#     Packet seq_num=23913, packet_type=video, transport_seq=272, delay_since_capture=435.29 ms
#     Packet seq_num=32129, packet_type=fec, transport_seq=274, delay_since_capture=441.158 ms
#
# Frame rtp_ts_capture = 3669682574
# rtp_ts=1477796563, frame_type=delta, frame_size=6331 bytes, packet_count=6, num_media_packets=6, num_fec_packets=1
# sender_side_delay=436.882 ms, encoding_delay = 12.597 ms, pacing delay = 424.285 ms
#     Packet seq_num=23914, packet_type=video, transport_seq=273, delay_since_capture=404.447 ms
#     Packet seq_num=23915, packet_type=video, transport_seq=275, delay_since_capture=416.801 ms
#     Packet seq_num=23916, packet_type=video, transport_seq=276, delay_since_capture=416.854 ms
#     Packet seq_num=23917, packet_type=video, transport_seq=277, delay_since_capture=421.995 ms
#     Packet seq_num=23918, packet_type=video, transport_seq=278, delay_since_capture=427.173 ms
#     Packet seq_num=23919, packet_type=video, transport_seq=279, delay_since_capture=432.41 ms
#     Packet seq_num=32130, packet_type=fec, transport_seq=281, delay_since_capture=436.882 ms
#
# Frame rtp_ts_capture = 3669685544
# rtp_ts=1477799533, frame_type=delta, frame_size=4548 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=425.938 ms, encoding_delay = 11.617 ms, pacing delay = 414.321 ms
#     Packet seq_num=23920, packet_type=video, transport_seq=280, delay_since_capture=401.361 ms
#     Packet seq_num=23921, packet_type=video, transport_seq=282, delay_since_capture=408.779 ms
#     Packet seq_num=23922, packet_type=video, transport_seq=283, delay_since_capture=413.985 ms
#     Packet seq_num=23923, packet_type=video, transport_seq=284, delay_since_capture=419.201 ms
#     Packet seq_num=23924, packet_type=video, transport_seq=285, delay_since_capture=419.273 ms
#     Packet seq_num=32131, packet_type=fec, transport_seq=287, delay_since_capture=425.938 ms
#
# Frame rtp_ts_capture = 3669688604
# rtp_ts=1477802593, frame_type=delta, frame_size=2121 bytes, packet_count=2, num_media_packets=2, num_fec_packets=1
# sender_side_delay=406.537 ms, encoding_delay = 9.444 ms, pacing delay = 397.093 ms
#     Packet seq_num=23925, packet_type=video, transport_seq=286, delay_since_capture=388.273 ms
#     Packet seq_num=23926, packet_type=video, transport_seq=288, delay_since_capture=396.874 ms
#     Packet seq_num=32132, packet_type=fec, transport_seq=290, delay_since_capture=406.537 ms
#
# Frame rtp_ts_capture = 3669691574
# rtp_ts=1477805563, frame_type=delta, frame_size=3568 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=389.807 ms, encoding_delay = 13.282 ms, pacing delay = 376.525 ms
#     Packet seq_num=23927, packet_type=video, transport_seq=289, delay_since_capture=367.807 ms
#     Packet seq_num=23928, packet_type=video, transport_seq=291, delay_since_capture=378.538 ms
#     Packet seq_num=23929, packet_type=video, transport_seq=292, delay_since_capture=378.59 ms
#     Packet seq_num=23930, packet_type=video, transport_seq=293, delay_since_capture=381.858 ms
#     Packet seq_num=32133, packet_type=fec, transport_seq=295, delay_since_capture=389.807 ms
#
# Frame rtp_ts_capture = 3669694544
# rtp_ts=1477808533, frame_type=delta, frame_size=4002 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=378.25 ms, encoding_delay = 13.747 ms, pacing delay = 364.503 ms
#     Packet seq_num=23931, packet_type=video, transport_seq=294, delay_since_capture=356.519 ms
#     Packet seq_num=23932, packet_type=video, transport_seq=296, delay_since_capture=362.014 ms
#     Packet seq_num=23933, packet_type=video, transport_seq=297, delay_since_capture=366.557 ms
#     Packet seq_num=23934, packet_type=video, transport_seq=298, delay_since_capture=372.321 ms
#     Packet seq_num=32134, packet_type=fec, transport_seq=300, delay_since_capture=378.25 ms
#
# Frame rtp_ts_capture = 3669697604
# rtp_ts=1477811593, frame_type=delta, frame_size=15174 bytes, packet_count=14, num_media_packets=14, num_fec_packets=1
# sender_side_delay=409.555 ms, encoding_delay = 24.489 ms, pacing delay = 385.066 ms
#     Packet seq_num=23935, packet_type=video, transport_seq=299, delay_since_capture=338.99 ms
#     Packet seq_num=23936, packet_type=video, transport_seq=301, delay_since_capture=350.378 ms
#     Packet seq_num=23937, packet_type=video, transport_seq=302, delay_since_capture=355.895 ms
#     Packet seq_num=23938, packet_type=video, transport_seq=303, delay_since_capture=355.946 ms
#     Packet seq_num=23939, packet_type=video, transport_seq=304, delay_since_capture=361.379 ms
#     Packet seq_num=23940, packet_type=video, transport_seq=305, delay_since_capture=366.981 ms
#     Packet seq_num=23941, packet_type=video, transport_seq=306, delay_since_capture=372.44 ms
#     Packet seq_num=23942, packet_type=video, transport_seq=307, delay_since_capture=372.504 ms
#     Packet seq_num=23943, packet_type=video, transport_seq=308, delay_since_capture=377.175 ms
#     Packet seq_num=23944, packet_type=video, transport_seq=309, delay_since_capture=382.602 ms
#     Packet seq_num=23945, packet_type=video, transport_seq=310, delay_since_capture=388.064 ms
#     Packet seq_num=23946, packet_type=video, transport_seq=311, delay_since_capture=389.13 ms
#     Packet seq_num=23947, packet_type=video, transport_seq=312, delay_since_capture=393.955 ms
#     Packet seq_num=23948, packet_type=video, transport_seq=313, delay_since_capture=399.561 ms
#     Packet seq_num=32135, packet_type=fec, transport_seq=315, delay_since_capture=409.555 ms
#
# Frame rtp_ts_capture = 3669700574
# rtp_ts=1477814563, frame_type=delta, frame_size=4370 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=396.234 ms, encoding_delay = 18.225 ms, pacing delay = 378.009 ms
#     Packet seq_num=23949, packet_type=video, transport_seq=314, delay_since_capture=370.759 ms
#     Packet seq_num=23950, packet_type=video, transport_seq=316, delay_since_capture=376.909 ms
#     Packet seq_num=23951, packet_type=video, transport_seq=317, delay_since_capture=381.251 ms
#     Packet seq_num=23952, packet_type=video, transport_seq=318, delay_since_capture=385.707 ms
#     Packet seq_num=32136, packet_type=fec, transport_seq=320, delay_since_capture=396.234 ms
#
# Frame rtp_ts_capture = 3669703544
# rtp_ts=1477817533, frame_type=delta, frame_size=7468 bytes, packet_count=7, num_media_packets=7, num_fec_packets=1
# sender_side_delay=394.645 ms, encoding_delay = 15.851 ms, pacing delay = 378.794 ms
#     Packet seq_num=23953, packet_type=video, transport_seq=319, delay_since_capture=357.755 ms
#     Packet seq_num=23954, packet_type=video, transport_seq=321, delay_since_capture=368.225 ms
#     Packet seq_num=23955, packet_type=video, transport_seq=322, delay_since_capture=372.709 ms
#     Packet seq_num=23956, packet_type=video, transport_seq=323, delay_since_capture=372.763 ms
#     Packet seq_num=23957, packet_type=video, transport_seq=324, delay_since_capture=378.545 ms
#     Packet seq_num=23958, packet_type=video, transport_seq=325, delay_since_capture=383.82 ms
#     Packet seq_num=23959, packet_type=video, transport_seq=326, delay_since_capture=389.25 ms
#     Packet seq_num=32137, packet_type=fec, transport_seq=328, delay_since_capture=394.645 ms
#
# Frame rtp_ts_capture = 3669706604
# rtp_ts=1477820593, frame_type=delta, frame_size=18086 bytes, packet_count=17, num_media_packets=17, num_fec_packets=1
# sender_side_delay=434.564 ms, encoding_delay = 13.987 ms, pacing delay = 420.577 ms
#     Packet seq_num=23960, packet_type=video, transport_seq=327, delay_since_capture=355.842 ms
#     Packet seq_num=23961, packet_type=video, transport_seq=329, delay_since_capture=366.517 ms
#     Packet seq_num=23962, packet_type=video, transport_seq=330, delay_since_capture=371.752 ms
#     Packet seq_num=23963, packet_type=video, transport_seq=331, delay_since_capture=376.241 ms
#     Packet seq_num=23964, packet_type=video, transport_seq=332, delay_since_capture=376.49 ms
#     Packet seq_num=23965, packet_type=video, transport_seq=333, delay_since_capture=381.89 ms
#     Packet seq_num=23966, packet_type=video, transport_seq=334, delay_since_capture=387.249 ms
#     Packet seq_num=23967, packet_type=video, transport_seq=335, delay_since_capture=389.768 ms
#     Packet seq_num=23968, packet_type=video, transport_seq=336, delay_since_capture=397.635 ms
#     Packet seq_num=23969, packet_type=video, transport_seq=337, delay_since_capture=397.688 ms
#     Packet seq_num=23970, packet_type=video, transport_seq=338, delay_since_capture=402.155 ms
#     Packet seq_num=23971, packet_type=video, transport_seq=339, delay_since_capture=407.653 ms
#     Packet seq_num=23972, packet_type=video, transport_seq=340, delay_since_capture=409.291 ms
#     Packet seq_num=23973, packet_type=video, transport_seq=341, delay_since_capture=417.989 ms
#     Packet seq_num=23974, packet_type=video, transport_seq=342, delay_since_capture=418.041 ms
#     Packet seq_num=23975, packet_type=video, transport_seq=343, delay_since_capture=423.364 ms
#     Packet seq_num=23976, packet_type=video, transport_seq=344, delay_since_capture=428.882 ms
#     Packet seq_num=32138, packet_type=fec, transport_seq=346, delay_since_capture=434.564 ms
#
# Frame rtp_ts_capture = 3669709574
# rtp_ts=1477823563, frame_type=delta, frame_size=12923 bytes, packet_count=12, num_media_packets=12, num_fec_packets=1
# sender_side_delay=454.944 ms, encoding_delay = 12.039 ms, pacing delay = 442.905 ms
#     Packet seq_num=23977, packet_type=video, transport_seq=345, delay_since_capture=401.349 ms
#     Packet seq_num=23978, packet_type=video, transport_seq=347, delay_since_capture=406.794 ms
#     Packet seq_num=23979, packet_type=video, transport_seq=348, delay_since_capture=412.226 ms
#     Packet seq_num=23980, packet_type=video, transport_seq=349, delay_since_capture=417.71 ms
#     Packet seq_num=23981, packet_type=video, transport_seq=350, delay_since_capture=417.778 ms
#     Packet seq_num=23982, packet_type=video, transport_seq=351, delay_since_capture=423.183 ms
#     Packet seq_num=23983, packet_type=video, transport_seq=352, delay_since_capture=428.653 ms
#     Packet seq_num=23984, packet_type=video, transport_seq=353, delay_since_capture=434.063 ms
#     Packet seq_num=23985, packet_type=video, transport_seq=354, delay_since_capture=434.127 ms
#     Packet seq_num=23986, packet_type=video, transport_seq=355, delay_since_capture=439.402 ms
#     Packet seq_num=23987, packet_type=video, transport_seq=356, delay_since_capture=443.861 ms
#     Packet seq_num=23988, packet_type=video, transport_seq=357, delay_since_capture=449.443 ms
#     Packet seq_num=32139, packet_type=fec, transport_seq=359, delay_since_capture=454.944 ms
#
# Frame rtp_ts_capture = 3669712544
# rtp_ts=1477826533, frame_type=delta, frame_size=8227 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=457.387 ms, encoding_delay = 12.513 ms, pacing delay = 444.874 ms
#     Packet seq_num=23989, packet_type=video, transport_seq=358, delay_since_capture=421.425 ms
#     Packet seq_num=23990, packet_type=video, transport_seq=360, delay_since_capture=426.833 ms
#     Packet seq_num=23991, packet_type=video, transport_seq=361, delay_since_capture=431.556 ms
#     Packet seq_num=23992, packet_type=video, transport_seq=362, delay_since_capture=437.009 ms
#     Packet seq_num=23993, packet_type=video, transport_seq=363, delay_since_capture=437.075 ms
#     Packet seq_num=23994, packet_type=video, transport_seq=364, delay_since_capture=441.446 ms
#     Packet seq_num=23995, packet_type=video, transport_seq=365, delay_since_capture=446.934 ms
#     Packet seq_num=23996, packet_type=video, transport_seq=366, delay_since_capture=450.553 ms
#     Packet seq_num=32140, packet_type=fec, transport_seq=368, delay_since_capture=457.387 ms
#
# Frame rtp_ts_capture = 3669715514
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669718574
# rtp_ts=1477832563, frame_type=delta, frame_size=5457 bytes, packet_count=5, num_media_packets=5, num_fec_packets=1
# sender_side_delay=417.384 ms, encoding_delay = 11.532 ms, pacing delay = 405.852 ms
#     Packet seq_num=23997, packet_type=video, transport_seq=367, delay_since_capture=390.673 ms
#     Packet seq_num=23998, packet_type=video, transport_seq=369, delay_since_capture=396.225 ms
#     Packet seq_num=23999, packet_type=video, transport_seq=370, delay_since_capture=400.801 ms
#     Packet seq_num=24000, packet_type=video, transport_seq=371, delay_since_capture=406.407 ms
#     Packet seq_num=24001, packet_type=video, transport_seq=372, delay_since_capture=407.671 ms
#     Packet seq_num=32141, packet_type=fec, transport_seq=374, delay_since_capture=417.384 ms
#
# Frame rtp_ts_capture = 3669721544
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669724514
# rtp_ts=1477838503, frame_type=delta, frame_size=2502 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=366.133 ms, encoding_delay = 15.081 ms, pacing delay = 351.052 ms
#     Packet seq_num=24002, packet_type=video, transport_seq=373, delay_since_capture=345.117 ms
#     Packet seq_num=24003, packet_type=video, transport_seq=375, delay_since_capture=355.231 ms
#     Packet seq_num=24004, packet_type=video, transport_seq=376, delay_since_capture=355.33 ms
#     Packet seq_num=32142, packet_type=fec, transport_seq=378, delay_since_capture=366.133 ms
#
# Frame rtp_ts_capture = 3669727574
#     dropped by encoder!
#
# Frame rtp_ts_capture = 3669730544
# rtp_ts=1477844533, frame_type=delta, frame_size=2388 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=310.305 ms, encoding_delay = 10.365 ms, pacing delay = 299.94 ms
#     Packet seq_num=24005, packet_type=video, transport_seq=377, delay_since_capture=293.961 ms
#     Packet seq_num=24006, packet_type=video, transport_seq=379, delay_since_capture=299.45 ms
#     Packet seq_num=24007, packet_type=video, transport_seq=380, delay_since_capture=304.799 ms
#     Packet seq_num=32143, packet_type=fec, transport_seq=382, delay_since_capture=310.305 ms
#
# Frame rtp_ts_capture = 3669733514
# rtp_ts=1477847503, frame_type=delta, frame_size=2057 bytes, packet_count=2, num_media_packets=2, num_fec_packets=1
# sender_side_delay=288.848 ms, encoding_delay = 10.276 ms, pacing delay = 278.572 ms
#     Packet seq_num=24008, packet_type=video, transport_seq=381, delay_since_capture=271.755 ms
#     Packet seq_num=24009, packet_type=video, transport_seq=383, delay_since_capture=280.736 ms
#     Packet seq_num=32144, packet_type=fec, transport_seq=385, delay_since_capture=288.848 ms
#
# Frame rtp_ts_capture = 3669736574
# rtp_ts=1477850563, frame_type=delta, frame_size=1442 bytes, packet_count=2, num_media_packets=2, num_fec_packets=1
# sender_side_delay=265.293 ms, encoding_delay = 9.539 ms, pacing delay = 255.754 ms
#     Packet seq_num=24010, packet_type=video, transport_seq=384, delay_since_capture=249.745 ms
#     Packet seq_num=24011, packet_type=video, transport_seq=386, delay_since_capture=258.059 ms
#     Packet seq_num=32145, packet_type=fec, transport_seq=388, delay_since_capture=265.293 ms
#
# Frame rtp_ts_capture = 3669739544
# rtp_ts=1477853533, frame_type=delta, frame_size=2148 bytes, packet_count=2, num_media_packets=2, num_fec_packets=1
# sender_side_delay=243.182 ms, encoding_delay = 9.747 ms, pacing delay = 233.435 ms
#     Packet seq_num=24012, packet_type=video, transport_seq=387, delay_since_capture=226.045 ms
#     Packet seq_num=24013, packet_type=video, transport_seq=389, delay_since_capture=237.379 ms
#     Packet seq_num=32146, packet_type=fec, transport_seq=391, delay_since_capture=243.182 ms
#
# Frame rtp_ts_capture = 3669742514
# rtp_ts=1477856503, frame_type=delta, frame_size=3762 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=225.832 ms, encoding_delay = 9.243 ms, pacing delay = 216.589 ms
#     Packet seq_num=24014, packet_type=video, transport_seq=390, delay_since_capture=204.224 ms
#     Packet seq_num=24015, packet_type=video, transport_seq=392, delay_since_capture=212.056 ms
#     Packet seq_num=24016, packet_type=video, transport_seq=393, delay_since_capture=215.474 ms
#     Packet seq_num=24017, packet_type=video, transport_seq=394, delay_since_capture=220.236 ms
#     Packet seq_num=32147, packet_type=fec, transport_seq=396, delay_since_capture=225.832 ms
#
# Frame rtp_ts_capture = 3669745574
# rtp_ts=1477859563, frame_type=delta, frame_size=7134 bytes, packet_count=7, num_media_packets=7, num_fec_packets=1
# sender_side_delay=228.425 ms, encoding_delay = 8.655 ms, pacing delay = 219.77 ms
#     Packet seq_num=24018, packet_type=video, transport_seq=395, delay_since_capture=192.441 ms
#     Packet seq_num=24019, packet_type=video, transport_seq=397, delay_since_capture=196.887 ms
#     Packet seq_num=24020, packet_type=video, transport_seq=398, delay_since_capture=202.198 ms
#     Packet seq_num=24021, packet_type=video, transport_seq=399, delay_since_capture=207.567 ms
#     Packet seq_num=24022, packet_type=video, transport_seq=400, delay_since_capture=207.639 ms
#     Packet seq_num=24023, packet_type=video, transport_seq=401, delay_since_capture=211.39 ms
# ...
#     Packet seq_num=27908, packet_type=video, transport_seq=4710, delay_since_capture=18.969 ms
#     Packet seq_num=27909, packet_type=video, transport_seq=4711, delay_since_capture=23.682 ms
#     Packet seq_num=27910, packet_type=video, transport_seq=4712, delay_since_capture=23.716 ms
#     Packet seq_num=27911, packet_type=video, transport_seq=4713, delay_since_capture=26.324 ms
#     Packet seq_num=27912, packet_type=video, transport_seq=4714, delay_since_capture=26.349 ms
#     Packet seq_num=27913, packet_type=video, transport_seq=4715, delay_since_capture=28.624 ms
#     Packet seq_num=27914, packet_type=video, transport_seq=4716, delay_since_capture=34.257 ms
#     Packet seq_num=27915, packet_type=video, transport_seq=4717, delay_since_capture=34.277 ms
#     Packet seq_num=27916, packet_type=video, transport_seq=4718, delay_since_capture=34.32 ms
#     Packet seq_num=32572, packet_type=fec, transport_seq=4719, delay_since_capture=38.628 ms
#
# Frame rtp_ts_capture = 3671263514
# rtp_ts=1479377503, frame_type=delta, frame_size=6285 bytes, packet_count=6, num_media_packets=6, num_fec_packets=1
# sender_side_delay=33.126 ms, encoding_delay = 18.585 ms, pacing delay = 14.541 ms
#     Packet seq_num=27917, packet_type=video, transport_seq=4720, delay_since_capture=18.778 ms
#     Packet seq_num=27918, packet_type=video, transport_seq=4721, delay_since_capture=23.27 ms
#     Packet seq_num=27919, packet_type=video, transport_seq=4722, delay_since_capture=23.338 ms
#     Packet seq_num=27920, packet_type=video, transport_seq=4723, delay_since_capture=28.647 ms
#     Packet seq_num=27921, packet_type=video, transport_seq=4724, delay_since_capture=28.709 ms
#     Packet seq_num=27922, packet_type=video, transport_seq=4725, delay_since_capture=28.781 ms
#     Packet seq_num=32573, packet_type=fec, transport_seq=4726, delay_since_capture=33.126 ms
#
# Frame rtp_ts_capture = 3671266574
# rtp_ts=1479380563, frame_type=delta, frame_size=1613 bytes, packet_count=2, num_media_packets=2, num_fec_packets=1
# sender_side_delay=24.505 ms, encoding_delay = 14.364 ms, pacing delay = 10.141 ms
#     Packet seq_num=27923, packet_type=video, transport_seq=4727, delay_since_capture=14.654 ms
#     Packet seq_num=27924, packet_type=video, transport_seq=4728, delay_since_capture=19.106 ms
#     Packet seq_num=32574, packet_type=fec, transport_seq=4729, delay_since_capture=24.505 ms
#
# Frame rtp_ts_capture = 3671269544
# rtp_ts=1479383533, frame_type=delta, frame_size=12401 bytes, packet_count=12, num_media_packets=12, num_fec_packets=1
# sender_side_delay=49.168 ms, encoding_delay = 24.792 ms, pacing delay = 24.376 ms
#     Packet seq_num=27925, packet_type=video, transport_seq=4730, delay_since_capture=25.225 ms
#     Packet seq_num=27926, packet_type=video, transport_seq=4731, delay_since_capture=29.79 ms
#     Packet seq_num=27927, packet_type=video, transport_seq=4732, delay_since_capture=29.85 ms
#     Packet seq_num=27928, packet_type=video, transport_seq=4733, delay_since_capture=35.198 ms
#     Packet seq_num=27929, packet_type=video, transport_seq=4734, delay_since_capture=35.257 ms
#     Packet seq_num=27930, packet_type=video, transport_seq=4735, delay_since_capture=35.298 ms
#     Packet seq_num=27931, packet_type=video, transport_seq=4736, delay_since_capture=39.807 ms
#     Packet seq_num=27932, packet_type=video, transport_seq=4737, delay_since_capture=39.859 ms
#     Packet seq_num=27933, packet_type=video, transport_seq=4738, delay_since_capture=39.91 ms
#     Packet seq_num=27934, packet_type=video, transport_seq=4739, delay_since_capture=45.067 ms
#     Packet seq_num=27935, packet_type=video, transport_seq=4740, delay_since_capture=45.117 ms
#     Packet seq_num=27936, packet_type=video, transport_seq=4741, delay_since_capture=45.207 ms
#     Packet seq_num=32575, packet_type=fec, transport_seq=4742, delay_since_capture=49.168 ms
#
# Frame rtp_ts_capture = 3671272514
# rtp_ts=1479386503, frame_type=delta, frame_size=4078 bytes, packet_count=4, num_media_packets=4, num_fec_packets=1
# sender_side_delay=27.84 ms, encoding_delay = 15.69 ms, pacing delay = 12.15 ms
#     Packet seq_num=27937, packet_type=video, transport_seq=4743, delay_since_capture=15.879 ms
#     Packet seq_num=27938, packet_type=video, transport_seq=4744, delay_since_capture=17.099 ms
#     Packet seq_num=27939, packet_type=video, transport_seq=4745, delay_since_capture=22.475 ms
#     Packet seq_num=27940, packet_type=video, transport_seq=4746, delay_since_capture=22.57 ms
#     Packet seq_num=32576, packet_type=fec, transport_seq=4747, delay_since_capture=27.84 ms
#
# Frame rtp_ts_capture = 3671275574
# rtp_ts=1479389563, frame_type=delta, frame_size=7845 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=45.379 ms, encoding_delay = 24.244 ms, pacing delay = 21.135 ms
#     Packet seq_num=27941, packet_type=video, transport_seq=4748, delay_since_capture=24.553 ms
#     Packet seq_num=27942, packet_type=video, transport_seq=4749, delay_since_capture=29.02 ms
#     Packet seq_num=27943, packet_type=video, transport_seq=4750, delay_since_capture=29.075 ms
#     Packet seq_num=27944, packet_type=video, transport_seq=4751, delay_since_capture=34.608 ms
#     Packet seq_num=27945, packet_type=video, transport_seq=4752, delay_since_capture=34.662 ms
#     Packet seq_num=27946, packet_type=video, transport_seq=4753, delay_since_capture=34.7 ms
#     Packet seq_num=27947, packet_type=video, transport_seq=4754, delay_since_capture=34.739 ms
#     Packet seq_num=27948, packet_type=video, transport_seq=4755, delay_since_capture=40.083 ms
#     Packet seq_num=32577, packet_type=fec, transport_seq=4756, delay_since_capture=45.379 ms
#
# Frame rtp_ts_capture = 3671278544
# rtp_ts=1479392533, frame_type=delta, frame_size=9117 bytes, packet_count=9, num_media_packets=9, num_fec_packets=1
# sender_side_delay=41.534 ms, encoding_delay = 19.598 ms, pacing delay = 21.936 ms
#     Packet seq_num=27949, packet_type=video, transport_seq=4757, delay_since_capture=19.778 ms
#     Packet seq_num=27950, packet_type=video, transport_seq=4758, delay_since_capture=24.627 ms
#     Packet seq_num=27951, packet_type=video, transport_seq=4759, delay_since_capture=24.679 ms
#     Packet seq_num=27952, packet_type=video, transport_seq=4760, delay_since_capture=26.13 ms
#     Packet seq_num=27953, packet_type=video, transport_seq=4761, delay_since_capture=30.639 ms
#     Packet seq_num=27954, packet_type=video, transport_seq=4762, delay_since_capture=30.692 ms
#     Packet seq_num=27955, packet_type=video, transport_seq=4763, delay_since_capture=30.733 ms
#     Packet seq_num=27956, packet_type=video, transport_seq=4764, delay_since_capture=36.071 ms
#     Packet seq_num=27957, packet_type=video, transport_seq=4765, delay_since_capture=36.159 ms
#     Packet seq_num=32578, packet_type=fec, transport_seq=4766, delay_since_capture=41.534 ms
#
# Frame rtp_ts_capture = 3671281514
# rtp_ts=1479395503, frame_type=delta, frame_size=7789 bytes, packet_count=8, num_media_packets=8, num_fec_packets=1
# sender_side_delay=40.928 ms, encoding_delay = 19.498 ms, pacing delay = 21.43 ms
#     Packet seq_num=27958, packet_type=video, transport_seq=4767, delay_since_capture=19.719 ms
#     Packet seq_num=27959, packet_type=video, transport_seq=4768, delay_since_capture=25.267 ms
#     Packet seq_num=27960, packet_type=video, transport_seq=4769, delay_since_capture=25.322 ms
#     Packet seq_num=27961, packet_type=video, transport_seq=4770, delay_since_capture=25.364 ms
#     Packet seq_num=27962, packet_type=video, transport_seq=4771, delay_since_capture=30.829 ms
#     Packet seq_num=27963, packet_type=video, transport_seq=4772, delay_since_capture=30.882 ms
#     Packet seq_num=27964, packet_type=video, transport_seq=4773, delay_since_capture=30.931 ms
#     Packet seq_num=27965, packet_type=video, transport_seq=4774, delay_since_capture=34.993 ms
#     Packet seq_num=32579, packet_type=fec, transport_seq=4775, delay_since_capture=40.928 ms
#
# Frame rtp_ts_capture = 3671284574
# rtp_ts=1479398563, frame_type=delta, frame_size=18224 bytes, packet_count=17, num_media_packets=17, num_fec_packets=1
# sender_side_delay=52.825 ms, encoding_delay = 19.627 ms, pacing delay = 33.198 ms
#     Packet seq_num=27966, packet_type=video, transport_seq=4776, delay_since_capture=19.853 ms
#     Packet seq_num=27967, packet_type=video, transport_seq=4777, delay_since_capture=25.16 ms
#     Packet seq_num=27968, packet_type=video, transport_seq=4778, delay_since_capture=25.214 ms
#     Packet seq_num=27969, packet_type=video, transport_seq=4779, delay_since_capture=25.263 ms
#     Packet seq_num=27970, packet_type=video, transport_seq=4780, delay_since_capture=30.438 ms
#     Packet seq_num=27971, packet_type=video, transport_seq=4781, delay_since_capture=30.491 ms
#     Packet seq_num=27972, packet_type=video, transport_seq=4782, delay_since_capture=30.541 ms
#     Packet seq_num=27973, packet_type=video, transport_seq=4783, delay_since_capture=34.87 ms
#     Packet seq_num=27974, packet_type=video, transport_seq=4784, delay_since_capture=34.923 ms
#     Packet seq_num=27975, packet_type=video, transport_seq=4785, delay_since_capture=40.233 ms
#     Packet seq_num=27976, packet_type=video, transport_seq=4786, delay_since_capture=40.288 ms
#     Packet seq_num=27977, packet_type=video, transport_seq=4787, delay_since_capture=40.327 ms
#     Packet seq_num=27978, packet_type=video, transport_seq=4788, delay_since_capture=45.591 ms
#     Packet seq_num=27979, packet_type=video, transport_seq=4789, delay_since_capture=45.645 ms
#     Packet seq_num=27980, packet_type=video, transport_seq=4790, delay_since_capture=45.683 ms
#     Packet seq_num=27981, packet_type=video, transport_seq=4791, delay_since_capture=49.014 ms
#     Packet seq_num=27982, packet_type=video, transport_seq=4792, delay_since_capture=49.125 ms
#     Packet seq_num=32580, packet_type=fec, transport_seq=4794, delay_since_capture=52.825 ms
#
# Frame rtp_ts_capture = 3671287544
# rtp_ts=1479401533, frame_type=delta, frame_size=12793 bytes, packet_count=12, num_media_packets=12, num_fec_packets=1
# sender_side_delay=43.379 ms, encoding_delay = 12.15 ms, pacing delay = 31.229 ms
#     Packet seq_num=27983, packet_type=video, transport_seq=4793, delay_since_capture=17.121 ms
#     Packet seq_num=27984, packet_type=video, transport_seq=4795, delay_since_capture=19.516 ms
#     Packet seq_num=27985, packet_type=video, transport_seq=4796, delay_since_capture=21.794 ms
#     Packet seq_num=27986, packet_type=video, transport_seq=4797, delay_since_capture=26.428 ms
#     Packet seq_num=27987, packet_type=video, transport_seq=4798, delay_since_capture=26.479 ms
#     Packet seq_num=27988, packet_type=video, transport_seq=4799, delay_since_capture=26.526 ms
#     Packet seq_num=27989, packet_type=video, transport_seq=4800, delay_since_capture=31.756 ms
#     Packet seq_num=27990, packet_type=video, transport_seq=4801, delay_since_capture=31.808 ms
#     Packet seq_num=27991, packet_type=video, transport_seq=4802, delay_since_capture=31.853 ms
#     Packet seq_num=27992, packet_type=video, transport_seq=4803, delay_since_capture=37.21 ms
#     Packet seq_num=27993, packet_type=video, transport_seq=4804, delay_since_capture=37.264 ms
#     Packet seq_num=27994, packet_type=video, transport_seq=4805, delay_since_capture=37.373 ms
#     Packet seq_num=32581, packet_type=fec, transport_seq=4806, delay_since_capture=43.379 ms
#
# Frame rtp_ts_capture = 3671290514
# rtp_ts=1479404503, frame_type=delta, frame_size=10246 bytes, packet_count=10, num_media_packets=10, num_fec_packets=1
# sender_side_delay=32.704 ms, encoding_delay = 11.706 ms, pacing delay = 20.998 ms
#     Packet seq_num=27995, packet_type=video, transport_seq=4807, delay_since_capture=11.905 ms
#     Packet seq_num=27996, packet_type=video, transport_seq=4808, delay_since_capture=16.275 ms
#     Packet seq_num=27997, packet_type=video, transport_seq=4809, delay_since_capture=16.331 ms
#     Packet seq_num=27998, packet_type=video, transport_seq=4810, delay_since_capture=17.7 ms
#     Packet seq_num=27999, packet_type=video, transport_seq=4811, delay_since_capture=21.986 ms
#     Packet seq_num=28000, packet_type=video, transport_seq=4812, delay_since_capture=22.03 ms
#     Packet seq_num=28001, packet_type=video, transport_seq=4813, delay_since_capture=22.08 ms
#     Packet seq_num=28002, packet_type=video, transport_seq=4814, delay_since_capture=27.299 ms
#     Packet seq_num=28003, packet_type=video, transport_seq=4815, delay_since_capture=27.343 ms
#     Packet seq_num=28004, packet_type=video, transport_seq=4816, delay_since_capture=27.423 ms
#     Packet seq_num=32582, packet_type=fec, transport_seq=4817, delay_since_capture=32.704 ms
#
# Frame rtp_ts_capture = 3671293574
# rtp_ts=1479407563, frame_type=delta, frame_size=11099 bytes, packet_count=10, num_media_packets=10, num_fec_packets=1
# sender_side_delay=46.165 ms, encoding_delay = 20.075 ms, pacing delay = 26.09 ms
#     Packet seq_num=28005, packet_type=video, transport_seq=4818, delay_since_capture=20.395 ms
#     Packet seq_num=28006, packet_type=video, transport_seq=4819, delay_since_capture=25.808 ms
#     Packet seq_num=28007, packet_type=video, transport_seq=4820, delay_since_capture=25.878 ms
#     Packet seq_num=28008, packet_type=video, transport_seq=4821, delay_since_capture=25.918 ms
#     Packet seq_num=28009, packet_type=video, transport_seq=4822, delay_since_capture=31.337 ms
#     Packet seq_num=28010, packet_type=video, transport_seq=4823, delay_since_capture=31.374 ms
#     Packet seq_num=28011, packet_type=video, transport_seq=4824, delay_since_capture=31.391 ms
#     Packet seq_num=28012, packet_type=video, transport_seq=4825, delay_since_capture=33.765 ms
#     Packet seq_num=28013, packet_type=video, transport_seq=4826, delay_since_capture=36.093 ms
#     Packet seq_num=28014, packet_type=video, transport_seq=4827, delay_since_capture=41.708 ms
#     Packet seq_num=32583, packet_type=fec, transport_seq=4828, delay_since_capture=46.165 ms
#
# Frame rtp_ts_capture = 3671296544
# rtp_ts=1479410533, frame_type=delta, frame_size=3132 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=21.528 ms, encoding_delay = 13.367 ms, pacing delay = 8.161 ms
#     Packet seq_num=28015, packet_type=video, transport_seq=4829, delay_since_capture=13.493 ms
#     Packet seq_num=28016, packet_type=video, transport_seq=4830, delay_since_capture=18.832 ms
#     Packet seq_num=28017, packet_type=video, transport_seq=4831, delay_since_capture=18.896 ms
#     Packet seq_num=32584, packet_type=fec, transport_seq=4832, delay_since_capture=21.528 ms
#
# Frame rtp_ts_capture = 3671299514
# rtp_ts=1479413503, frame_type=delta, frame_size=2642 bytes, packet_count=3, num_media_packets=3, num_fec_packets=1
# sender_side_delay=22.452 ms, encoding_delay = 12.599 ms, pacing delay = 9.853 ms
#     Packet seq_num=28018, packet_type=video, transport_seq=4833, delay_since_capture=12.761 ms
#     Packet seq_num=28019, packet_type=video, transport_seq=4834, delay_since_capture=17.118 ms
#     Packet seq_num=28020, packet_type=video, transport_seq=4835, delay_since_capture=17.183 ms
#     Packet seq_num=32585, packet_type=fec, transport_seq=4836, delay_since_capture=22.452 ms
#
# Frame rtp_ts_capture = 3671302574
# rtp_ts=1479416563, frame_type=delta, frame_size=12692 bytes, packet_count=12, num_media_packets=0, num_fec_packets=0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 43
#      40 sender_side_delay = last_packet_sent_ts - ts_captured if last_packet_sent_ts is not None else None
#      42 print(f"rtp_ts={rtp_ts}, frame_type={frame_type}, frame_size={frame_size} bytes, packet_count={packet_count}, num_media_packets={num_media_packets}, num_fec_packets={num_fec_packets}")
# ---> 43 print(f"sender_side_delay={sender_side_delay/1000} ms, encoding_delay = {encoding_delay/1000} ms, pacing delay = {pacing_delay/1000} ms")
#      45 for _, packet_event in events_packet_sent.iterrows():
#      46     seq = packet_event["args.seq"]
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'
