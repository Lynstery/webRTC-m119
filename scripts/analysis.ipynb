# %%
import json
import pandas as pd
import numpy as np

def load_events(path):
    with open(path) as f:
        data = json.load(f)
    return data["traceEvents"]

def flatten_event(e, source):
    """展开 args，仅保留 name, ts, args.xxx，并增加 from 字段"""

    out = {
        "name": e.get("name"),
        "ts": e.get("ts"),
        "from": source, 
    }

    args = e.get("args", {})
    if isinstance(args, dict):
        for k, v in args.items():
            out[f"args.{k}"] = v

    return out

def preprocess_events(events):
    tmp = pd.DataFrame(events)
    args_uint64 = tmp.dtypes[tmp.dtypes == "float64"]
    print(args_uint64.index.tolist())
    for e in events:
        for arg in args_uint64.index.tolist():
            if arg not in e:
                e[arg] = 0

path_sender = "../expr/trace_sender.json"
path_receiver = "../expr/trace_receiver.json"

# 读取原始数据
events_sender = load_events(path_sender)
events_receiver = load_events(path_receiver)

# 展开 + 加 from 字段
flat_sender = [flatten_event(e, "sender") for e in events_sender]
flat_receiver = [flatten_event(e, "receiver") for e in events_receiver]

# 合并两个列表
all_events = flat_sender + flat_receiver

preprocess_events(all_events)

df = pd.DataFrame(all_events)

df.dtypes
df["name"].unique().tolist()
# Out:
# ['args.last_target_bps', 'args.last_stable_target_bps', 'args.last_fraction_loss_', 'args.last_rtt_ms', 'args.value', 'args.update_target_bitrate_bps', 'args.encoder_target_rate_bps', 'args.protection_bitrate_bps', 'args.encoder_overhead_rate_bps', 'args.post_encode_overhead_bps', 'args.rtp_ts_capture', 'args.rtp_ts', 'args.capture_time_ms', 'args.frame_size', 'args.packet_count', 'args.transport_seq', 'args.is_received', 'args.last_rtp_ts', 'args.num_media_packets', 'args.num_fec_packets', 'args.param_fec_rate', 'args.fec_payload_type', 'args.fec_ssrc', 'args.protected_frame_rtp_ts', 'args.rtt_ms', 'args.total_delta', 'args.lost_delta', 'args.payload_type', 'args.is_recovered', 'args.picture_id', 'args.render_time_ms', 'args.fec_seq', 'args.scheduled_decode_time_ms', 'args.rtx_seq']
# ['BitrateAllocator:OnChanged',
#  'rtt_ms',
#  'loss',
#  'bwe_bps',
#  'Sender:AllocateBitrate',
#  'Frame:Captured',
#  'Frame:Start Encode',
#  'Frame:Encoded',
#  'Frame:Packetization',
#  'Frame:Dropped',
#  'Packet:Sent',
#  'RTCP:TransportPacketFeedback',
#  'Frame:Generate FEC',
#  'FlexFEC:GetFecPackets',
#  'RTCP:receive NACK',
#  'RTCP:Receive RTT',
#  'RTCP:ReportBlocksTransportLossReport',
#  'RtpDemuxer:ResolveSink',
#  'Packet:Receive Media RTP',
#  'FlexFEC:Receive RTP Packet',
#  'Frame:Received EncodedFrame',
#  'Frame:ToFrameBuffer',
#  'Frame:ReadytoDecode',
#  'Frame:Start Decode',
#  'FlexFEC:Receive FEC Packet',
#  'Frame:Decoded',
#  'RTCP:SendNack',
#  'Packet:Receive Recovered Media RTP',
#  'Frame:Scheduled for Decode',
#  'FlexFEC:Recover Packet',
#  'Rtx:Receive RTX Packet']

# %%
all_frame_rtp_ts_capture = df[df["name"] == "Frame:Captured"]["args.rtp_ts_capture"].unique()
all_frame_rtp_ts_capture.sort()

for rtp_ts_capture in all_frame_rtp_ts_capture:
    print("--------------------------------")
    print("Frame rtp_ts_capture =", rtp_ts_capture)
    event_frame_captured = df[(df["name"] == "Frame:Captured") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    event_frame_start_encode = df[(df["name"] == "Frame:Start Encode") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    
    if event_frame_start_encode.empty:
        event_frame_dropped = df[(df["name"] == "Frame:Dropped") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        reason = event_frame_dropped["args.reason"].values[0] 
        print(f"    dropped before encoding, reason={reason}!")
        continue
    else:
        event_frame_encoded = df[(df["name"] == "Frame:Encoded") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        
        if event_frame_encoded.empty:
            print(f"    dropped by encoder!")
            continue
        
        ts_captured = event_frame_captured["ts"].values[0]
        ts_encoded = event_frame_encoded["ts"].values[0]
        rtp_ts = event_frame_encoded["args.rtp_ts"].values[0]
        frame_type = event_frame_encoded["args.frame_type"].values[0]
        frame_size = event_frame_encoded["args.frame_size"].values[0]
        event_frame_packetization = df[(df["name"] == "Frame:Packetization") & (df["args.rtp_ts"] == rtp_ts)]
        packet_count = event_frame_packetization["args.packet_count"].values[0]
        event_frame_generate_fec = df[(df["name"] == "Frame:Generate FEC") & (df["args.last_rtp_ts"] == rtp_ts)]
        num_fec_packets = event_frame_generate_fec["args.num_fec_packets"].values[0] if not event_frame_generate_fec.empty else 0

        events_frame_all_packet_sent = df[(df["name"] == "Packet:Sent") & ((df["args.rtp_ts"] == rtp_ts) | (df["args.protected_frame_rtp_ts"] == rtp_ts))]
        events_frame_media_packet_sent = events_frame_all_packet_sent[events_frame_all_packet_sent["args.packet_type"] == "video"]
        
        
        events_frame_all_packet_sent = events_frame_all_packet_sent.sort_values(by="ts")
        events_frame_media_packet_sent = events_frame_media_packet_sent.sort_values(by="ts") 
        
        ts_first_packet_sent = events_frame_all_packet_sent["ts"].values[0] if not events_frame_all_packet_sent.empty else None 
        ts_last_media_packet_sent = events_frame_media_packet_sent["ts"].values[-1] if not events_frame_media_packet_sent.empty else None
        
        encoding_delay = ts_encoded - ts_captured
        pacing_delay = ts_last_media_packet_sent - ts_encoded if ts_last_media_packet_sent is not None else 0

        print(f"rtp_ts={rtp_ts}, frame_type={frame_type}, frame_size={frame_size} bytes, packet_count={packet_count}, num_fec_packets={num_fec_packets}")
        print("all related packets sent:") 
        for _, event_packet_sent in events_frame_all_packet_sent.iterrows():
            seq = event_packet_sent["args.seq"]
            packet_type = event_packet_sent["args.packet_type"]
            ts_packet_sent = event_packet_sent["ts"]
            print(f"    Packet Sent: type={packet_type}, seq={seq}, send_delay_since_encoded={(ts_packet_sent - ts_encoded)/1000} ms")
            
            if packet_type == "video": 
                event_media_packet_received = df[(df["name"] == "Packet:Receive Media RTP") & (df["args.seq"] == seq)]
                event_recovered_packet_received = df[(df["name"] == "Packet:Receive Recovered Media RTP") & (df["args.seq"] == seq)]
                
                if not event_media_packet_received.empty:
                    ts_received = event_media_packet_received["ts"].values[0]
                    print(f"        received, delay_since_sent={(ts_received - ts_packet_sent)/1000} ms, delay_since_encoded={(ts_received - ts_encoded)/1000} ms")
                elif not event_recovered_packet_received.empty:
                    ts_received = event_recovered_packet_received["ts"].values[0]
                    print(f"        received, delay_since_sent={(ts_received - ts_packet_sent)/1000} ms, delay_since_encoded={(ts_received - ts_encoded)/1000} ms (recovered by RTX/FEC)")
                    
            elif packet_type == "fec":
                event_fec_packet_received = df[(df["name"] == "FlexFEC:Receive FEC Packet") & (df["args.fec_seq"] == seq)]
                if not event_fec_packet_received.empty:
                    ts_received = event_fec_packet_received["ts"].values[0]
                    protected_seqs = event_fec_packet_received["args.protected_seqs"].values[0]
                    print(f"        received, delay_since_sent={(ts_received - ts_packet_sent)/1000} ms, delay_since_encoded={(ts_received - ts_encoded)/1000} ms")
                    print(f"        protected seqs={protected_seqs}")
                else:
                    print(f"        NOT received")
                    
            elif packet_type == "rtx":
                event_rtx_packet_received = df[(df["name"] == "Rtx:Receive RTX Packet") & (df["args.rtx_seq"] == seq)]
                if not event_rtx_packet_received.empty:
                    ts_received = event_rtx_packet_received["ts"].values[0]
                    original_seq = event_rtx_packet_received["args.seq"].values[0]
                    print(f"        received, delay_since_sent={(ts_received - ts_packet_sent)/1000} ms, delay_since_encoded={(ts_received - ts_encoded)/1000} ms")
                    print(f"        original seq={original_seq}")
                else:
                    print(f"    NOT received")
            
        if ts_last_media_packet_sent is None:
            print(f"    Not start sending!")
            continue 
        
        print(f"encoding_delay = {encoding_delay/1000} ms, pacing delay = {pacing_delay/1000} ms")
         
        event_frame_received_encoded = df[(df["name"] == "Frame:Received EncodedFrame") & (df["args.rtp_ts"] == rtp_ts)]
        if event_frame_received_encoded.empty:
            print(f"    Not received at receiver!")
            continue
        
        picture_id = event_frame_received_encoded["args.picture_id"].values[0]
        refs = event_frame_received_encoded["args.refs"].values[0]
        ts_received_encoded = event_frame_received_encoded["ts"].values[0]
        
        print(f"received encoded frame")
        
        event_frame_ready_to_decode = df[(df["name"] == "Frame:ReadytoDecode") & (df["args.rtp_ts"] == rtp_ts)] 
        event_frame_start_decode = df[(df["name"] == "Frame:Start Decode") & (df["args.rtp_ts"] == rtp_ts)]
        event_frame_decoded = df[(df["name"] == "Frame:Decoded") & (df["args.rtp_ts"] == rtp_ts)]
        
        if event_frame_decoded.empty:
            print(f"    Not decoded at receiver!")
            continue 
         
        ts_ready_to_decode = event_frame_ready_to_decode["ts"].values[0]
        ts_start_decode = event_frame_start_decode["ts"].values[0]
        ts_decoded = event_frame_decoded["ts"].values[0]
        
        frame_network_delay = ts_received_encoded - ts_last_media_packet_sent
        jitter_delay = ts_start_decode - ts_received_encoded
        decoding_delay = ts_decoded - ts_start_decode
        e2e_delay = ts_decoded - ts_captured
        print(f"picture_id={picture_id}, refs={refs}")
        
        print(f"frame_network_delay={frame_network_delay/1000} ms")
        print(f"jitter_delay={jitter_delay/1000} ms")
        print(f"decoding_delay={decoding_delay/1000} ms")
        print(f"e2e_delay={e2e_delay/1000} ms")
# Out:
# --------------------------------
# Frame rtp_ts_capture = 2191817394
# rtp_ts=1651471566, frame_type=key, frame_size=52321 bytes, packet_count=48
# all related packets sent:
#     Packet Sent: type=video, seq=21880, send_delay_since_encoded=4.175 ms
#         received, delay_since_sent=82.028 ms, delay_since_encoded=86.203 ms
#     Packet Sent: type=video, seq=21881, send_delay_since_encoded=13.86 ms
#         received, delay_since_sent=81.868 ms, delay_since_encoded=95.728 ms
#     Packet Sent: type=video, seq=21882, send_delay_since_encoded=24.251 ms
#         received, delay_since_sent=81.78 ms, delay_since_encoded=106.031 ms
#     Packet Sent: type=video, seq=21883, send_delay_since_encoded=34.646 ms
#         received, delay_since_sent=81.768 ms, delay_since_encoded=116.414 ms
#     Packet Sent: type=video, seq=21884, send_delay_since_encoded=46.228 ms
#         received, delay_since_sent=81.785 ms, delay_since_encoded=128.013 ms
#     Packet Sent: type=video, seq=21885, send_delay_since_encoded=52.521 ms
#         received, delay_since_sent=81.864 ms, delay_since_encoded=134.385 ms
#     Packet Sent: type=video, seq=21886, send_delay_since_encoded=58.048 ms
#         received, delay_since_sent=81.841 ms, delay_since_encoded=139.889 ms
#     Packet Sent: type=video, seq=21887, send_delay_since_encoded=63.673 ms
#         received, delay_since_sent=81.757 ms, delay_since_encoded=145.43 ms
#     Packet Sent: type=video, seq=21888, send_delay_since_encoded=69.117 ms
#         received, delay_since_sent=81.843 ms, delay_since_encoded=150.96 ms
#     Packet Sent: type=video, seq=21889, send_delay_since_encoded=75.974 ms
#         received, delay_since_sent=83.245 ms, delay_since_encoded=159.219 ms
#     Packet Sent: type=video, seq=21890, send_delay_since_encoded=87.589 ms
#         received, delay_since_sent=81.834 ms, delay_since_encoded=169.423 ms
#     Packet Sent: type=video, seq=21891, send_delay_since_encoded=97.915 ms
#         received, delay_since_sent=81.835 ms, delay_since_encoded=179.75 ms
#     Packet Sent: type=video, seq=21892, send_delay_since_encoded=108.252 ms
#         received, delay_since_sent=82.004 ms, delay_since_encoded=190.256 ms
#     Packet Sent: type=video, seq=21893, send_delay_since_encoded=118.011 ms
#         received, delay_since_sent=81.728 ms, delay_since_encoded=199.739 ms
#     Packet Sent: type=video, seq=21894, send_delay_since_encoded=124.331 ms
#         received, delay_since_sent=83.046 ms, delay_since_encoded=207.377 ms
#     Packet Sent: type=video, seq=21895, send_delay_since_encoded=129.784 ms
#         received, delay_since_sent=81.761 ms, delay_since_encoded=211.545 ms
#     Packet Sent: type=video, seq=21896, send_delay_since_encoded=135.235 ms
#         received, delay_since_sent=81.811 ms, delay_since_encoded=217.046 ms
#     Packet Sent: type=video, seq=21897, send_delay_since_encoded=140.803 ms
#         received, delay_since_sent=81.729 ms, delay_since_encoded=222.532 ms
#     Packet Sent: type=video, seq=21898, send_delay_since_encoded=256.372 ms
#         received, delay_since_sent=81.906 ms, delay_since_encoded=338.278 ms
#     Packet Sent: type=video, seq=21899, send_delay_since_encoded=256.432 ms
#         received, delay_since_sent=82.055 ms, delay_since_encoded=338.487 ms
#     Packet Sent: type=video, seq=21900, send_delay_since_encoded=256.476 ms
#         received, delay_since_sent=82.226 ms, delay_since_encoded=338.702 ms
#     Packet Sent: type=video, seq=21901, send_delay_since_encoded=256.522 ms
#         received, delay_since_sent=83.852 ms, delay_since_encoded=340.374 ms
#     Packet Sent: type=video, seq=21902, send_delay_since_encoded=256.562 ms
#         received, delay_since_sent=86.378 ms, delay_since_encoded=342.94 ms
#     Packet Sent: type=video, seq=21903, send_delay_since_encoded=256.602 ms
#         received, delay_since_sent=88.731 ms, delay_since_encoded=345.333 ms
#     Packet Sent: type=video, seq=21904, send_delay_since_encoded=256.642 ms
#         received, delay_since_sent=91.337 ms, delay_since_encoded=347.979 ms
#     Packet Sent: type=video, seq=21905, send_delay_since_encoded=256.682 ms
#         received, delay_since_sent=93.782 ms, delay_since_encoded=350.464 ms
#     Packet Sent: type=video, seq=21906, send_delay_since_encoded=256.734 ms
#         received, delay_since_sent=96.389 ms, delay_since_encoded=353.123 ms
#     Packet Sent: type=video, seq=21907, send_delay_since_encoded=256.774 ms
#         received, delay_since_sent=98.783 ms, delay_since_encoded=355.557 ms
#     Packet Sent: type=video, seq=21908, send_delay_since_encoded=261.379 ms
#         received, delay_since_sent=96.83 ms, delay_since_encoded=358.209 ms
#     Packet Sent: type=video, seq=21909, send_delay_since_encoded=267.369 ms
#         received, delay_since_sent=93.424 ms, delay_since_encoded=360.793 ms
#     Packet Sent: type=video, seq=21910, send_delay_since_encoded=271.946 ms
#         received, delay_since_sent=91.383 ms, delay_since_encoded=363.329 ms
#     Packet Sent: type=video, seq=21911, send_delay_since_encoded=275.466 ms
#         received, delay_since_sent=90.422 ms, delay_since_encoded=365.888 ms
#     Packet Sent: type=video, seq=21912, send_delay_since_encoded=282.152 ms
#         received, delay_since_sent=86.304 ms, delay_since_encoded=368.456 ms
#     Packet Sent: type=video, seq=21913, send_delay_since_encoded=284.033 ms
#         received, delay_since_sent=87.825 ms, delay_since_encoded=371.858 ms
#     Packet Sent: type=video, seq=21914, send_delay_since_encoded=292.869 ms
#         received, delay_since_sent=81.816 ms, delay_since_encoded=374.685 ms
#     Packet Sent: type=video, seq=21915, send_delay_since_encoded=298.324 ms
#         received, delay_since_sent=81.921 ms, delay_since_encoded=380.245 ms
#     Packet Sent: type=video, seq=21916, send_delay_since_encoded=298.379 ms
#         received, delay_since_sent=82.127 ms, delay_since_encoded=380.506 ms
#     Packet Sent: type=video, seq=21917, send_delay_since_encoded=302.894 ms
#         received, delay_since_sent=81.887 ms, delay_since_encoded=384.781 ms
#     Packet Sent: type=video, seq=21918, send_delay_since_encoded=308.46 ms
#         received, delay_since_sent=81.847 ms, delay_since_encoded=390.307 ms
#     Packet Sent: type=video, seq=21919, send_delay_since_encoded=313.216 ms
#         received, delay_since_sent=81.854 ms, delay_since_encoded=395.07 ms
#     Packet Sent: type=video, seq=21920, send_delay_since_encoded=318.289 ms
#         received, delay_since_sent=81.777 ms, delay_since_encoded=400.066 ms
#     Packet Sent: type=video, seq=21921, send_delay_since_encoded=323.812 ms
#         received, delay_since_sent=81.786 ms, delay_since_encoded=405.598 ms
#     Packet Sent: type=video, seq=21922, send_delay_since_encoded=329.785 ms
#         received, delay_since_sent=81.787 ms, delay_since_encoded=411.572 ms
#     Packet Sent: type=video, seq=21923, send_delay_since_encoded=335.218 ms
#         received, delay_since_sent=81.957 ms, delay_since_encoded=417.175 ms
#     Packet Sent: type=video, seq=21924, send_delay_since_encoded=337.864 ms
#         received, delay_since_sent=81.684 ms, delay_since_encoded=419.548 ms
#     Packet Sent: type=video, seq=21925, send_delay_since_encoded=345.46 ms
#         received, delay_since_sent=81.786 ms, delay_since_encoded=427.246 ms
#     Packet Sent: type=video, seq=21926, send_delay_since_encoded=349.847 ms
#         received, delay_since_sent=81.677 ms, delay_since_encoded=431.524 ms
#     Packet Sent: type=video, seq=21927, send_delay_since_encoded=355.393 ms
#         received, delay_since_sent=81.826 ms, delay_since_encoded=437.219 ms
#     Packet Sent: type=fec, seq=5303, send_delay_since_encoded=362.331 ms
#         received, delay_since_sent=82.158 ms, delay_since_encoded=444.489 ms
#         protected seqs=[21880, 21881, 21882, 21883, 21884, 21885, 21886, 21887, 21888, 21889, 21890, 21891, 21892, 21893, 21894, 21895, 21896, 21897, 21898, 21899, 21900, 21901, 21902, 21903, 21904, 21905, 21906, 21907, 21908, 21909, 21910, 21911, 21912, 21913, 21914, 21915, 21916, 21917, 21918, 21919, 21920, 21921, 21922, 21923, 21924, 21925, 21926, 21927]
# num_media_packets=48, num_fec_packets=1
# encoding_delay = 73.321 ms, pacing delay = 355.393 ms
# received encoded frame
# picture_id=7613, refs=[]
# frame_network_delay=82.267 ms
# jitter_delay=0.593 ms
# decoding_delay=36.324 ms
# e2e_delay=547.898 ms
# --------------------------------
# Frame rtp_ts_capture = 2191820454
#     dropped before encoding, reason=encoder_blocked!
# --------------------------------
# Frame rtp_ts_capture = 2191823424
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 2191826394
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 2191829454
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 2191832424
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 2191835394
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 2191838454
# rtp_ts=1651492626, frame_type=delta, frame_size=24518 bytes, packet_count=23
# all related packets sent:
#     Packet Sent: type=video, seq=21928, send_delay_since_encoded=182.495 ms
#         received, delay_since_sent=81.78 ms, delay_since_encoded=264.275 ms
#     Packet Sent: type=video, seq=21929, send_delay_since_encoded=192.753 ms
#         received, delay_since_sent=81.998 ms, delay_since_encoded=274.751 ms
#     Packet Sent: type=video, seq=21930, send_delay_since_encoded=195.342 ms
#         received, delay_since_sent=81.975 ms, delay_since_encoded=277.317 ms
#     Packet Sent: type=video, seq=21931, send_delay_since_encoded=203.139 ms
#         received, delay_since_sent=81.846 ms, delay_since_encoded=284.985 ms
#     Packet Sent: type=video, seq=21932, send_delay_since_encoded=207.628 ms
#         received, delay_since_sent=81.84 ms, delay_since_encoded=289.468 ms
#     Packet Sent: type=video, seq=21933, send_delay_since_encoded=209.144 ms
#         received, delay_since_sent=81.839 ms, delay_since_encoded=290.983 ms
#     Packet Sent: type=video, seq=21934, send_delay_since_encoded=217.711 ms
#         received, delay_since_sent=82.017 ms, delay_since_encoded=299.728 ms
#     Packet Sent: type=video, seq=21935, send_delay_since_encoded=217.776 ms
#         received, delay_since_sent=82.19 ms, delay_since_encoded=299.966 ms
#     Packet Sent: type=video, seq=21936, send_delay_since_encoded=222.636 ms
#         received, delay_since_sent=162.076 ms, delay_since_encoded=384.712 ms (recovered by RTX/FEC)
#     Packet Sent: type=video, seq=21937, send_delay_since_encoded=228.085 ms
#         received, delay_since_sent=81.894 ms, delay_since_encoded=309.979 ms
#     Packet Sent: type=video, seq=21938, send_delay_since_encoded=232.485 ms
#         received, delay_since_sent=81.721 ms, delay_since_encoded=314.206 ms
#     Packet Sent: type=video, seq=21939, send_delay_since_encoded=238.242 ms
#         received, delay_since_sent=81.612 ms, delay_since_encoded=319.854 ms
#     Packet Sent: type=video, seq=21940, send_delay_since_encoded=243.642 ms
#         received, delay_since_sent=81.611 ms, delay_since_encoded=325.253 ms
#     Packet Sent: type=video, seq=21941, send_delay_since_encoded=249.0 ms
#         received, delay_since_sent=81.643 ms, delay_since_encoded=330.643 ms
#     Packet Sent: type=video, seq=21942, send_delay_since_encoded=254.53 ms
#         received, delay_since_sent=81.723 ms, delay_since_encoded=336.253 ms
#     Packet Sent: type=video, seq=21943, send_delay_since_encoded=259.147 ms
#         received, delay_since_sent=81.733 ms, delay_since_encoded=340.88 ms
#     Packet Sent: type=video, seq=21944, send_delay_since_encoded=265.408 ms
#         received, delay_since_sent=81.622 ms, delay_since_encoded=347.03 ms
#     Packet Sent: type=video, seq=21945, send_delay_since_encoded=270.811 ms
#         received, delay_since_sent=81.667 ms, delay_since_encoded=352.478 ms
#     Packet Sent: type=video, seq=21946, send_delay_since_encoded=270.872 ms
#         received, delay_since_sent=81.891 ms, delay_since_encoded=352.763 ms
#     Packet Sent: type=video, seq=21947, send_delay_since_encoded=276.31 ms
#         received, delay_since_sent=81.662 ms, delay_since_encoded=357.972 ms
#     Packet Sent: type=video, seq=21948, send_delay_since_encoded=281.073 ms
#         received, delay_since_sent=81.544 ms, delay_since_encoded=362.617 ms
#     Packet Sent: type=video, seq=21949, send_delay_since_encoded=288.13 ms
#         received, delay_since_sent=81.702 ms, delay_since_encoded=369.832 ms
#     Packet Sent: type=video, seq=21950, send_delay_since_encoded=292.707 ms
#         received, delay_since_sent=81.752 ms, delay_since_encoded=374.459 ms
#     Packet Sent: type=fec, seq=5304, send_delay_since_encoded=302.577 ms
#         received, delay_since_sent=81.642 ms, delay_since_encoded=384.219 ms
#         protected seqs=[21928, 21929, 21930, 21931, 21932, 21933, 21934, 21935, 21936, 21937, 21938, 21939, 21940, 21941, 21942, 21943, 21944, 21945, 21946, 21947, 21948, 21949, 21950]
#     Packet Sent: type=rtx, seq=14300, send_delay_since_encoded=334.109 ms
#         received, delay_since_sent=81.859 ms, delay_since_encoded=415.968 ms
#         original seq=21936
# num_media_packets=23, num_fec_packets=1
# encoding_delay = 17.377 ms, pacing delay = 292.707 ms
# received encoded frame
# picture_id=7614, refs=[7613]
# frame_network_delay=92.211 ms
# jitter_delay=0.385 ms
# decoding_delay=21.541 ms
# e2e_delay=424.221 ms
# --------------------------------
# Frame rtp_ts_capture = 2191841424
# rtp_ts=1651495596, frame_type=delta, frame_size=31318 bytes, packet_count=29
# all related packets sent:
#     Packet Sent: type=video, seq=21951, send_delay_since_encoded=247.535 ms
#         received, delay_since_sent=81.653 ms, delay_since_encoded=329.188 ms
#     Packet Sent: type=video, seq=21952, send_delay_since_encoded=257.685 ms
#         received, delay_since_sent=81.681 ms, delay_since_encoded=339.366 ms
#     Packet Sent: type=video, seq=21953, send_delay_since_encoded=259.152 ms
#         received, delay_since_sent=81.798 ms, delay_since_encoded=340.95 ms
#     Packet Sent: type=video, seq=21954, send_delay_since_encoded=263.544 ms
#         received, delay_since_sent=81.663 ms, delay_since_encoded=345.207 ms
#     Packet Sent: type=video, seq=21955, send_delay_since_encoded=267.992 ms
#         received, delay_since_sent=81.756 ms, delay_since_encoded=349.748 ms
#     Packet Sent: type=video, seq=21956, send_delay_since_encoded=273.555 ms
#         received, delay_since_sent=81.841 ms, delay_since_encoded=355.396 ms
#     Packet Sent: type=video, seq=21957, send_delay_since_encoded=277.904 ms
#         received, delay_since_sent=81.871 ms, delay_since_encoded=359.775 ms
#     Packet Sent: type=video, seq=21958, send_delay_since_encoded=288.046 ms
#         received, delay_since_sent=81.674 ms, delay_since_encoded=369.72 ms
#     Packet Sent: type=video, seq=21959, send_delay_since_encoded=293.48 ms
#         received, delay_since_sent=81.703 ms, delay_since_encoded=375.183 ms
#     Packet Sent: type=video, seq=21960, send_delay_since_encoded=298.865 ms
#         received, delay_since_sent=81.673 ms, delay_since_encoded=380.538 ms
#     Packet Sent: type=video, seq=21961, send_delay_since_encoded=304.435 ms
#         received, delay_since_sent=81.642 ms, delay_since_encoded=386.077 ms
#     Packet Sent: type=video, seq=21962, send_delay_since_encoded=308.912 ms
#         received, delay_since_sent=81.77 ms, delay_since_encoded=390.682 ms
#     Packet Sent: type=video, seq=21963, send_delay_since_encoded=314.934 ms
#         received, delay_since_sent=81.623 ms, delay_since_encoded=396.557 ms
#     Packet Sent: type=video, seq=21964, send_delay_since_encoded=320.257 ms
#         received, delay_since_sent=81.627 ms, delay_since_encoded=401.884 ms
#     Packet Sent: type=video, seq=21965, send_delay_since_encoded=321.67 ms
#         received, delay_since_sent=81.656 ms, delay_since_encoded=403.326 ms
#     Packet Sent: type=video, seq=21966, send_delay_since_encoded=330.325 ms
#         received, delay_since_sent=81.705 ms, delay_since_encoded=412.03 ms
#     Packet Sent: type=video, seq=21967, send_delay_since_encoded=330.38 ms
#         received, delay_since_sent=82.048 ms, delay_since_encoded=412.428 ms
#     Packet Sent: type=video, seq=21968, send_delay_since_encoded=335.392 ms
#         received, delay_since_sent=81.712 ms, delay_since_encoded=417.104 ms
#     Packet Sent: type=video, seq=21969, send_delay_since_encoded=340.307 ms
#         received, delay_since_sent=81.69 ms, delay_since_encoded=421.997 ms
#     Packet Sent: type=video, seq=21970, send_delay_since_encoded=345.373 ms
#         received, delay_since_sent=81.646 ms, delay_since_encoded=427.019 ms
#     Packet Sent: type=video, seq=21971, send_delay_since_encoded=350.728 ms
#         received, delay_since_sent=81.63 ms, delay_since_encoded=432.358 ms
#     Packet Sent: type=video, seq=21972, send_delay_since_encoded=356.144 ms
#         received, delay_since_sent=81.619 ms, delay_since_encoded=437.763 ms
#     Packet Sent: type=video, seq=21973, send_delay_since_encoded=359.618 ms
#         received, delay_since_sent=81.609 ms, delay_since_encoded=441.227 ms
#     Packet Sent: type=video, seq=21974, send_delay_since_encoded=366.128 ms
#         received, delay_since_sent=81.814 ms, delay_since_encoded=447.942 ms
#     Packet Sent: type=video, seq=21975, send_delay_since_encoded=371.799 ms
#         received, delay_since_sent=81.829 ms, delay_since_encoded=453.628 ms
#     Packet Sent: type=video, seq=21976, send_delay_since_encoded=374.916 ms
#         received, delay_since_sent=81.762 ms, delay_since_encoded=456.678 ms
#     Packet Sent: type=video, seq=21977, send_delay_since_encoded=381.532 ms
#         received, delay_since_sent=81.674 ms, delay_since_encoded=463.206 ms
#     Packet Sent: type=video, seq=21978, send_delay_since_encoded=383.954 ms
#         received, delay_since_sent=81.664 ms, delay_since_encoded=465.618 ms
#     Packet Sent: type=video, seq=21979, send_delay_since_encoded=387.777 ms
#         received, delay_since_sent=81.569 ms, delay_since_encoded=469.346 ms
#     Packet Sent: type=fec, seq=5305, send_delay_since_encoded=398.812 ms
#         received, delay_since_sent=81.883 ms, delay_since_encoded=480.695 ms
#         protected seqs=[21951, 21952, 21953, 21954, 21955, 21956, 21957, 21958, 21959, 21960, 21961, 21962, 21963, 21964, 21965, 21966, 21967, 21968, 21969, 21970, 21971, 21972, 21973, 21974, 21975, 21976, 21977, 21978, 21979]
# num_media_packets=29, num_fec_packets=1
# encoding_delay = 34.735 ms, pacing delay = 387.777 ms
# received encoded frame
# picture_id=7615, refs=[7614]
# frame_network_delay=81.82 ms
# jitter_delay=0.488 ms
# decoding_delay=32.247 ms
# e2e_delay=537.067 ms
# --------------------------------
# Frame rtp_ts_capture = 2191844394
# rtp_ts=1651498566, frame_type=delta, frame_size=21834 bytes, packet_count=20
# all related packets sent:
#     Packet Sent: type=video, seq=21980, send_delay_since_encoded=365.189 ms
#         received, delay_since_sent=81.79 ms, delay_since_encoded=446.979 ms
#     Packet Sent: type=video, seq=21981, send_delay_since_encoded=376.029 ms
#         received, delay_since_sent=81.966 ms, delay_since_encoded=457.995 ms
#     Packet Sent: type=video, seq=21982, send_delay_since_encoded=380.445 ms
#         received, delay_since_sent=82.091 ms, delay_since_encoded=462.536 ms
#     Packet Sent: type=video, seq=21983, send_delay_since_encoded=385.852 ms
#         received, delay_since_sent=81.783 ms, delay_since_encoded=467.635 ms
#     Packet Sent: type=video, seq=21984, send_delay_since_encoded=391.358 ms
#         received, delay_since_sent=81.725 ms, delay_since_encoded=473.083 ms
#     Packet Sent: type=video, seq=21985, send_delay_since_encoded=396.79 ms
#         received, delay_since_sent=81.621 ms, delay_since_encoded=478.411 ms
#     Packet Sent: type=video, seq=21986, send_delay_since_encoded=402.156 ms
#         received, delay_since_sent=81.721 ms, delay_since_encoded=483.877 ms
#     Packet Sent: type=video, seq=21987, send_delay_since_encoded=404.314 ms
#         received, delay_since_sent=81.735 ms, delay_since_encoded=486.049 ms
#     Packet Sent: type=video, seq=21988, send_delay_since_encoded=412.464 ms
#         received, delay_since_sent=81.756 ms, delay_since_encoded=494.22 ms
#     Packet Sent: type=video, seq=21989, send_delay_since_encoded=412.528 ms
#         received, delay_since_sent=82.0 ms, delay_since_encoded=494.528 ms
#     Packet Sent: type=video, seq=21990, send_delay_since_encoded=418.071 ms
#         received, delay_since_sent=81.79 ms, delay_since_encoded=499.861 ms
#     Packet Sent: type=video, seq=21991, send_delay_since_encoded=423.21 ms
#         received, delay_since_sent=81.699 ms, delay_since_encoded=504.909 ms
#     Packet Sent: type=video, seq=21992, send_delay_since_encoded=427.628 ms
#         received, delay_since_sent=81.628 ms, delay_since_encoded=509.256 ms
#     Packet Sent: type=video, seq=21993, send_delay_since_encoded=433.225 ms
#         received, delay_since_sent=81.867 ms, delay_since_encoded=515.092 ms
#     Packet Sent: type=video, seq=21994, send_delay_since_encoded=437.576 ms
#         received, delay_since_sent=81.754 ms, delay_since_encoded=519.33 ms
#     Packet Sent: type=video, seq=21995, send_delay_since_encoded=443.15 ms
#         received, delay_since_sent=81.986 ms, delay_since_encoded=525.136 ms
#     Packet Sent: type=video, seq=21996, send_delay_since_encoded=447.689 ms
#         received, delay_since_sent=81.725 ms, delay_since_encoded=529.414 ms
#     Packet Sent: type=video, seq=21997, send_delay_since_encoded=450.292 ms
#         received, delay_since_sent=81.743 ms, delay_since_encoded=532.035 ms
#     Packet Sent: type=video, seq=21998, send_delay_since_encoded=455.34 ms
#         received, delay_since_sent=81.625 ms, delay_since_encoded=536.965 ms
#     Packet Sent: type=video, seq=21999, send_delay_since_encoded=463.112 ms
#         received, delay_since_sent=81.841 ms, delay_since_encoded=544.953 ms
#     Packet Sent: type=fec, seq=5306, send_delay_since_encoded=473.821 ms
#         received, delay_since_sent=81.881 ms, delay_since_encoded=555.702 ms
#         protected seqs=[21980, 21981, 21982, 21983, 21984, 21985, 21986, 21987, 21988, 21989, 21990, 21991, 21992, 21993, 21994, 21995, 21996, 21997, 21998, 21999]
# num_media_packets=20, num_fec_packets=1
# encoding_delay = 28.042 ms, pacing delay = 463.112 ms
# received encoded frame
# picture_id=7616, refs=[7615]
# frame_network_delay=82.042 ms
# jitter_delay=0.511 ms
# decoding_delay=27.352 ms
# e2e_delay=601.059 ms
# --------------------------------
# Frame rtp_ts_capture = 2191847454
# rtp_ts=1651501626, frame_type=delta, frame_size=10036 bytes, packet_count=10
# all related packets sent:
#     Packet Sent: type=video, seq=22000, send_delay_since_encoded=441.097 ms
#         received, delay_since_sent=81.744 ms, delay_since_encoded=522.841 ms
#     Packet Sent: type=video, seq=22001, send_delay_since_encoded=451.988 ms
#         received, delay_since_sent=81.895 ms, delay_since_encoded=533.883 ms
#     Packet Sent: type=video, seq=22002, send_delay_since_encoded=452.058 ms
#         received, delay_since_sent=82.166 ms, delay_since_encoded=534.224 ms
#     Packet Sent: type=video, seq=22003, send_delay_since_encoded=457.117 ms
#         received, delay_since_sent=81.847 ms, delay_since_encoded=538.964 ms
#     Packet Sent: type=video, seq=22004, send_delay_since_encoded=462.526 ms
#         received, delay_since_sent=81.787 ms, delay_since_encoded=544.313 ms
#     Packet Sent: type=video, seq=22005, send_delay_since_encoded=467.993 ms
#         received, delay_since_sent=81.644 ms, delay_since_encoded=549.637 ms
#     Packet Sent: type=video, seq=22006, send_delay_since_encoded=473.373 ms
#         received, delay_since_sent=81.702 ms, delay_since_encoded=555.075 ms
#     Packet Sent: type=video, seq=22007, send_delay_since_encoded=473.428 ms
#         received, delay_since_sent=102.602 ms, delay_since_encoded=576.03 ms (recovered by RTX/FEC)
#     Packet Sent: type=video, seq=22008, send_delay_since_encoded=478.269 ms
#         received, delay_since_sent=81.724 ms, delay_since_encoded=559.993 ms
#     Packet Sent: type=video, seq=22009, send_delay_since_encoded=483.829 ms
#         received, delay_since_sent=81.674 ms, delay_since_encoded=565.503 ms
#     Packet Sent: type=fec, seq=5307, send_delay_since_encoded=493.795 ms
#         received, delay_since_sent=81.693 ms, delay_since_encoded=575.488 ms
#         protected seqs=[22000, 22001, 22002, 22003, 22004, 22005, 22006, 22007, 22008, 22009]
#     Packet Sent: type=rtx, seq=14301, send_delay_since_encoded=585.33 ms
#         received, delay_since_sent=81.867 ms, delay_since_encoded=667.197 ms
#         original seq=22007
# num_media_packets=10, num_fec_packets=1
# encoding_delay = 23.777 ms, pacing delay = 483.829 ms
# received encoded frame
# picture_id=7617, refs=[7616]
# frame_network_delay=92.331 ms
# jitter_delay=0.327 ms
# decoding_delay=23.784 ms
# e2e_delay=624.048 ms
# --------------------------------
# Frame rtp_ts_capture = 2191850424
# rtp_ts=1651504596, frame_type=delta, frame_size=6321 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=22010, send_delay_since_encoded=458.327 ms
#         received, delay_since_sent=81.696 ms, delay_since_encoded=540.023 ms
#     Packet Sent: type=video, seq=22011, send_delay_since_encoded=468.861 ms
#         received, delay_since_sent=81.855 ms, delay_since_encoded=550.716 ms
#     Packet Sent: type=video, seq=22012, send_delay_since_encoded=473.349 ms
#         received, delay_since_sent=81.812 ms, delay_since_encoded=555.161 ms
#     Packet Sent: type=video, seq=22013, send_delay_since_encoded=474.787 ms
#         received, delay_since_sent=81.721 ms, delay_since_encoded=556.508 ms
#     Packet Sent: type=video, seq=22014, send_delay_since_encoded=480.102 ms
#         received, delay_since_sent=81.826 ms, delay_since_encoded=561.928 ms
#     Packet Sent: type=video, seq=22015, send_delay_since_encoded=485.709 ms
#         received, delay_since_sent=92.531 ms, delay_since_encoded=578.24 ms (recovered by RTX/FEC)
#     Packet Sent: type=fec, seq=5308, send_delay_since_encoded=496.007 ms
#         received, delay_since_sent=81.686 ms, delay_since_encoded=577.693 ms
#         protected seqs=[22010, 22011, 22012, 22013, 22014, 22015]
# num_media_packets=6, num_fec_packets=1
# encoding_delay = 20.706 ms, pacing delay = 485.709 ms
# received encoded frame
# picture_id=7618, refs=[7617]
# frame_network_delay=92.64 ms
# jitter_delay=0.386 ms
# decoding_delay=21.651 ms
# e2e_delay=621.092 ms
# --------------------------------
# Frame rtp_ts_capture = 2191853394
# rtp_ts=1651507566, frame_type=delta, frame_size=5256 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=22016, send_delay_since_encoded=467.446 ms
#         received, delay_since_sent=81.863 ms, delay_since_encoded=549.309 ms
#     Packet Sent: type=video, seq=22017, send_delay_since_encoded=473.544 ms
#         received, delay_since_sent=81.661 ms, delay_since_encoded=555.205 ms
#     Packet Sent: type=video, seq=22018, send_delay_since_encoded=482.77 ms
#         received, delay_since_sent=81.991 ms, delay_since_encoded=564.761 ms
#     Packet Sent: type=video, seq=22019, send_delay_since_encoded=482.827 ms
#         received, delay_since_sent=82.305 ms, delay_since_encoded=565.132 ms
#     Packet Sent: type=video, seq=22020, send_delay_since_encoded=488.162 ms
#         received, delay_since_sent=81.827 ms, delay_since_encoded=569.989 ms
#     Packet Sent: type=fec, seq=5309, send_delay_since_encoded=498.381 ms
#         received, delay_since_sent=81.939 ms, delay_since_encoded=580.32 ms
#         protected seqs=[22016, 22017, 22018, 22019, 22020]
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 11.236 ms, pacing delay = 488.162 ms
# received encoded frame
# picture_id=7619, refs=[7618]
# frame_network_delay=81.961 ms
# jitter_delay=6.768 ms
# decoding_delay=14.878 ms
# e2e_delay=603.005 ms
# --------------------------------
# Frame rtp_ts_capture = 2191856454
# rtp_ts=1651510626, frame_type=delta, frame_size=4936 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=22021, send_delay_since_encoded=459.077 ms
#         received, delay_since_sent=81.856 ms, delay_since_encoded=540.933 ms
#     Packet Sent: type=video, seq=22022, send_delay_since_encoded=468.123 ms
#         received, delay_since_sent=81.823 ms, delay_since_encoded=549.946 ms
#     Packet Sent: type=video, seq=22023, send_delay_since_encoded=470.466 ms
#         received, delay_since_sent=81.909 ms, delay_since_encoded=552.375 ms
#     Packet Sent: type=video, seq=22024, send_delay_since_encoded=475.752 ms
#         received, delay_since_sent=81.919 ms, delay_since_encoded=557.671 ms
#     Packet Sent: type=video, seq=22025, send_delay_since_encoded=481.084 ms
#         received, delay_since_sent=81.856 ms, delay_since_encoded=562.94 ms
#     Packet Sent: type=fec, seq=5310, send_delay_since_encoded=488.879 ms
#         received, delay_since_sent=82.014 ms, delay_since_encoded=570.893 ms
#         protected seqs=[22021, 22022, 22023, 22024, 22025]
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 12.588 ms, pacing delay = 481.084 ms
# received encoded frame
# picture_id=7620, refs=[7619]
# frame_network_delay=81.953 ms
# jitter_delay=0.531 ms
# decoding_delay=15.695 ms
# e2e_delay=591.851 ms
# --------------------------------
# Frame rtp_ts_capture = 2191859424
# rtp_ts=1651513596, frame_type=delta, frame_size=5760 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=22026, send_delay_since_encoded=453.793 ms
#         received, delay_since_sent=81.773 ms, delay_since_encoded=535.566 ms
#     Packet Sent: type=video, seq=22027, send_delay_since_encoded=463.832 ms
#         received, delay_since_sent=81.988 ms, delay_since_encoded=545.82 ms
#     Packet Sent: type=video, seq=22028, send_delay_since_encoded=469.077 ms
#         received, delay_since_sent=81.744 ms, delay_since_encoded=550.821 ms
#     Packet Sent: type=video, seq=22029, send_delay_since_encoded=474.601 ms
#         received, delay_since_sent=81.65 ms, delay_since_encoded=556.251 ms
#     Packet Sent: type=video, seq=22030, send_delay_since_encoded=480.139 ms
#         received, delay_since_sent=81.806 ms, delay_since_encoded=561.945 ms
#     Packet Sent: type=video, seq=22031, send_delay_since_encoded=481.597 ms
#         received, delay_since_sent=81.753 ms, delay_since_encoded=563.35 ms
#     Packet Sent: type=fec, seq=5311, send_delay_since_encoded=490.366 ms
#         received, delay_since_sent=81.947 ms, delay_since_encoded=572.313 ms
#         protected seqs=[22026, 22027, 22028, 22029, 22030, 22031]
# num_media_packets=6, num_fec_packets=1
# encoding_delay = 11.988 ms, pacing delay = 481.597 ms
# received encoded frame
# picture_id=7621, refs=[7620]
# frame_network_delay=81.855 ms
# jitter_delay=0.573 ms
# decoding_delay=15.457 ms
# e2e_delay=591.47 ms
# --------------------------------
# Frame rtp_ts_capture = 2191862394
# rtp_ts=1651516566, frame_type=delta, frame_size=5218 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=22032, send_delay_since_encoded=452.766 ms
#         received, delay_since_sent=81.73 ms, delay_since_encoded=534.496 ms
#     Packet Sent: type=video, seq=22033, send_delay_since_encoded=463.868 ms
#         received, delay_since_sent=81.876 ms, delay_since_encoded=545.744 ms
#     Packet Sent: type=video, seq=22034, send_delay_since_encoded=467.504 ms
#         received, delay_since_sent=81.648 ms, delay_since_encoded=549.152 ms
#     Packet Sent: type=video, seq=22035, send_delay_since_encoded=474.113 ms
#         received, delay_since_sent=197.189 ms, delay_since_encoded=671.302 ms (recovered by RTX/FEC)
#     Packet Sent: type=video, seq=22036, send_delay_since_encoded=475.226 ms
#         received, delay_since_sent=201.473 ms, delay_since_encoded=676.699 ms (recovered by RTX/FEC)
#     Packet Sent: type=fec, seq=5312, send_delay_since_encoded=489.234 ms
#         received, delay_since_sent=81.636 ms, delay_since_encoded=570.87 ms
#         protected seqs=[22032, 22033, 22034, 22035, 22036]
#     Packet Sent: type=rtx, seq=14302, send_delay_since_encoded=589.563 ms
#         received, delay_since_sent=81.7 ms, delay_since_encoded=671.263 ms
#         original seq=22035
#     Packet Sent: type=rtx, seq=14303, send_delay_since_encoded=594.859 ms
#         received, delay_since_sent=81.804 ms, delay_since_encoded=676.663 ms
#         original seq=22036
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 10.823 ms, pacing delay = 475.226 ms
# received encoded frame
# picture_id=7622, refs=[7621]
# frame_network_delay=201.59 ms
# jitter_delay=0.276 ms
# decoding_delay=13.254 ms
# e2e_delay=701.169 ms
# --------------------------------
# Frame rtp_ts_capture = 2191865454
# rtp_ts=1651519626, frame_type=delta, frame_size=5268 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=22037, send_delay_since_encoded=450.21 ms
#         received, delay_since_sent=81.631 ms, delay_since_encoded=531.841 ms
#     Packet Sent: type=video, seq=22038, send_delay_since_encoded=455.622 ms
#         received, delay_since_sent=81.903 ms, delay_since_encoded=537.525 ms
#     Packet Sent: type=video, seq=22039, send_delay_since_encoded=460.968 ms
#         received, delay_since_sent=81.618 ms, delay_since_encoded=542.586 ms
#     Packet Sent: type=video, seq=22040, send_delay_since_encoded=466.598 ms
#         received, delay_since_sent=81.635 ms, delay_since_encoded=548.233 ms
#     Packet Sent: type=video, seq=22041, send_delay_since_encoded=472.004 ms
#         received, delay_since_sent=81.753 ms, delay_since_encoded=553.757 ms
#     Packet Sent: type=fec, seq=5313, send_delay_since_encoded=482.602 ms
#         received, delay_since_sent=81.757 ms, delay_since_encoded=564.359 ms
#         protected seqs=[22037, 22038, 22039, 22040, 22041]
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 11.203 ms, pacing delay = 472.004 ms
# received encoded frame
# picture_id=7623, refs=[7622]
# frame_network_delay=81.875 ms
# jitter_delay=103.16 ms
# decoding_delay=13.716 ms
# e2e_delay=681.958 ms
# --------------------------------
# Frame rtp_ts_capture = 2191868424
# rtp_ts=1651522596, frame_type=delta, frame_size=12466 bytes, packet_count=12
# all related packets sent:
#     Packet Sent: type=video, seq=22042, send_delay_since_encoded=443.859 ms
#         received, delay_since_sent=81.734 ms, delay_since_encoded=525.593 ms
#     Packet Sent: type=video, seq=22043, send_delay_since_encoded=449.161 ms
#         received, delay_since_sent=82.087 ms, delay_since_encoded=531.248 ms
#     Packet Sent: type=video, seq=22044, send_delay_since_encoded=454.507 ms
#         received, delay_since_sent=81.661 ms, delay_since_encoded=536.168 ms
#     Packet Sent: type=video, seq=22045, send_delay_since_encoded=457.882 ms
#         received, delay_since_sent=81.725 ms, delay_since_encoded=539.607 ms
#     Packet Sent: type=video, seq=22046, send_delay_since_encoded=464.732 ms
#         received, delay_since_sent=81.931 ms, delay_since_encoded=546.663 ms
#     Packet Sent: type=video, seq=22047, send_delay_since_encoded=468.183 ms
#         received, delay_since_sent=81.597 ms, delay_since_encoded=549.78 ms
#     Packet Sent: type=video, seq=22048, send_delay_since_encoded=474.968 ms
#         received, delay_since_sent=81.64 ms, delay_since_encoded=556.608 ms
#     Packet Sent: type=video, seq=22049, send_delay_since_encoded=479.778 ms
#         received, delay_since_sent=81.717 ms, delay_since_encoded=561.495 ms
#     Packet Sent: type=video, seq=22050, send_delay_since_encoded=481.352 ms
#         received, delay_since_sent=81.605 ms, delay_since_encoded=562.957 ms
#     Packet Sent: type=video, seq=22051, send_delay_since_encoded=484.846 ms
#         received, delay_since_sent=81.725 ms, delay_since_encoded=566.571 ms
#     Packet Sent: type=video, seq=22052, send_delay_since_encoded=490.269 ms
#         received, delay_since_sent=81.766 ms, delay_since_encoded=572.035 ms
#     Packet Sent: type=video, seq=22053, send_delay_since_encoded=495.881 ms
#         received, delay_since_sent=81.84 ms, delay_since_encoded=577.721 ms
#     Packet Sent: type=fec, seq=5314, send_delay_since_encoded=506.072 ms
#         received, delay_since_sent=81.919 ms, delay_since_encoded=587.991 ms
#         protected seqs=[22042, 22043, 22044, 22045, 22046, 22047, 22048, 22049, 22050, 22051, 22052, 22053]
# num_media_packets=12, num_fec_packets=1
# encoding_delay = 11.324 ms, pacing delay = 495.881 ms
# received encoded frame
# picture_id=7624, refs=[7623]
# frame_network_delay=82.03 ms
# jitter_delay=59.739 ms
# decoding_delay=14.557 ms
# e2e_delay=663.531 ms
# --------------------------------
# Frame rtp_ts_capture = 2191871394
# rtp_ts=1651525566, frame_type=delta, frame_size=9588 bytes, packet_count=9
# all related packets sent:
#     Packet Sent: type=video, seq=22054, send_delay_since_encoded=467.572 ms
#         received, delay_since_sent=81.904 ms, delay_since_encoded=549.476 ms
#     Packet Sent: type=video, seq=22055, send_delay_since_encoded=474.848 ms
#         received, delay_since_sent=81.771 ms, delay_since_encoded=556.619 ms
#     Packet Sent: type=video, seq=22056, send_delay_since_encoded=479.292 ms
#         received, delay_since_sent=81.788 ms, delay_since_encoded=561.08 ms
#     Packet Sent: type=video, seq=22057, send_delay_since_encoded=484.586 ms
#         received, delay_since_sent=81.622 ms, delay_since_encoded=566.208 ms
#     Packet Sent: type=video, seq=22058, send_delay_since_encoded=498.35 ms
#         received, delay_since_sent=81.811 ms, delay_since_encoded=580.161 ms
#     Packet Sent: type=video, seq=22059, send_delay_since_encoded=502.384 ms
#         received, delay_since_sent=81.74 ms, delay_since_encoded=584.124 ms
#     Packet Sent: type=video, seq=22060, send_delay_since_encoded=509.551 ms
#         received, delay_since_sent=81.726 ms, delay_since_encoded=591.277 ms
#     Packet Sent: type=video, seq=22061, send_delay_since_encoded=514.968 ms
#         received, delay_since_sent=81.752 ms, delay_since_encoded=596.72 ms
#     Packet Sent: type=video, seq=22062, send_delay_since_encoded=519.328 ms
#         received, delay_since_sent=81.618 ms, delay_since_encoded=600.946 ms
#     Packet Sent: type=fec, seq=5315, send_delay_since_encoded=524.693 ms
#         received, delay_since_sent=82.024 ms, delay_since_encoded=606.717 ms
#         protected seqs=[22054, 22055, 22056, 22057, 22058, 22059, 22060, 22061, 22062]
# num_media_packets=9, num_fec_packets=1
# encoding_delay = 10.873 ms, pacing delay = 519.328 ms
# received encoded frame
# picture_id=7625, refs=[7624]
# frame_network_delay=81.738 ms
# jitter_delay=18.618 ms
# decoding_delay=14.812 ms
# e2e_delay=645.369 ms
# --------------------------------
# Frame rtp_ts_capture = 2191874454
# rtp_ts=1651528626, frame_type=delta, frame_size=7726 bytes, packet_count=7
# all related packets sent:
#     Packet Sent: type=video, seq=22063, send_delay_since_encoded=493.125 ms
#         received, delay_since_sent=81.579 ms, delay_since_encoded=574.704 ms
#     Packet Sent: type=video, seq=22064, send_delay_since_encoded=498.007 ms
#         received, delay_since_sent=81.586 ms, delay_since_encoded=579.593 ms
#     Packet Sent: type=video, seq=22065, send_delay_since_encoded=503.292 ms
#         received, delay_since_sent=81.626 ms, delay_since_encoded=584.918 ms
#     Packet Sent: type=video, seq=22066, send_delay_since_encoded=508.384 ms
#         received, delay_since_sent=81.584 ms, delay_since_encoded=589.968 ms
#     Packet Sent: type=video, seq=22067, send_delay_since_encoded=513.619 ms
#         received, delay_since_sent=102.611 ms, delay_since_encoded=616.23 ms (recovered by RTX/FEC)
#     Packet Sent: type=video, seq=22068, send_delay_since_encoded=516.867 ms
#         received, delay_since_sent=81.58 ms, delay_since_encoded=598.447 ms
#     Packet Sent: type=video, seq=22069, send_delay_since_encoded=524.223 ms
#         received, delay_since_sent=81.711 ms, delay_since_encoded=605.934 ms
#     Packet Sent: type=fec, seq=5316, send_delay_since_encoded=533.851 ms
#         received, delay_since_sent=81.694 ms, delay_since_encoded=615.545 ms
#         protected seqs=[22063, 22064, 22065, 22066, 22067, 22068, 22069]
#     Packet Sent: type=rtx, seq=14304, send_delay_since_encoded=620.452 ms
#         received, delay_since_sent=81.55 ms, delay_since_encoded=702.002 ms
#         original seq=22067
# num_media_packets=7, num_fec_packets=1
# encoding_delay = 9.067 ms, pacing delay = 524.223 ms
# received encoded frame
# picture_id=7626, refs=[7625]
# frame_network_delay=92.118 ms
# jitter_delay=0.283 ms
# decoding_delay=13.899 ms
# e2e_delay=639.59 ms
# --------------------------------
# Frame rtp_ts_capture = 2191877424
# rtp_ts=1651531596, frame_type=delta, frame_size=3794 bytes, packet_count=4
# all related packets sent:
#     Packet Sent: type=video, seq=22070, send_delay_since_encoded=495.835 ms
#         received, delay_since_sent=81.741 ms, delay_since_encoded=577.576 ms
#     Packet Sent: type=video, seq=22071, send_delay_since_encoded=505.445 ms
#         received, delay_since_sent=81.96 ms, delay_since_encoded=587.405 ms
#     Packet Sent: type=video, seq=22072, send_delay_since_encoded=505.493 ms
#         received, delay_since_sent=82.352 ms, delay_since_encoded=587.845 ms
#     Packet Sent: type=video, seq=22073, send_delay_since_encoded=509.897 ms
#         received, delay_since_sent=81.674 ms, delay_since_encoded=591.571 ms
#     Packet Sent: type=fec, seq=5317, send_delay_since_encoded=520.529 ms
#         received, delay_since_sent=81.769 ms, delay_since_encoded=602.298 ms
#         protected seqs=[22070, 22071, 22072, 22073]
# num_media_packets=4, num_fec_packets=1
# encoding_delay = 9.415 ms, pacing delay = 509.897 ms
# received encoded frame
# picture_id=7627, refs=[7626]
# frame_network_delay=81.767 ms
# jitter_delay=6.038 ms
# decoding_delay=12.156 ms
# e2e_delay=619.273 ms
# --------------------------------
# Frame rtp_ts_capture = 2191880394
# rtp_ts=1651534566, frame_type=delta, frame_size=2168 bytes, packet_count=2
# all related packets sent:
#     Packet Sent: type=video, seq=22074, send_delay_since_encoded=481.343 ms
#         received, delay_since_sent=81.78 ms, delay_since_encoded=563.123 ms
#     Packet Sent: type=video, seq=22075, send_delay_since_encoded=491.931 ms
#         received, delay_since_sent=81.805 ms, delay_since_encoded=573.736 ms
#     Packet Sent: type=fec, seq=5318, send_delay_since_encoded=499.504 ms
#         received, delay_since_sent=81.884 ms, delay_since_encoded=581.388 ms
#         protected seqs=[22074, 22075]
# num_media_packets=2, num_fec_packets=1
# encoding_delay = 9.854 ms, pacing delay = 491.931 ms
# received encoded frame
# picture_id=7628, refs=[7627]
# frame_network_delay=81.89 ms
# jitter_delay=2.484 ms
# decoding_delay=11.548 ms
# e2e_delay=597.707 ms
# --------------------------------
# Frame rtp_ts_capture = 2191883454
# rtp_ts=1651537626, frame_type=delta, frame_size=6300 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=22076, send_delay_since_encoded=457.716 ms
#         received, delay_since_sent=81.759 ms, delay_since_encoded=539.475 ms
#     Packet Sent: type=video, seq=22077, send_delay_since_encoded=468.299 ms
#         received, delay_since_sent=81.841 ms, delay_since_encoded=550.14 ms
#     Packet Sent: type=video, seq=22078, send_delay_since_encoded=468.363 ms
#         received, delay_since_sent=82.244 ms, delay_since_encoded=550.607 ms
#     Packet Sent: type=video, seq=22079, send_delay_since_encoded=473.193 ms
#         received, delay_since_sent=81.63 ms, delay_since_encoded=554.823 ms
#     Packet Sent: type=video, seq=22080, send_delay_since_encoded=478.426 ms
#         received, delay_since_sent=81.636 ms, delay_since_encoded=560.062 ms
#     Packet Sent: type=video, seq=22081, send_delay_since_encoded=483.712 ms
#         received, delay_since_sent=89.418 ms, delay_since_encoded=573.13 ms (recovered by RTX/FEC)
#     Packet Sent: type=fec, seq=5319, send_delay_since_encoded=490.893 ms
#         received, delay_since_sent=81.541 ms, delay_since_encoded=572.434 ms
#         protected seqs=[22076, 22077, 22078, 22079, 22080, 22081]
#     Packet Sent: type=rtx, seq=14305, send_delay_since_encoded=592.781 ms
#         received, delay_since_sent=81.499 ms, delay_since_encoded=674.28 ms
#         original seq=22081
# num_media_packets=6, num_fec_packets=1
# encoding_delay = 15.143 ms, pacing delay = 483.712 ms
# received encoded frame
# picture_id=7629, refs=[7628]
# frame_network_delay=89.525 ms
# jitter_delay=0.255 ms
# decoding_delay=14.277 ms
# e2e_delay=602.912 ms
# --------------------------------
# Frame rtp_ts_capture = 2191886424
# rtp_ts=1651540596, frame_type=delta, frame_size=5374 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=22082, send_delay_since_encoded=455.66 ms
#         received, delay_since_sent=81.674 ms, delay_since_encoded=537.334 ms
#     Packet Sent: type=video, seq=22083, send_delay_since_encoded=467.483 ms
#         received, delay_since_sent=81.735 ms, delay_since_encoded=549.218 ms
#     Packet Sent: type=video, seq=22084, send_delay_since_encoded=472.506 ms
#         received, delay_since_sent=81.846 ms, delay_since_encoded=554.352 ms
#     Packet Sent: type=video, seq=22085, send_delay_since_encoded=477.652 ms
#         received, delay_since_sent=81.609 ms, delay_since_encoded=559.261 ms
#     Packet Sent: type=video, seq=22086, send_delay_since_encoded=477.738 ms
#         received, delay_since_sent=81.995 ms, delay_since_encoded=559.733 ms
#     Packet Sent: type=fec, seq=5320, send_delay_since_encoded=493.762 ms
#         received, delay_since_sent=81.681 ms, delay_since_encoded=575.443 ms
#         protected seqs=[22082, 22083, 22084, 22085, 22086]
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 13.071 ms, pacing delay = 477.738 ms
# received encoded frame
# picture_id=7630, refs=[7629]
# frame_network_delay=82.091 ms
# jitter_delay=0.577 ms
# decoding_delay=14.237 ms
# e2e_delay=587.714 ms
# --------------------------------
# Frame rtp_ts_capture = 2191889394
# rtp_ts=1651543566, frame_type=delta, frame_size=6436 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=22087, send_delay_since_encoded=453.955 ms
#         received, delay_since_sent=81.726 ms, delay_since_encoded=535.681 ms
#     Packet Sent: type=video, seq=22088, send_delay_since_encoded=464.807 ms
#         received, delay_since_sent=81.687 ms, delay_since_encoded=546.494 ms
#     Packet Sent: type=video, seq=22089, send_delay_since_encoded=470.135 ms
#         received, delay_since_sent=81.713 ms, delay_since_encoded=551.848 ms
#     Packet Sent: type=video, seq=22090, send_delay_since_encoded=475.635 ms
#         received, delay_since_sent=81.684 ms, delay_since_encoded=557.319 ms
#     Packet Sent: type=video, seq=22091, send_delay_since_encoded=475.689 ms
#         received, delay_since_sent=82.082 ms, delay_since_encoded=557.771 ms
#     Packet Sent: type=video, seq=22092, send_delay_since_encoded=481.031 ms
#         received, delay_since_sent=81.596 ms, delay_since_encoded=562.627 ms
#     Packet Sent: type=fec, seq=5321, send_delay_since_encoded=491.796 ms
#         received, delay_since_sent=82.053 ms, delay_since_encoded=573.849 ms
#         protected seqs=[22087, 22088, 22089, 22090, 22091, 22092]
# num_media_packets=6, num_fec_packets=1
# encoding_delay = 14.033 ms, pacing delay = 481.031 ms
# received encoded frame
# picture_id=7631, refs=[7630]
# frame_network_delay=81.699 ms
# jitter_delay=0.612 ms
# decoding_delay=15.822 ms
# e2e_delay=593.197 ms
# --------------------------------
# Frame rtp_ts_capture = 2191892454
# rtp_ts=1651546626, frame_type=delta, frame_size=5938 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=22093, send_delay_since_encoded=454.165 ms
#         received, delay_since_sent=81.657 ms, delay_since_encoded=535.822 ms
#     Packet Sent: type=video, seq=22094, send_delay_since_encoded=464.25 ms
#         received, delay_since_sent=81.643 ms, delay_since_encoded=545.893 ms
#     Packet Sent: type=video, seq=22095, send_delay_since_encoded=465.46 ms
#         received, delay_since_sent=81.552 ms, delay_since_encoded=547.012 ms
#     Packet Sent: type=video, seq=22096, send_delay_since_encoded=469.69 ms
#         received, delay_since_sent=81.753 ms, delay_since_encoded=551.443 ms
#     Packet Sent: type=video, seq=22097, send_delay_since_encoded=474.947 ms
#         received, delay_since_sent=96.075 ms, delay_since_encoded=571.022 ms (recovered by RTX/FEC)
#     Packet Sent: type=video, seq=22098, send_delay_since_encoded=480.206 ms
# ...
#     Packet Sent: type=video, seq=29103, send_delay_since_encoded=5.738 ms
#         received, delay_since_sent=81.711 ms, delay_since_encoded=87.449 ms
#     Packet Sent: type=video, seq=29104, send_delay_since_encoded=5.797 ms
#         received, delay_since_sent=82.221 ms, delay_since_encoded=88.018 ms
#     Packet Sent: type=video, seq=29105, send_delay_since_encoded=11.161 ms
#         received, delay_since_sent=82.308 ms, delay_since_encoded=93.469 ms
#     Packet Sent: type=video, seq=29106, send_delay_since_encoded=11.27 ms
#         received, delay_since_sent=82.77 ms, delay_since_encoded=94.04 ms
#     Packet Sent: type=fec, seq=9067, send_delay_since_encoded=16.625 ms
#         received, delay_since_sent=82.068 ms, delay_since_encoded=98.693 ms
#         protected seqs=[29100, 29101, 29103]
#     Packet Sent: type=fec, seq=9068, send_delay_since_encoded=21.985 ms
#         received, delay_since_sent=81.793 ms, delay_since_encoded=103.778 ms
#         protected seqs=[29100, 29102, 29104, 29106]
#     Packet Sent: type=fec, seq=9069, send_delay_since_encoded=22.034 ms
#         received, delay_since_sent=82.158 ms, delay_since_encoded=104.192 ms
#         protected seqs=[29101, 29102, 29105]
#     Packet Sent: type=fec, seq=9070, send_delay_since_encoded=23.385 ms
#         NOT received
# num_media_packets=7, num_fec_packets=4
# encoding_delay = 12.448 ms, pacing delay = 11.27 ms
# received encoded frame
# picture_id=8754, refs=[8753]
# frame_network_delay=82.867 ms
# jitter_delay=0.731 ms
# decoding_delay=16.038 ms
# e2e_delay=123.354 ms
# --------------------------------
# Frame rtp_ts_capture = 2195726364
# rtp_ts=1655380536, frame_type=delta, frame_size=9078 bytes, packet_count=9
# all related packets sent:
#     Packet Sent: type=video, seq=29107, send_delay_since_encoded=0.232 ms
#         received, delay_since_sent=82.343 ms, delay_since_encoded=82.575 ms
#     Packet Sent: type=video, seq=29108, send_delay_since_encoded=5.649 ms
#         received, delay_since_sent=82.139 ms, delay_since_encoded=87.788 ms
#     Packet Sent: type=video, seq=29109, send_delay_since_encoded=5.705 ms
#         received, delay_since_sent=82.663 ms, delay_since_encoded=88.368 ms
#     Packet Sent: type=video, seq=29110, send_delay_since_encoded=11.066 ms
#         received, delay_since_sent=81.829 ms, delay_since_encoded=92.895 ms
#     Packet Sent: type=video, seq=29111, send_delay_since_encoded=11.128 ms
#         received, delay_since_sent=82.336 ms, delay_since_encoded=93.464 ms
#     Packet Sent: type=video, seq=29112, send_delay_since_encoded=16.457 ms
#         received, delay_since_sent=82.126 ms, delay_since_encoded=98.583 ms
#     Packet Sent: type=video, seq=29113, send_delay_since_encoded=16.513 ms
#         received, delay_since_sent=82.665 ms, delay_since_encoded=99.178 ms
#     Packet Sent: type=video, seq=29114, send_delay_since_encoded=21.867 ms
#         received, delay_since_sent=82.042 ms, delay_since_encoded=103.909 ms
#     Packet Sent: type=video, seq=29115, send_delay_since_encoded=21.993 ms
#         received, delay_since_sent=82.519 ms, delay_since_encoded=104.512 ms
#     Packet Sent: type=fec, seq=9071, send_delay_since_encoded=27.414 ms
#         received, delay_since_sent=82.251 ms, delay_since_encoded=109.665 ms
#         protected seqs=[29107, 29111, 29112]
#     Packet Sent: type=fec, seq=9072, send_delay_since_encoded=27.454 ms
#         received, delay_since_sent=82.659 ms, delay_since_encoded=110.113 ms
#         protected seqs=[29109, 29112, 29114]
#     Packet Sent: type=fec, seq=9073, send_delay_since_encoded=31.507 ms
#         received, delay_since_sent=81.856 ms, delay_since_encoded=113.363 ms
#         protected seqs=[29107, 29110, 29113, 29115]
#     Packet Sent: type=fec, seq=9074, send_delay_since_encoded=36.373 ms
#         received, delay_since_sent=81.753 ms, delay_since_encoded=118.126 ms
#         protected seqs=[29108, 29114, 29115]
#     Packet Sent: type=fec, seq=9075, send_delay_since_encoded=42.223 ms
#         received, delay_since_sent=82.442 ms, delay_since_encoded=124.665 ms
#         protected seqs=[29108, 29110, 29111]
# num_media_packets=9, num_fec_packets=5
# encoding_delay = 10.881 ms, pacing delay = 21.993 ms
# received encoded frame
# picture_id=8755, refs=[8754]
# frame_network_delay=82.636 ms
# jitter_delay=0.718 ms
# decoding_delay=13.602 ms
# e2e_delay=129.83 ms
# --------------------------------
# Frame rtp_ts_capture = 2195729424
# rtp_ts=1655383596, frame_type=delta, frame_size=10524 bytes, packet_count=10
# all related packets sent:
#     Packet Sent: type=video, seq=29116, send_delay_since_encoded=1.633 ms
#         received, delay_since_sent=81.818 ms, delay_since_encoded=83.451 ms
#     Packet Sent: type=video, seq=29117, send_delay_since_encoded=10.889 ms
#         received, delay_since_sent=81.851 ms, delay_since_encoded=92.74 ms
#     Packet Sent: type=video, seq=29118, send_delay_since_encoded=16.17 ms
#         received, delay_since_sent=81.834 ms, delay_since_encoded=98.004 ms
#     Packet Sent: type=video, seq=29119, send_delay_since_encoded=16.226 ms
#         received, delay_since_sent=82.375 ms, delay_since_encoded=98.601 ms
#     Packet Sent: type=video, seq=29120, send_delay_since_encoded=21.736 ms
#         received, delay_since_sent=81.782 ms, delay_since_encoded=103.518 ms
#     Packet Sent: type=video, seq=29121, send_delay_since_encoded=21.792 ms
#         received, delay_since_sent=82.288 ms, delay_since_encoded=104.08 ms
#     Packet Sent: type=video, seq=29122, send_delay_since_encoded=27.197 ms
#         received, delay_since_sent=81.746 ms, delay_since_encoded=108.943 ms
#     Packet Sent: type=video, seq=29123, send_delay_since_encoded=27.254 ms
#         received, delay_since_sent=82.266 ms, delay_since_encoded=109.52 ms
#     Packet Sent: type=video, seq=29124, send_delay_since_encoded=32.559 ms
#         received, delay_since_sent=81.782 ms, delay_since_encoded=114.341 ms
#     Packet Sent: type=video, seq=29125, send_delay_since_encoded=32.692 ms
#         received, delay_since_sent=82.215 ms, delay_since_encoded=114.907 ms
#     Packet Sent: type=fec, seq=9076, send_delay_since_encoded=36.033 ms
#         received, delay_since_sent=81.853 ms, delay_since_encoded=117.886 ms
#         protected seqs=[29116, 29117, 29120, 29122]
#     Packet Sent: type=fec, seq=9077, send_delay_since_encoded=42.374 ms
#         received, delay_since_sent=82.575 ms, delay_since_encoded=124.949 ms
#         protected seqs=[29118, 29119, 29122, 29124]
#     Packet Sent: type=fec, seq=9078, send_delay_since_encoded=47.665 ms
#         received, delay_since_sent=82.555 ms, delay_since_encoded=130.22 ms
#         protected seqs=[29116, 29118, 29123, 29125]
#     Packet Sent: type=fec, seq=9079, send_delay_since_encoded=52.968 ms
#         received, delay_since_sent=82.485 ms, delay_since_encoded=135.453 ms
#         protected seqs=[29117, 29119, 29121, 29123]
#     Packet Sent: type=fec, seq=9080, send_delay_since_encoded=58.544 ms
#         received, delay_since_sent=81.835 ms, delay_since_encoded=140.379 ms
#         protected seqs=[29120, 29124, 29125]
# num_media_packets=10, num_fec_packets=5
# encoding_delay = 8.766 ms, pacing delay = 32.692 ms
# received encoded frame
# picture_id=8756, refs=[8755]
# frame_network_delay=82.337 ms
# jitter_delay=0.756 ms
# decoding_delay=15.369 ms
# e2e_delay=139.92 ms
# --------------------------------
# Frame rtp_ts_capture = 2195732394
# rtp_ts=1655386566, frame_type=delta, frame_size=8035 bytes, packet_count=8
# all related packets sent:
#     Packet Sent: type=video, seq=29126, send_delay_since_encoded=8.83 ms
#         received, delay_since_sent=82.023 ms, delay_since_encoded=90.853 ms
#     Packet Sent: type=video, seq=29127, send_delay_since_encoded=14.153 ms
#         received, delay_since_sent=81.986 ms, delay_since_encoded=96.139 ms
#     Packet Sent: type=video, seq=29128, send_delay_since_encoded=19.459 ms
#         received, delay_since_sent=81.893 ms, delay_since_encoded=101.352 ms
#     Packet Sent: type=video, seq=29129, send_delay_since_encoded=21.69 ms
#         received, delay_since_sent=81.863 ms, delay_since_encoded=103.553 ms
#     Packet Sent: type=video, seq=29130, send_delay_since_encoded=30.577 ms
#         received, delay_since_sent=81.809 ms, delay_since_encoded=112.386 ms
#     Packet Sent: type=video, seq=29131, send_delay_since_encoded=30.623 ms
#         received, delay_since_sent=82.373 ms, delay_since_encoded=112.996 ms
#     Packet Sent: type=video, seq=29132, send_delay_since_encoded=32.583 ms
#         received, delay_since_sent=81.723 ms, delay_since_encoded=114.306 ms
#     Packet Sent: type=video, seq=29133, send_delay_since_encoded=36.004 ms
#         received, delay_since_sent=81.775 ms, delay_since_encoded=117.779 ms
#     Packet Sent: type=fec, seq=9081, send_delay_since_encoded=41.389 ms
#         received, delay_since_sent=82.437 ms, delay_since_encoded=123.826 ms
#         protected seqs=[29127, 29131, 29133]
#     Packet Sent: type=fec, seq=9082, send_delay_since_encoded=45.749 ms
#         received, delay_since_sent=82.384 ms, delay_since_encoded=128.133 ms
#         protected seqs=[29126, 29128, 29129, 29131]
#     Packet Sent: type=fec, seq=9083, send_delay_since_encoded=51.083 ms
#         received, delay_since_sent=82.469 ms, delay_since_encoded=133.552 ms
#         protected seqs=[29127, 29128, 29130, 29132]
#     Packet Sent: type=fec, seq=9084, send_delay_since_encoded=56.376 ms
#         received, delay_since_sent=82.402 ms, delay_since_encoded=138.778 ms
#         protected seqs=[29126, 29130, 29133]
# num_media_packets=8, num_fec_packets=4
# encoding_delay = 8.824 ms, pacing delay = 36.004 ms
# received encoded frame
# picture_id=8757, refs=[8756]
# frame_network_delay=81.887 ms
# jitter_delay=0.711 ms
# decoding_delay=15.023 ms
# e2e_delay=142.449 ms
# --------------------------------
# Frame rtp_ts_capture = 2195735364
# rtp_ts=1655389536, frame_type=delta, frame_size=6610 bytes, packet_count=6
# all related packets sent:
#     Packet Sent: type=video, seq=29134, send_delay_since_encoded=8.908 ms
#         received, delay_since_sent=81.872 ms, delay_since_encoded=90.78 ms
#     Packet Sent: type=video, seq=29135, send_delay_since_encoded=13.267 ms
#         received, delay_since_sent=81.852 ms, delay_since_encoded=95.119 ms
#     Packet Sent: type=video, seq=29136, send_delay_since_encoded=18.596 ms
#         received, delay_since_sent=81.9 ms, delay_since_encoded=100.496 ms
#     Packet Sent: type=video, seq=29137, send_delay_since_encoded=23.891 ms
#         received, delay_since_sent=81.866 ms, delay_since_encoded=105.757 ms
#     Packet Sent: type=video, seq=29138, send_delay_since_encoded=28.677 ms
#         received, delay_since_sent=81.75 ms, delay_since_encoded=110.427 ms
#     Packet Sent: type=video, seq=29139, send_delay_since_encoded=33.967 ms
#         received, delay_since_sent=81.809 ms, delay_since_encoded=115.776 ms
#     Packet Sent: type=fec, seq=9085, send_delay_since_encoded=34.112 ms
#         received, delay_since_sent=83.059 ms, delay_since_encoded=117.171 ms
#         protected seqs=[29134, 29135, 29137]
#     Packet Sent: type=fec, seq=9086, send_delay_since_encoded=44.56 ms
#         received, delay_since_sent=81.936 ms, delay_since_encoded=126.496 ms
#         protected seqs=[29135, 29136, 29138]
#     Packet Sent: type=fec, seq=9087, send_delay_since_encoded=50.095 ms
#         received, delay_since_sent=81.867 ms, delay_since_encoded=131.962 ms
#         protected seqs=[29134, 29136, 29139]
# num_media_packets=6, num_fec_packets=3
# encoding_delay = 8.103 ms, pacing delay = 33.967 ms
# received encoded frame
# picture_id=8758, refs=[8757]
# frame_network_delay=81.911 ms
# jitter_delay=1.769 ms
# decoding_delay=13.995 ms
# e2e_delay=139.745 ms
# --------------------------------
# Frame rtp_ts_capture = 2195738424
# rtp_ts=1655392596, frame_type=delta, frame_size=2918 bytes, packet_count=3
# all related packets sent:
#     Packet Sent: type=video, seq=29140, send_delay_since_encoded=0.349 ms
#         received, delay_since_sent=82.496 ms, delay_since_encoded=82.845 ms
#     Packet Sent: type=video, seq=29141, send_delay_since_encoded=5.473 ms
#         received, delay_since_sent=81.877 ms, delay_since_encoded=87.35 ms
#     Packet Sent: type=video, seq=29142, send_delay_since_encoded=10.85 ms
#         received, delay_since_sent=115.329 ms, delay_since_encoded=126.179 ms (recovered by RTX/FEC)
# num_media_packets=0, num_fec_packets=0
# encoding_delay = 8.495 ms, pacing delay = 10.85 ms
# received encoded frame
# picture_id=8759, refs=[8758]
# frame_network_delay=115.416 ms
# jitter_delay=0.735 ms
# decoding_delay=14.163 ms
# e2e_delay=149.659 ms
# --------------------------------
# Frame rtp_ts_capture = 2195741394
# rtp_ts=1655395566, frame_type=delta, frame_size=1683 bytes, packet_count=2
# all related packets sent:
#     Packet Sent: type=video, seq=29143, send_delay_since_encoded=0.108 ms
#         received, delay_since_sent=81.905 ms, delay_since_encoded=82.013 ms
#     Packet Sent: type=video, seq=29144, send_delay_since_encoded=4.641 ms
#         received, delay_since_sent=81.898 ms, delay_since_encoded=86.539 ms
#     Packet Sent: type=fec, seq=9088, send_delay_since_encoded=10.069 ms
#         received, delay_since_sent=82.203 ms, delay_since_encoded=92.272 ms
#         protected seqs=[29140, 29142, 29143]
#     Packet Sent: type=fec, seq=9089, send_delay_since_encoded=10.089 ms
#         received, delay_since_sent=83.344 ms, delay_since_encoded=93.433 ms
#         protected seqs=[29140, 29141, 29144]
#     Packet Sent: type=fec, seq=9090, send_delay_since_encoded=14.456 ms
#         received, delay_since_sent=81.922 ms, delay_since_encoded=96.378 ms
#         protected seqs=[29141, 29143]
# num_media_packets=5, num_fec_packets=3
# encoding_delay = 8.195 ms, pacing delay = 4.641 ms
# received encoded frame
# picture_id=8760, refs=[8759]
# frame_network_delay=81.985 ms
# jitter_delay=21.777 ms
# decoding_delay=12.981 ms
# e2e_delay=129.579 ms
# --------------------------------
# Frame rtp_ts_capture = 2195744364
# rtp_ts=1655398536, frame_type=delta, frame_size=4899 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=29145, send_delay_since_encoded=0.128 ms
#         received, delay_since_sent=81.857 ms, delay_since_encoded=81.985 ms
#     Packet Sent: type=video, seq=29146, send_delay_since_encoded=5.429 ms
#         received, delay_since_sent=81.806 ms, delay_since_encoded=87.235 ms
#     Packet Sent: type=video, seq=29147, send_delay_since_encoded=5.455 ms
#         received, delay_since_sent=82.356 ms, delay_since_encoded=87.811 ms
#     Packet Sent: type=video, seq=29148, send_delay_since_encoded=10.733 ms
#         received, delay_since_sent=81.775 ms, delay_since_encoded=92.508 ms
#     Packet Sent: type=video, seq=29149, send_delay_since_encoded=10.822 ms
#         received, delay_since_sent=82.266 ms, delay_since_encoded=93.088 ms
#     Packet Sent: type=fec, seq=9091, send_delay_since_encoded=15.157 ms
#         received, delay_since_sent=81.758 ms, delay_since_encoded=96.915 ms
#         protected seqs=[29145, 29147, 29148]
#     Packet Sent: type=fec, seq=9092, send_delay_since_encoded=16.538 ms
#         received, delay_since_sent=81.833 ms, delay_since_encoded=98.371 ms
#         protected seqs=[29145, 29146, 29149]
#     Packet Sent: type=fec, seq=9093, send_delay_since_encoded=20.933 ms
#         received, delay_since_sent=81.741 ms, delay_since_encoded=102.674 ms
#         protected seqs=[29146, 29148]
# num_media_packets=5, num_fec_packets=3
# encoding_delay = 12.383 ms, pacing delay = 10.822 ms
# received encoded frame
# picture_id=8761, refs=[8760]
# frame_network_delay=82.363 ms
# jitter_delay=0.73 ms
# decoding_delay=15.247 ms
# e2e_delay=121.545 ms
# --------------------------------
# Frame rtp_ts_capture = 2195747424
# rtp_ts=1655401596, frame_type=delta, frame_size=5515 bytes, packet_count=5
# all related packets sent:
#     Packet Sent: type=video, seq=29150, send_delay_since_encoded=0.196 ms
#         received, delay_since_sent=81.762 ms, delay_since_encoded=81.958 ms
# num_media_packets=0, num_fec_packets=0
# encoding_delay = 11.92 ms, pacing delay = 0.196 ms
# received encoded frame
# picture_id=8762, refs=[8761]
# frame_network_delay=98.007 ms
# jitter_delay=0.732 ms
# decoding_delay=16.873 ms
# e2e_delay=127.728 ms
