# %%
import json
import pandas as pd
import numpy as np

def load_events(path):
    with open(path) as f:
        data = json.load(f)
    return data["traceEvents"]

def flatten_event(e, source):
    """展开 args，仅保留 name, ts, args.xxx，并增加 from 字段"""

    out = {
        "name": e.get("name"),
        "ts": e.get("ts"),
        "from": source, 
    }

    args = e.get("args", {})
    if isinstance(args, dict):
        for k, v in args.items():
            out[f"args.{k}"] = v

    return out

def preprocess_events(events):
    tmp = pd.DataFrame(events)
    args_uint64 = tmp.dtypes[tmp.dtypes == "float64"]
    print(args_uint64.index.tolist())
    for e in events:
        for arg in args_uint64.index.tolist():
            if arg not in e:
                e[arg] = 0

path_sender = "../expr/trace_sender.json"
path_receiver = "../expr/trace_receiver.json"

# 读取原始数据
events_sender = load_events(path_sender)
events_receiver = load_events(path_receiver)

# 展开 + 加 from 字段
flat_sender = [flatten_event(e, "sender") for e in events_sender]
flat_receiver = [flatten_event(e, "receiver") for e in events_receiver]

# 合并两个列表
all_events = flat_sender + flat_receiver

preprocess_events(all_events)

df = pd.DataFrame(all_events)

df.dtypes
df["name"].unique().tolist()
# Out:
# ['args.last_target_bps', 'args.last_stable_target_bps', 'args.last_fraction_loss_', 'args.last_rtt_ms', 'args.value', 'args.update_target_bitrate_bps', 'args.encoder_target_rate_bps', 'args.protection_bitrate_bps', 'args.encoder_overhead_rate_bps', 'args.post_encode_overhead_bps', 'args.rtp_ts_capture', 'args.rtp_ts', 'args.capture_time_ms', 'args.frame_size', 'args.packet_count', 'args.seq', 'args.transport_seq', 'args.is_received', 'args.last_rtp_ts', 'args.num_media_packets', 'args.num_fec_packets', 'args.param_fec_rate', 'args.fec_payload_type', 'args.fec_ssrc', 'args.protected_frame_rtp_ts', 'args.rtt_ms', 'args.total_delta', 'args.lost_delta', 'args.payload_type', 'args.is_recovered', 'args.picture_id', 'args.render_time_ms', 'args.fec_seq', 'args.scheduled_decode_time_ms']
# ['BitrateAllocator:OnChanged',
#  'rtt_ms',
#  'loss',
#  'bwe_bps',
#  'Sender:AllocateBitrate',
#  'Frame:Captured',
#  'Frame:Start Encode',
#  'Frame:Encoded',
#  'Frame:Packetization',
#  'Frame:Dropped',
#  'Packet:Sent',
#  'RTCP:TransportPacketFeedback',
#  'Frame:Generate FEC',
#  'FlexFEC:GetFecPackets',
#  'RTCP:RTT',
#  'RTCP:ReportBlocksTransportLossReport',
#  'Packet:Received RTP',
#  'FlexFEC:Receive RTP Packet',
#  'Frame:Received EncodedFrame',
#  'Frame:ToFrameBuffer',
#  'Frame:ReadytoDecode',
#  'Frame:Start Decode',
#  'FEC:Receive FEC Packet',
#  'Frame:Decoded',
#  'Frame:Scheduled for Decode']

# %%
all_frame_rtp_ts_capture = df[df["name"] == "Frame:Captured"]["args.rtp_ts_capture"].unique()
all_frame_rtp_ts_capture.sort()

for rtp_ts_capture in all_frame_rtp_ts_capture:
    print("--------------------------------")
    print("Frame rtp_ts_capture =", rtp_ts_capture)
    event_frame_captured = df[(df["name"] == "Frame:Captured") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    event_frame_start_encode = df[(df["name"] == "Frame:Start Encode") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    
    if event_frame_start_encode.empty:
        event_frame_dropped = df[(df["name"] == "Frame:Dropped") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        reason = event_frame_dropped["args.reason"].values[0] 
        print(f"    dropped before encoding, reason={reason}!")
        continue
    else:
        event_frame_encoded = df[(df["name"] == "Frame:Encoded") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        
        if event_frame_encoded.empty:
            print(f"    dropped by encoder!")
            continue
        
        ts_captured = event_frame_captured["ts"].values[0]
        ts_encoded = event_frame_encoded["ts"].values[0]
        rtp_ts = event_frame_encoded["args.rtp_ts"].values[0]
        frame_type = event_frame_encoded["args.frame_type"].values[0]
        frame_size = event_frame_encoded["args.frame_size"].values[0]
        event_frame_packetization = df[(df["name"] == "Frame:Packetization") & (df["args.rtp_ts"] == rtp_ts)]
        packet_count = event_frame_packetization["args.packet_count"].values[0]
        event_frame_generate_fec = df[(df["name"] == "Frame:Generate FEC") & (df["args.last_rtp_ts"] == rtp_ts)]
        num_media_packets = event_frame_generate_fec["args.num_media_packets"].values[0] if not event_frame_generate_fec.empty else 0 
        num_fec_packets = event_frame_generate_fec["args.num_fec_packets"].values[0] if not event_frame_generate_fec.empty else 0

        events_packet_sent = df[(df["name"] == "Packet:Sent") & (df["args.rtp_ts"] == rtp_ts)]
        events_packet_sent_with_fec = df[(df["name"] == "Packet:Sent") & ((df["args.rtp_ts"] == rtp_ts) | (df["args.protected_frame_rtp_ts"] == rtp_ts))]

        events_packet_sent = events_packet_sent.sort_values(by="ts")
        events_packet_sent_with_fec = events_packet_sent_with_fec.sort_values(by="ts") 
        
        ts_first_packet_sent = events_packet_sent["ts"].values[0] if not events_packet_sent.empty else None 
        ts_last_packet_sent = events_packet_sent["ts"].values[-1] if not events_packet_sent.empty else None
        
        encoding_delay = ts_encoded - ts_captured
        pacing_delay = ts_last_packet_sent - ts_encoded if ts_last_packet_sent is not None else 0
        sender_side_delay = ts_last_packet_sent - ts_captured if ts_last_packet_sent is not None else None

        print(f"rtp_ts={rtp_ts}, frame_type={frame_type}, frame_size={frame_size} bytes, packet_count={packet_count}")
        
        """
        for _, packet_event in events_packet_sent_with_fec.iterrows():
            seq = packet_event["args.seq"]
            packet_type = packet_event["args.packet_type"]
            transport_seq = packet_event["args.transport_seq"]
            print(f"    Packet seq_num={seq}, packet_type={packet_type}, transport_seq={transport_seq}, delay_since_capture={(packet_event['ts'] - ts_captured)/1000} ms")
        """
        if ts_last_packet_sent is None:
            print(f"    During sending!")
            continue 
        
        print(f"num_media_packets={num_media_packets}, num_fec_packets={num_fec_packets}")
        print(f"sender_side_delay={sender_side_delay/1000} ms, encoding_delay = {encoding_delay/1000} ms, pacing delay = {pacing_delay/1000} ms")
         
        event_frame_received_encoded = df[(df["name"] == "Frame:Received EncodedFrame") & (df["args.rtp_ts"] == rtp_ts)]
        if event_frame_received_encoded.empty:
            print(f"    Not received at receiver!")
            continue
        
        picture_id = event_frame_received_encoded["args.picture_id"].values[0]
        refs = event_frame_received_encoded["args.refs"].values[0]
        ts_received_encoded = event_frame_received_encoded["ts"].values[0]
        
        print(f"received encoded frame")
        
        event_frame_ready_to_decode = df[(df["name"] == "Frame:ReadytoDecode") & (df["args.rtp_ts"] == rtp_ts)] 
        event_frame_start_decode = df[(df["name"] == "Frame:Start Decode") & (df["args.rtp_ts"] == rtp_ts)]
        event_frame_decoded = df[(df["name"] == "Frame:Decoded") & (df["args.rtp_ts"] == rtp_ts)]
        
        if event_frame_decoded.empty:
            print(f"    Not decoded at receiver!")
            continue 
         
        ts_ready_to_decode = event_frame_ready_to_decode["ts"].values[0]
        ts_start_decode = event_frame_start_decode["ts"].values[0]
        ts_decoded = event_frame_decoded["ts"].values[0]
        
        frame_network_delay = ts_received_encoded - ts_last_packet_sent 
        waiting_refs_delay = ts_ready_to_decode - ts_received_encoded
        jitter_delay = ts_start_decode - ts_ready_to_decode
        decoding_delay = ts_decoded - ts_start_decode
        e2e_delay = ts_decoded - ts_captured
        print(f"picture_id={picture_id}, refs={refs}")
        print(f"frame_network_delay={frame_network_delay/1000} ms, jitter_delay={jitter_delay/1000} ms, decoding_delay={decoding_delay/1000} ms, e2e_delay={e2e_delay/1000} ms")
# Out:
# --------------------------------
# Frame rtp_ts_capture = 3669601574
# rtp_ts=1477715563, frame_type=key, frame_size=52321 bytes, packet_count=48
# num_media_packets=48, num_fec_packets=1
# sender_side_delay=350.21 ms, encoding_delay = 70.996 ms, pacing delay = 279.214 ms
# received encoded frame
# picture_id=19033, refs=[]
# frame_network_delay=0.49 ms, jitter_delay=0.182 ms, decoding_delay=10.591 ms, e2e_delay=361.473 ms
# --------------------------------
# Frame rtp_ts_capture = 3669604544
#     dropped before encoding, reason=encoder_blocked!
# --------------------------------
# Frame rtp_ts_capture = 3669607604
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669610574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669613544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669616604
# rtp_ts=1477730593, frame_type=delta, frame_size=30775 bytes, packet_count=28
# num_media_packets=28, num_fec_packets=1
# sender_side_delay=322.123 ms, encoding_delay = 16.43 ms, pacing delay = 305.693 ms
# received encoded frame
# picture_id=19034, refs=[19033]
# frame_network_delay=0.721 ms, jitter_delay=0.108 ms, decoding_delay=5.948 ms, e2e_delay=328.9 ms
# --------------------------------
# Frame rtp_ts_capture = 3669619574
# rtp_ts=1477733563, frame_type=delta, frame_size=31262 bytes, packet_count=29
# num_media_packets=29, num_fec_packets=1
# sender_side_delay=420.452 ms, encoding_delay = 27.656 ms, pacing delay = 392.796 ms
# received encoded frame
# picture_id=19035, refs=[19034]
# frame_network_delay=0.673 ms, jitter_delay=0.135 ms, decoding_delay=7.791 ms, e2e_delay=429.051 ms
# --------------------------------
# Frame rtp_ts_capture = 3669622544
# rtp_ts=1477736533, frame_type=delta, frame_size=22363 bytes, packet_count=21
# num_media_packets=21, num_fec_packets=1
# sender_side_delay=486.484 ms, encoding_delay = 22.903 ms, pacing delay = 463.581 ms
# received encoded frame
# picture_id=19036, refs=[19035]
# frame_network_delay=0.578 ms, jitter_delay=0.127 ms, decoding_delay=6.735 ms, e2e_delay=493.924 ms
# --------------------------------
# Frame rtp_ts_capture = 3669625604
# rtp_ts=1477739593, frame_type=delta, frame_size=14748 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=516.199 ms, encoding_delay = 19.762 ms, pacing delay = 496.437 ms
# received encoded frame
# picture_id=19037, refs=[19036]
# frame_network_delay=0.494 ms, jitter_delay=0.148 ms, decoding_delay=6.92 ms, e2e_delay=523.761 ms
# --------------------------------
# Frame rtp_ts_capture = 3669628574
# rtp_ts=1477742563, frame_type=delta, frame_size=10013 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=529.971 ms, encoding_delay = 23.289 ms, pacing delay = 506.682 ms
# received encoded frame
# picture_id=19038, refs=[19037]
# frame_network_delay=0.698 ms, jitter_delay=0.079 ms, decoding_delay=5.89 ms, e2e_delay=536.638 ms
# --------------------------------
# Frame rtp_ts_capture = 3669631544
# rtp_ts=1477745533, frame_type=delta, frame_size=4436 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=523.077 ms, encoding_delay = 10.806 ms, pacing delay = 512.271 ms
# received encoded frame
# picture_id=19039, refs=[19038]
# frame_network_delay=0.687 ms, jitter_delay=0.154 ms, decoding_delay=3.76 ms, e2e_delay=527.678 ms
# --------------------------------
# Frame rtp_ts_capture = 3669634604
# rtp_ts=1477748593, frame_type=delta, frame_size=4097 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=509.687 ms, encoding_delay = 11.504 ms, pacing delay = 498.183 ms
# received encoded frame
# picture_id=19040, refs=[19039]
# frame_network_delay=0.787 ms, jitter_delay=0.061 ms, decoding_delay=3.446 ms, e2e_delay=513.981 ms
# --------------------------------
# Frame rtp_ts_capture = 3669637574
# rtp_ts=1477751563, frame_type=delta, frame_size=5130 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=496.826 ms, encoding_delay = 12.448 ms, pacing delay = 484.378 ms
# received encoded frame
# picture_id=19041, refs=[19040]
# frame_network_delay=0.666 ms, jitter_delay=0.139 ms, decoding_delay=3.886 ms, e2e_delay=501.517 ms
# --------------------------------
# Frame rtp_ts_capture = 3669640544
# rtp_ts=1477754533, frame_type=delta, frame_size=4808 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=490.132 ms, encoding_delay = 10.33 ms, pacing delay = 479.802 ms
# received encoded frame
# picture_id=19042, refs=[19041]
# frame_network_delay=0.655 ms, jitter_delay=0.071 ms, decoding_delay=4.273 ms, e2e_delay=495.131 ms
# --------------------------------
# Frame rtp_ts_capture = 3669643604
# rtp_ts=1477757593, frame_type=delta, frame_size=4181 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=476.814 ms, encoding_delay = 10.126 ms, pacing delay = 466.688 ms
# received encoded frame
# picture_id=19043, refs=[19042]
# frame_network_delay=0.9 ms, jitter_delay=0.1 ms, decoding_delay=4.369 ms, e2e_delay=482.183 ms
# --------------------------------
# Frame rtp_ts_capture = 3669646574
# rtp_ts=1477760563, frame_type=delta, frame_size=8634 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=480.944 ms, encoding_delay = 9.093 ms, pacing delay = 471.851 ms
# received encoded frame
# picture_id=19044, refs=[19043]
# frame_network_delay=0.487 ms, jitter_delay=0.138 ms, decoding_delay=4.299 ms, e2e_delay=485.868 ms
# --------------------------------
# Frame rtp_ts_capture = 3669649544
# rtp_ts=1477763533, frame_type=delta, frame_size=8179 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=489.926 ms, encoding_delay = 12.651 ms, pacing delay = 477.275 ms
# received encoded frame
# picture_id=19045, refs=[19044]
# frame_network_delay=0.807 ms, jitter_delay=0.171 ms, decoding_delay=4.048 ms, e2e_delay=494.952 ms
# --------------------------------
# Frame rtp_ts_capture = 3669652604
# rtp_ts=1477766593, frame_type=delta, frame_size=7744 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=489.085 ms, encoding_delay = 12.013 ms, pacing delay = 477.072 ms
# received encoded frame
# picture_id=19046, refs=[19045]
# frame_network_delay=0.655 ms, jitter_delay=0.125 ms, decoding_delay=3.757 ms, e2e_delay=493.622 ms
# --------------------------------
# Frame rtp_ts_capture = 3669655574
# rtp_ts=1477769563, frame_type=delta, frame_size=5004 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=482.478 ms, encoding_delay = 8.933 ms, pacing delay = 473.545 ms
# received encoded frame
# picture_id=19047, refs=[19046]
# frame_network_delay=1.055 ms, jitter_delay=0.108 ms, decoding_delay=3.872 ms, e2e_delay=487.513 ms
# --------------------------------
# Frame rtp_ts_capture = 3669658544
# rtp_ts=1477772533, frame_type=delta, frame_size=2552 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=463.582 ms, encoding_delay = 10.663 ms, pacing delay = 452.919 ms
# received encoded frame
# picture_id=19048, refs=[19047]
# frame_network_delay=0.553 ms, jitter_delay=0.153 ms, decoding_delay=4.615 ms, e2e_delay=468.903 ms
# --------------------------------
# Frame rtp_ts_capture = 3669661514
# rtp_ts=1477775503, frame_type=delta, frame_size=2771 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=441.891 ms, encoding_delay = 9.297 ms, pacing delay = 432.594 ms
# received encoded frame
# picture_id=19049, refs=[19048]
# frame_network_delay=0.783 ms, jitter_delay=0.101 ms, decoding_delay=3.952 ms, e2e_delay=446.727 ms
# --------------------------------
# Frame rtp_ts_capture = 3669664574
# rtp_ts=1477778563, frame_type=delta, frame_size=3311 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=429.548 ms, encoding_delay = 8.872 ms, pacing delay = 420.676 ms
# received encoded frame
# picture_id=19050, refs=[19049]
# frame_network_delay=0.816 ms, jitter_delay=0.183 ms, decoding_delay=4.427 ms, e2e_delay=434.974 ms
# --------------------------------
# Frame rtp_ts_capture = 3669667544
# rtp_ts=1477781533, frame_type=delta, frame_size=6061 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=422.559 ms, encoding_delay = 9.934 ms, pacing delay = 412.625 ms
# received encoded frame
# picture_id=19051, refs=[19050]
# frame_network_delay=0.707 ms, jitter_delay=0.069 ms, decoding_delay=4.042 ms, e2e_delay=427.377 ms
# --------------------------------
# Frame rtp_ts_capture = 3669670604
# rtp_ts=1477784593, frame_type=delta, frame_size=4987 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=411.6 ms, encoding_delay = 11.414 ms, pacing delay = 400.186 ms
# received encoded frame
# picture_id=19052, refs=[19051]
# frame_network_delay=0.719 ms, jitter_delay=0.071 ms, decoding_delay=4.357 ms, e2e_delay=416.747 ms
# --------------------------------
# Frame rtp_ts_capture = 3669673574
# rtp_ts=1477787563, frame_type=delta, frame_size=5608 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=408.605 ms, encoding_delay = 13.922 ms, pacing delay = 394.683 ms
# received encoded frame
# picture_id=19053, refs=[19052]
# frame_network_delay=1.011 ms, jitter_delay=0.133 ms, decoding_delay=4.97 ms, e2e_delay=414.719 ms
# --------------------------------
# Frame rtp_ts_capture = 3669676544
# rtp_ts=1477790533, frame_type=delta, frame_size=13921 bytes, packet_count=13
# num_media_packets=13, num_fec_packets=1
# sender_side_delay=433.016 ms, encoding_delay = 13.544 ms, pacing delay = 419.472 ms
# received encoded frame
# picture_id=19054, refs=[19053]
# frame_network_delay=0.484 ms, jitter_delay=0.136 ms, decoding_delay=4.694 ms, e2e_delay=438.33 ms
# --------------------------------
# Frame rtp_ts_capture = 3669679604
# rtp_ts=1477793593, frame_type=delta, frame_size=8119 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=435.29 ms, encoding_delay = 11.195 ms, pacing delay = 424.095 ms
# received encoded frame
# picture_id=19055, refs=[19054]
# frame_network_delay=0.553 ms, jitter_delay=0.097 ms, decoding_delay=5.115 ms, e2e_delay=441.055 ms
# --------------------------------
# Frame rtp_ts_capture = 3669682574
# rtp_ts=1477796563, frame_type=delta, frame_size=6331 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=432.41 ms, encoding_delay = 12.597 ms, pacing delay = 419.813 ms
# received encoded frame
# picture_id=19056, refs=[19055]
# frame_network_delay=0.444 ms, jitter_delay=0.138 ms, decoding_delay=3.957 ms, e2e_delay=436.949 ms
# --------------------------------
# Frame rtp_ts_capture = 3669685544
# rtp_ts=1477799533, frame_type=delta, frame_size=4548 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=419.273 ms, encoding_delay = 11.617 ms, pacing delay = 407.656 ms
# received encoded frame
# picture_id=19057, refs=[19056]
# frame_network_delay=0.507 ms, jitter_delay=0.11 ms, decoding_delay=4.353 ms, e2e_delay=424.243 ms
# --------------------------------
# Frame rtp_ts_capture = 3669688604
# rtp_ts=1477802593, frame_type=delta, frame_size=2121 bytes, packet_count=2
# num_media_packets=2, num_fec_packets=1
# sender_side_delay=396.874 ms, encoding_delay = 9.444 ms, pacing delay = 387.43 ms
# received encoded frame
# picture_id=19058, refs=[19057]
# frame_network_delay=0.563 ms, jitter_delay=0.155 ms, decoding_delay=3.923 ms, e2e_delay=401.515 ms
# --------------------------------
# Frame rtp_ts_capture = 3669691574
# rtp_ts=1477805563, frame_type=delta, frame_size=3568 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=381.858 ms, encoding_delay = 13.282 ms, pacing delay = 368.576 ms
# received encoded frame
# picture_id=19059, refs=[19058]
# frame_network_delay=0.792 ms, jitter_delay=0.087 ms, decoding_delay=4.126 ms, e2e_delay=386.863 ms
# --------------------------------
# Frame rtp_ts_capture = 3669694544
# rtp_ts=1477808533, frame_type=delta, frame_size=4002 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=372.321 ms, encoding_delay = 13.747 ms, pacing delay = 358.574 ms
# received encoded frame
# picture_id=19060, refs=[19059]
# frame_network_delay=0.874 ms, jitter_delay=0.099 ms, decoding_delay=4.715 ms, e2e_delay=378.009 ms
# --------------------------------
# Frame rtp_ts_capture = 3669697604
# rtp_ts=1477811593, frame_type=delta, frame_size=15174 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=399.561 ms, encoding_delay = 24.489 ms, pacing delay = 375.072 ms
# received encoded frame
# picture_id=19061, refs=[19060]
# frame_network_delay=0.647 ms, jitter_delay=0.124 ms, decoding_delay=7.93 ms, e2e_delay=408.262 ms
# --------------------------------
# Frame rtp_ts_capture = 3669700574
# rtp_ts=1477814563, frame_type=delta, frame_size=4370 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=385.707 ms, encoding_delay = 18.225 ms, pacing delay = 367.482 ms
# received encoded frame
# picture_id=19062, refs=[19061]
# frame_network_delay=0.607 ms, jitter_delay=0.153 ms, decoding_delay=4.754 ms, e2e_delay=391.221 ms
# --------------------------------
# Frame rtp_ts_capture = 3669703544
# rtp_ts=1477817533, frame_type=delta, frame_size=7468 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=389.25 ms, encoding_delay = 15.851 ms, pacing delay = 373.399 ms
# received encoded frame
# picture_id=19063, refs=[19062]
# frame_network_delay=0.785 ms, jitter_delay=0.172 ms, decoding_delay=4.73 ms, e2e_delay=394.937 ms
# --------------------------------
# Frame rtp_ts_capture = 3669706604
# rtp_ts=1477820593, frame_type=delta, frame_size=18086 bytes, packet_count=17
# num_media_packets=17, num_fec_packets=1
# sender_side_delay=428.882 ms, encoding_delay = 13.987 ms, pacing delay = 414.895 ms
# received encoded frame
# picture_id=19064, refs=[19063]
# frame_network_delay=0.827 ms, jitter_delay=0.137 ms, decoding_delay=6.67 ms, e2e_delay=436.516 ms
# --------------------------------
# Frame rtp_ts_capture = 3669709574
# rtp_ts=1477823563, frame_type=delta, frame_size=12923 bytes, packet_count=12
# num_media_packets=12, num_fec_packets=1
# sender_side_delay=449.443 ms, encoding_delay = 12.039 ms, pacing delay = 437.404 ms
# received encoded frame
# picture_id=19065, refs=[19064]
# frame_network_delay=0.733 ms, jitter_delay=0.143 ms, decoding_delay=5.159 ms, e2e_delay=455.478 ms
# --------------------------------
# Frame rtp_ts_capture = 3669712544
# rtp_ts=1477826533, frame_type=delta, frame_size=8227 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=450.553 ms, encoding_delay = 12.513 ms, pacing delay = 438.04 ms
# received encoded frame
# picture_id=19066, refs=[19065]
# frame_network_delay=0.828 ms, jitter_delay=0.067 ms, decoding_delay=4.636 ms, e2e_delay=456.084 ms
# --------------------------------
# Frame rtp_ts_capture = 3669715514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669718574
# rtp_ts=1477832563, frame_type=delta, frame_size=5457 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=407.671 ms, encoding_delay = 11.532 ms, pacing delay = 396.139 ms
# received encoded frame
# picture_id=19067, refs=[19066]
# frame_network_delay=0.694 ms, jitter_delay=0.074 ms, decoding_delay=4.318 ms, e2e_delay=412.757 ms
# --------------------------------
# Frame rtp_ts_capture = 3669721544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669724514
# rtp_ts=1477838503, frame_type=delta, frame_size=2502 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=355.33 ms, encoding_delay = 15.081 ms, pacing delay = 340.249 ms
# received encoded frame
# picture_id=19068, refs=[19067]
# frame_network_delay=0.579 ms, jitter_delay=0.119 ms, decoding_delay=4.561 ms, e2e_delay=360.589 ms
# --------------------------------
# Frame rtp_ts_capture = 3669727574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669730544
# rtp_ts=1477844533, frame_type=delta, frame_size=2388 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=304.799 ms, encoding_delay = 10.365 ms, pacing delay = 294.434 ms
# received encoded frame
# picture_id=19069, refs=[19068]
# frame_network_delay=0.842 ms, jitter_delay=0.068 ms, decoding_delay=4.84 ms, e2e_delay=310.549 ms
# --------------------------------
# Frame rtp_ts_capture = 3669733514
# rtp_ts=1477847503, frame_type=delta, frame_size=2057 bytes, packet_count=2
# num_media_packets=2, num_fec_packets=1
# sender_side_delay=280.736 ms, encoding_delay = 10.276 ms, pacing delay = 270.46 ms
# received encoded frame
# picture_id=19070, refs=[19069]
# frame_network_delay=0.604 ms, jitter_delay=0.109 ms, decoding_delay=3.877 ms, e2e_delay=285.326 ms
# --------------------------------
# Frame rtp_ts_capture = 3669736574
# rtp_ts=1477850563, frame_type=delta, frame_size=1442 bytes, packet_count=2
# num_media_packets=2, num_fec_packets=1
# sender_side_delay=258.059 ms, encoding_delay = 9.539 ms, pacing delay = 248.52 ms
# received encoded frame
# picture_id=19071, refs=[19070]
# frame_network_delay=0.545 ms, jitter_delay=0.059 ms, decoding_delay=3.732 ms, e2e_delay=262.395 ms
# --------------------------------
# Frame rtp_ts_capture = 3669739544
# rtp_ts=1477853533, frame_type=delta, frame_size=2148 bytes, packet_count=2
# num_media_packets=2, num_fec_packets=1
# sender_side_delay=237.379 ms, encoding_delay = 9.747 ms, pacing delay = 227.632 ms
# received encoded frame
# picture_id=19072, refs=[19071]
# frame_network_delay=1.074 ms, jitter_delay=0.02 ms, decoding_delay=4.692 ms, e2e_delay=243.165 ms
# --------------------------------
# Frame rtp_ts_capture = 3669742514
# rtp_ts=1477856503, frame_type=delta, frame_size=3762 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=220.236 ms, encoding_delay = 9.243 ms, pacing delay = 210.993 ms
# received encoded frame
# picture_id=19073, refs=[19072]
# frame_network_delay=0.723 ms, jitter_delay=0.017 ms, decoding_delay=4.213 ms, e2e_delay=225.189 ms
# --------------------------------
# Frame rtp_ts_capture = 3669745574
# rtp_ts=1477859563, frame_type=delta, frame_size=7134 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=218.393 ms, encoding_delay = 8.655 ms, pacing delay = 209.738 ms
# received encoded frame
# picture_id=19074, refs=[19073]
# frame_network_delay=0.685 ms, jitter_delay=0.076 ms, decoding_delay=3.791 ms, e2e_delay=222.945 ms
# --------------------------------
# Frame rtp_ts_capture = 3669748544
# rtp_ts=1477862533, frame_type=delta, frame_size=5164 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=210.102 ms, encoding_delay = 10.189 ms, pacing delay = 199.913 ms
# received encoded frame
# picture_id=19075, refs=[19074]
# frame_network_delay=0.925 ms, jitter_delay=0.058 ms, decoding_delay=4.21 ms, e2e_delay=215.295 ms
# --------------------------------
# Frame rtp_ts_capture = 3669751604
# rtp_ts=1477865593, frame_type=delta, frame_size=4178 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=192.519 ms, encoding_delay = 7.994 ms, pacing delay = 184.525 ms
# received encoded frame
# picture_id=19076, refs=[19075]
# frame_network_delay=0.649 ms, jitter_delay=0.069 ms, decoding_delay=3.76 ms, e2e_delay=196.997 ms
# --------------------------------
# Frame rtp_ts_capture = 3669754574
# rtp_ts=1477868563, frame_type=delta, frame_size=3553 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=176.68 ms, encoding_delay = 9.447 ms, pacing delay = 167.233 ms
# received encoded frame
# picture_id=19077, refs=[19076]
# frame_network_delay=0.765 ms, jitter_delay=0.061 ms, decoding_delay=3.236 ms, e2e_delay=180.742 ms
# --------------------------------
# Frame rtp_ts_capture = 3669757544
# rtp_ts=1477871533, frame_type=delta, frame_size=3704 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=163.385 ms, encoding_delay = 13.765 ms, pacing delay = 149.62 ms
# received encoded frame
# picture_id=19078, refs=[19077]
# frame_network_delay=0.541 ms, jitter_delay=0.055 ms, decoding_delay=3.539 ms, e2e_delay=167.52 ms
# --------------------------------
# Frame rtp_ts_capture = 3669760514
# rtp_ts=1477874503, frame_type=delta, frame_size=3478 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=146.426 ms, encoding_delay = 11.906 ms, pacing delay = 134.52 ms
# received encoded frame
# picture_id=19079, refs=[19078]
# frame_network_delay=0.548 ms, jitter_delay=0.062 ms, decoding_delay=3.829 ms, e2e_delay=150.865 ms
# --------------------------------
# Frame rtp_ts_capture = 3669763574
# rtp_ts=1477877563, frame_type=delta, frame_size=3758 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=129.98 ms, encoding_delay = 11.269 ms, pacing delay = 118.711 ms
# received encoded frame
# picture_id=19080, refs=[19079]
# frame_network_delay=0.585 ms, jitter_delay=0.02 ms, decoding_delay=3.879 ms, e2e_delay=134.464 ms
# --------------------------------
# Frame rtp_ts_capture = 3669766544
# rtp_ts=1477880533, frame_type=delta, frame_size=3411 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=117.342 ms, encoding_delay = 9.93 ms, pacing delay = 107.412 ms
# received encoded frame
# picture_id=19081, refs=[19080]
# frame_network_delay=0.765 ms, jitter_delay=0.122 ms, decoding_delay=4.235 ms, e2e_delay=122.464 ms
# --------------------------------
# Frame rtp_ts_capture = 3669769604
# rtp_ts=1477883593, frame_type=delta, frame_size=3683 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=99.266 ms, encoding_delay = 9.756 ms, pacing delay = 89.51 ms
# received encoded frame
# picture_id=19082, refs=[19081]
# frame_network_delay=0.572 ms, jitter_delay=0.042 ms, decoding_delay=4.345 ms, e2e_delay=104.225 ms
# --------------------------------
# Frame rtp_ts_capture = 3669772574
# rtp_ts=1477886563, frame_type=delta, frame_size=6274 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=92.6 ms, encoding_delay = 10.676 ms, pacing delay = 81.924 ms
# received encoded frame
# picture_id=19083, refs=[19082]
# frame_network_delay=0.514 ms, jitter_delay=0.064 ms, decoding_delay=4.941 ms, e2e_delay=98.119 ms
# --------------------------------
# Frame rtp_ts_capture = 3669775544
# rtp_ts=1477889533, frame_type=delta, frame_size=8702 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=95.99 ms, encoding_delay = 9.74 ms, pacing delay = 86.25 ms
# received encoded frame
# picture_id=19084, refs=[19083]
# frame_network_delay=0.746 ms, jitter_delay=0.093 ms, decoding_delay=4.81 ms, e2e_delay=101.639 ms
# --------------------------------
# Frame rtp_ts_capture = 3669778514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669781574
# rtp_ts=1477895563, frame_type=delta, frame_size=8193 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=61.548 ms, encoding_delay = 10.859 ms, pacing delay = 50.689 ms
# received encoded frame
# picture_id=19085, refs=[19084]
# frame_network_delay=0.762 ms, jitter_delay=0.055 ms, decoding_delay=5.381 ms, e2e_delay=67.746 ms
# --------------------------------
# Frame rtp_ts_capture = 3669784544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669787514
# rtp_ts=1477901503, frame_type=delta, frame_size=7992 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=44.528 ms, encoding_delay = 17.6 ms, pacing delay = 26.928 ms
# received encoded frame
# picture_id=19086, refs=[19085]
# frame_network_delay=0.694 ms, jitter_delay=0.184 ms, decoding_delay=5.819 ms, e2e_delay=51.225 ms
# --------------------------------
# Frame rtp_ts_capture = 3669790574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669793544
# rtp_ts=1477907533, frame_type=delta, frame_size=6716 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=39.605 ms, encoding_delay = 12.893 ms, pacing delay = 26.712 ms
# received encoded frame
# picture_id=19087, refs=[19086]
# frame_network_delay=0.722 ms, jitter_delay=0.101 ms, decoding_delay=5.556 ms, e2e_delay=45.984 ms
# --------------------------------
# Frame rtp_ts_capture = 3669796604
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669799574
# rtp_ts=1477913563, frame_type=delta, frame_size=5374 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=28.11 ms, encoding_delay = 11.841 ms, pacing delay = 16.269 ms
# received encoded frame
# picture_id=19088, refs=[19087]
# frame_network_delay=0.524 ms, jitter_delay=0.087 ms, decoding_delay=4.34 ms, e2e_delay=33.061 ms
# --------------------------------
# Frame rtp_ts_capture = 3669802544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669805514
# rtp_ts=1477919503, frame_type=delta, frame_size=5631 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=35.366 ms, encoding_delay = 13.872 ms, pacing delay = 21.494 ms
# received encoded frame
# picture_id=19089, refs=[19088]
# frame_network_delay=0.571 ms, jitter_delay=0.127 ms, decoding_delay=5.037 ms, e2e_delay=41.101 ms
# --------------------------------
# Frame rtp_ts_capture = 3669808574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669811544
# rtp_ts=1477925533, frame_type=delta, frame_size=5566 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=34.098 ms, encoding_delay = 13.091 ms, pacing delay = 21.007 ms
# received encoded frame
# picture_id=19090, refs=[19089]
# frame_network_delay=0.767 ms, jitter_delay=0.146 ms, decoding_delay=4.284 ms, e2e_delay=39.295 ms
# --------------------------------
# Frame rtp_ts_capture = 3669814514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669817574
# rtp_ts=1477931563, frame_type=delta, frame_size=5948 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=33.342 ms, encoding_delay = 14.882 ms, pacing delay = 18.46 ms
# received encoded frame
# picture_id=19091, refs=[19090]
# frame_network_delay=0.719 ms, jitter_delay=0.152 ms, decoding_delay=5.244 ms, e2e_delay=39.457 ms
# --------------------------------
# Frame rtp_ts_capture = 3669820544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669823604
# rtp_ts=1477937593, frame_type=delta, frame_size=5902 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=30.356 ms, encoding_delay = 10.051 ms, pacing delay = 20.305 ms
# received encoded frame
# picture_id=19092, refs=[19091]
# frame_network_delay=0.614 ms, jitter_delay=0.204 ms, decoding_delay=4.595 ms, e2e_delay=35.769 ms
# --------------------------------
# Frame rtp_ts_capture = 3669826574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669829544
# rtp_ts=1477943533, frame_type=delta, frame_size=10499 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=44.014 ms, encoding_delay = 9.71 ms, pacing delay = 34.304 ms
# received encoded frame
# picture_id=19093, refs=[19092]
# frame_network_delay=0.688 ms, jitter_delay=0.093 ms, decoding_delay=4.833 ms, e2e_delay=49.628 ms
# --------------------------------
# Frame rtp_ts_capture = 3669832604
# rtp_ts=1477946593, frame_type=delta, frame_size=9637 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=48.771 ms, encoding_delay = 10.437 ms, pacing delay = 38.334 ms
# received encoded frame
# picture_id=19094, refs=[19093]
# frame_network_delay=0.767 ms, jitter_delay=0.137 ms, decoding_delay=4.849 ms, e2e_delay=54.524 ms
# --------------------------------
# Frame rtp_ts_capture = 3669835574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669838544
# rtp_ts=1477952533, frame_type=delta, frame_size=8909 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=39.549 ms, encoding_delay = 9.715 ms, pacing delay = 29.834 ms
# received encoded frame
# picture_id=19095, refs=[19094]
# frame_network_delay=0.816 ms, jitter_delay=0.08 ms, decoding_delay=4.625 ms, e2e_delay=45.07 ms
# --------------------------------
# Frame rtp_ts_capture = 3669841514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669844574
# rtp_ts=1477958563, frame_type=delta, frame_size=7346 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=33.266 ms, encoding_delay = 10.184 ms, pacing delay = 23.082 ms
# received encoded frame
# picture_id=19096, refs=[19095]
# frame_network_delay=0.609 ms, jitter_delay=0.14 ms, decoding_delay=4.621 ms, e2e_delay=38.636 ms
# --------------------------------
# Frame rtp_ts_capture = 3669847544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669850604
# rtp_ts=1477964593, frame_type=delta, frame_size=7497 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=39.209 ms, encoding_delay = 12.734 ms, pacing delay = 26.475 ms
# received encoded frame
# picture_id=19097, refs=[19096]
# frame_network_delay=0.725 ms, jitter_delay=0.141 ms, decoding_delay=5.475 ms, e2e_delay=45.55 ms
# --------------------------------
# Frame rtp_ts_capture = 3669853574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669856544
# rtp_ts=1477970533, frame_type=delta, frame_size=6352 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=34.23 ms, encoding_delay = 13.243 ms, pacing delay = 20.987 ms
# received encoded frame
# picture_id=19098, refs=[19097]
# frame_network_delay=0.77 ms, jitter_delay=0.141 ms, decoding_delay=5.328 ms, e2e_delay=40.469 ms
# --------------------------------
# Frame rtp_ts_capture = 3669859514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669862574
# rtp_ts=1477976563, frame_type=delta, frame_size=7160 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=33.877 ms, encoding_delay = 11.994 ms, pacing delay = 21.883 ms
# received encoded frame
# picture_id=19099, refs=[19098]
# frame_network_delay=0.649 ms, jitter_delay=0.152 ms, decoding_delay=5.76 ms, e2e_delay=40.438 ms
# --------------------------------
# Frame rtp_ts_capture = 3669865544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669868514
# rtp_ts=1477982503, frame_type=delta, frame_size=7552 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=39.381 ms, encoding_delay = 11.671 ms, pacing delay = 27.71 ms
# received encoded frame
# picture_id=19100, refs=[19099]
# frame_network_delay=0.762 ms, jitter_delay=0.076 ms, decoding_delay=4.94 ms, e2e_delay=45.159 ms
# --------------------------------
# Frame rtp_ts_capture = 3669871574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669874544
# rtp_ts=1477988533, frame_type=delta, frame_size=8498 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=43.51 ms, encoding_delay = 11.818 ms, pacing delay = 31.692 ms
# received encoded frame
# picture_id=19101, refs=[19100]
# frame_network_delay=0.737 ms, jitter_delay=0.086 ms, decoding_delay=5.055 ms, e2e_delay=49.388 ms
# --------------------------------
# Frame rtp_ts_capture = 3669877514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669880574
# rtp_ts=1477994563, frame_type=delta, frame_size=10648 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=50.066 ms, encoding_delay = 14.402 ms, pacing delay = 35.664 ms
# received encoded frame
# picture_id=19102, refs=[19101]
# frame_network_delay=0.596 ms, jitter_delay=0.114 ms, decoding_delay=5.166 ms, e2e_delay=55.942 ms
# --------------------------------
# Frame rtp_ts_capture = 3669883544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669886604
# rtp_ts=1478000593, frame_type=delta, frame_size=15660 bytes, packet_count=15
# num_media_packets=15, num_fec_packets=1
# sender_side_delay=69.161 ms, encoding_delay = 16.595 ms, pacing delay = 52.566 ms
# received encoded frame
# picture_id=19103, refs=[19102]
# frame_network_delay=0.65 ms, jitter_delay=0.117 ms, decoding_delay=6.187 ms, e2e_delay=76.115 ms
# --------------------------------
# Frame rtp_ts_capture = 3669889574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669892544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669895514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669898574
# rtp_ts=1478012563, frame_type=delta, frame_size=16675 bytes, packet_count=16
# num_media_packets=16, num_fec_packets=1
# sender_side_delay=74.846 ms, encoding_delay = 15.911 ms, pacing delay = 58.935 ms
# received encoded frame
# picture_id=19104, refs=[19103]
# frame_network_delay=0.679 ms, jitter_delay=0.16 ms, decoding_delay=5.407 ms, e2e_delay=81.092 ms
# --------------------------------
# Frame rtp_ts_capture = 3669901544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669904514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669907574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669910544
# rtp_ts=1478024533, frame_type=delta, frame_size=18160 bytes, packet_count=17
# num_media_packets=17, num_fec_packets=1
# sender_side_delay=77.682 ms, encoding_delay = 17.098 ms, pacing delay = 60.584 ms
# received encoded frame
# picture_id=19105, refs=[19104]
# frame_network_delay=0.593 ms, jitter_delay=0.069 ms, decoding_delay=6.252 ms, e2e_delay=84.596 ms
# --------------------------------
# Frame rtp_ts_capture = 3669913514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669916574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669919544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669922514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669925574
# rtp_ts=1478039563, frame_type=delta, frame_size=15826 bytes, packet_count=15
# num_media_packets=15, num_fec_packets=1
# sender_side_delay=72.288 ms, encoding_delay = 16.527 ms, pacing delay = 55.761 ms
# received encoded frame
# picture_id=19106, refs=[19105]
# frame_network_delay=0.618 ms, jitter_delay=0.158 ms, decoding_delay=5.532 ms, e2e_delay=78.596 ms
# --------------------------------
# Frame rtp_ts_capture = 3669928544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669931514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669934574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669937544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669940604
# rtp_ts=1478054593, frame_type=delta, frame_size=14469 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=74.032 ms, encoding_delay = 21.573 ms, pacing delay = 52.459 ms
# received encoded frame
# picture_id=19107, refs=[19106]
# frame_network_delay=0.695 ms, jitter_delay=0.134 ms, decoding_delay=4.979 ms, e2e_delay=79.84 ms
# --------------------------------
# Frame rtp_ts_capture = 3669943574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669946544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669949604
# rtp_ts=1478063593, frame_type=delta, frame_size=14063 bytes, packet_count=13
# num_media_packets=13, num_fec_packets=1
# sender_side_delay=62.902 ms, encoding_delay = 15.936 ms, pacing delay = 46.966 ms
# received encoded frame
# picture_id=19108, refs=[19107]
# frame_network_delay=0.742 ms, jitter_delay=0.118 ms, decoding_delay=4.811 ms, e2e_delay=68.573 ms
# --------------------------------
# Frame rtp_ts_capture = 3669952574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669955544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669958514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669961574
# rtp_ts=1478075563, frame_type=delta, frame_size=16163 bytes, packet_count=15
# num_media_packets=15, num_fec_packets=1
# sender_side_delay=71.887 ms, encoding_delay = 14.8 ms, pacing delay = 57.087 ms
# received encoded frame
# picture_id=19109, refs=[19108]
# frame_network_delay=0.822 ms, jitter_delay=0.117 ms, decoding_delay=5.071 ms, e2e_delay=77.897 ms
# --------------------------------
# Frame rtp_ts_capture = 3669964544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669967514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669970574
# rtp_ts=1478084563, frame_type=delta, frame_size=17059 bytes, packet_count=16
# num_media_packets=16, num_fec_packets=1
# sender_side_delay=75.255 ms, encoding_delay = 16.69 ms, pacing delay = 58.565 ms
# received encoded frame
# picture_id=19110, refs=[19109]
# frame_network_delay=0.67 ms, jitter_delay=0.109 ms, decoding_delay=5.103 ms, e2e_delay=81.137 ms
# --------------------------------
# Frame rtp_ts_capture = 3669973544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669976514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669979574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669982544
# rtp_ts=1478096533, frame_type=delta, frame_size=20705 bytes, packet_count=19
# num_media_packets=19, num_fec_packets=1
# sender_side_delay=89.734 ms, encoding_delay = 17.074 ms, pacing delay = 72.66 ms
# received encoded frame
# picture_id=19111, refs=[19110]
# frame_network_delay=0.738 ms, jitter_delay=0.11 ms, decoding_delay=4.938 ms, e2e_delay=95.52 ms
# --------------------------------
# Frame rtp_ts_capture = 3669985514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669988574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669991544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3669994514
# rtp_ts=1478108503, frame_type=delta, frame_size=25264 bytes, packet_count=23
# num_media_packets=23, num_fec_packets=1
# sender_side_delay=105.703 ms, encoding_delay = 20.222 ms, pacing delay = 85.481 ms
# received encoded frame
# picture_id=19112, refs=[19111]
# frame_network_delay=0.666 ms, jitter_delay=0.111 ms, decoding_delay=5.938 ms, e2e_delay=112.418 ms
# --------------------------------
# Frame rtp_ts_capture = 3669997574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670000544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670003604
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670006574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670009544
# rtp_ts=1478123533, frame_type=delta, frame_size=25735 bytes, packet_count=24
# num_media_packets=24, num_fec_packets=1
# sender_side_delay=108.213 ms, encoding_delay = 20.363 ms, pacing delay = 87.85 ms
# received encoded frame
# picture_id=19113, refs=[19112]
# frame_network_delay=0.545 ms, jitter_delay=0.112 ms, decoding_delay=6.905 ms, e2e_delay=115.775 ms
# --------------------------------
# Frame rtp_ts_capture = 3670012604
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670015574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670018544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670021514
# rtp_ts=1478135503, frame_type=delta, frame_size=19574 bytes, packet_count=18
# num_media_packets=18, num_fec_packets=1
# sender_side_delay=87.453 ms, encoding_delay = 19.046 ms, pacing delay = 68.407 ms
# received encoded frame
# picture_id=19114, refs=[19113]
# frame_network_delay=0.655 ms, jitter_delay=0.144 ms, decoding_delay=5.508 ms, e2e_delay=93.76 ms
# --------------------------------
# Frame rtp_ts_capture = 3670024574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670027544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670030514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670033574
# rtp_ts=1478147563, frame_type=delta, frame_size=18052 bytes, packet_count=17
# num_media_packets=17, num_fec_packets=1
# sender_side_delay=81.605 ms, encoding_delay = 16.638 ms, pacing delay = 64.967 ms
# received encoded frame
# picture_id=19115, refs=[19114]
# frame_network_delay=0.523 ms, jitter_delay=0.111 ms, decoding_delay=5.42 ms, e2e_delay=87.659 ms
# --------------------------------
# Frame rtp_ts_capture = 3670036544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670039514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670042574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670045544
# rtp_ts=1478159533, frame_type=delta, frame_size=16328 bytes, packet_count=15
# num_media_packets=15, num_fec_packets=1
# sender_side_delay=73.671 ms, encoding_delay = 17.83 ms, pacing delay = 55.841 ms
# received encoded frame
# picture_id=19116, refs=[19115]
# frame_network_delay=0.549 ms, jitter_delay=0.125 ms, decoding_delay=4.868 ms, e2e_delay=79.213 ms
# --------------------------------
# Frame rtp_ts_capture = 3670048514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670051574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670054544
# rtp_ts=1478168533, frame_type=delta, frame_size=16980 bytes, packet_count=16
# num_media_packets=16, num_fec_packets=1
# sender_side_delay=76.46 ms, encoding_delay = 17.383 ms, pacing delay = 59.077 ms
# received encoded frame
# picture_id=19117, refs=[19116]
# frame_network_delay=0.654 ms, jitter_delay=0.12 ms, decoding_delay=4.761 ms, e2e_delay=81.995 ms
# --------------------------------
# Frame rtp_ts_capture = 3670057514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670060574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670063544
# rtp_ts=1478177533, frame_type=delta, frame_size=18466 bytes, packet_count=17
# num_media_packets=17, num_fec_packets=1
# sender_side_delay=87.805 ms, encoding_delay = 23.499 ms, pacing delay = 64.306 ms
# received encoded frame
# picture_id=19118, refs=[19117]
# frame_network_delay=0.607 ms, jitter_delay=0.079 ms, decoding_delay=6.084 ms, e2e_delay=94.575 ms
# --------------------------------
# Frame rtp_ts_capture = 3670066514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670069574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670072544
# rtp_ts=1478186533, frame_type=delta, frame_size=22942 bytes, packet_count=21
# num_media_packets=21, num_fec_packets=1
# sender_side_delay=103.567 ms, encoding_delay = 24.413 ms, pacing delay = 79.154 ms
# received encoded frame
# picture_id=19119, refs=[19118]
# frame_network_delay=0.62 ms, jitter_delay=0.179 ms, decoding_delay=7.528 ms, e2e_delay=111.894 ms
# --------------------------------
# Frame rtp_ts_capture = 3670075514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670078574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670081544
# rtp_ts=1478195533, frame_type=delta, frame_size=24170 bytes, packet_count=22
# num_media_packets=22, num_fec_packets=1
# sender_side_delay=107.432 ms, encoding_delay = 24.514 ms, pacing delay = 82.918 ms
# received encoded frame
# picture_id=19120, refs=[19119]
# frame_network_delay=0.609 ms, jitter_delay=0.145 ms, decoding_delay=6.783 ms, e2e_delay=114.969 ms
# --------------------------------
# Frame rtp_ts_capture = 3670084514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670087574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670090544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670093604
# rtp_ts=1478207593, frame_type=delta, frame_size=19749 bytes, packet_count=18
# num_media_packets=18, num_fec_packets=1
# sender_side_delay=85.95 ms, encoding_delay = 19.355 ms, pacing delay = 66.595 ms
# received encoded frame
# picture_id=19121, refs=[19120]
# frame_network_delay=0.665 ms, jitter_delay=0.024 ms, decoding_delay=6.781 ms, e2e_delay=93.42 ms
# --------------------------------
# Frame rtp_ts_capture = 3670096574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670099544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670102514
# rtp_ts=1478216503, frame_type=delta, frame_size=12628 bytes, packet_count=12
# num_media_packets=12, num_fec_packets=1
# sender_side_delay=58.199 ms, encoding_delay = 16.682 ms, pacing delay = 41.517 ms
# received encoded frame
# picture_id=19122, refs=[19121]
# frame_network_delay=0.545 ms, jitter_delay=0.087 ms, decoding_delay=6.027 ms, e2e_delay=64.858 ms
# --------------------------------
# Frame rtp_ts_capture = 3670105574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670108544
# rtp_ts=1478222533, frame_type=delta, frame_size=8131 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=42.275 ms, encoding_delay = 15.152 ms, pacing delay = 27.123 ms
# received encoded frame
# picture_id=19123, refs=[19122]
# frame_network_delay=0.722 ms, jitter_delay=0.095 ms, decoding_delay=5.427 ms, e2e_delay=48.519 ms
# --------------------------------
# Frame rtp_ts_capture = 3670111514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670114574
# rtp_ts=1478228563, frame_type=delta, frame_size=9696 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=47.338 ms, encoding_delay = 16.28 ms, pacing delay = 31.058 ms
# received encoded frame
# picture_id=19124, refs=[19123]
# frame_network_delay=0.793 ms, jitter_delay=0.154 ms, decoding_delay=5.897 ms, e2e_delay=54.182 ms
# --------------------------------
# Frame rtp_ts_capture = 3670117544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670120514
# rtp_ts=1478234503, frame_type=delta, frame_size=14845 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=72.846 ms, encoding_delay = 21.011 ms, pacing delay = 51.835 ms
# received encoded frame
# picture_id=19125, refs=[19124]
# frame_network_delay=0.747 ms, jitter_delay=0.147 ms, decoding_delay=8.647 ms, e2e_delay=82.387 ms
# --------------------------------
# Frame rtp_ts_capture = 3670123574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670126544
# rtp_ts=1478240533, frame_type=delta, frame_size=9790 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=50.169 ms, encoding_delay = 16.144 ms, pacing delay = 34.025 ms
# received encoded frame
# picture_id=19126, refs=[19125]
# frame_network_delay=0.684 ms, jitter_delay=0.143 ms, decoding_delay=6.439 ms, e2e_delay=57.435 ms
# --------------------------------
# Frame rtp_ts_capture = 3670129514
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670132574
# rtp_ts=1478246563, frame_type=delta, frame_size=9833 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=45.498 ms, encoding_delay = 14.925 ms, pacing delay = 30.573 ms
# received encoded frame
# picture_id=19127, refs=[19126]
# frame_network_delay=0.608 ms, jitter_delay=0.066 ms, decoding_delay=5.039 ms, e2e_delay=51.211 ms
# --------------------------------
# Frame rtp_ts_capture = 3670135544
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670138514
# rtp_ts=1478252503, frame_type=delta, frame_size=11434 bytes, packet_count=11
# num_media_packets=11, num_fec_packets=1
# sender_side_delay=53.785 ms, encoding_delay = 16.537 ms, pacing delay = 37.248 ms
# received encoded frame
# picture_id=19128, refs=[19127]
# frame_network_delay=0.669 ms, jitter_delay=0.056 ms, decoding_delay=5.365 ms, e2e_delay=59.875 ms
# --------------------------------
# Frame rtp_ts_capture = 3670141574
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 3670144544
# rtp_ts=1478258533, frame_type=delta, frame_size=13465 bytes, packet_count=13
# num_media_packets=13, num_fec_packets=1
# ...
# picture_id=19473, refs=[19472]
# frame_network_delay=0.53 ms, jitter_delay=0.068 ms, decoding_delay=4.371 ms, e2e_delay=29.678 ms
# --------------------------------
# Frame rtp_ts_capture = 3671188544
# rtp_ts=1479302533, frame_type=delta, frame_size=4826 bytes, packet_count=5
# num_media_packets=5, num_fec_packets=1
# sender_side_delay=21.485 ms, encoding_delay = 11.03 ms, pacing delay = 10.455 ms
# received encoded frame
# picture_id=19474, refs=[19473]
# frame_network_delay=0.433 ms, jitter_delay=0.058 ms, decoding_delay=4.261 ms, e2e_delay=26.237 ms
# --------------------------------
# Frame rtp_ts_capture = 3671191514
# rtp_ts=1479305503, frame_type=delta, frame_size=9280 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=27.632 ms, encoding_delay = 11.499 ms, pacing delay = 16.133 ms
# received encoded frame
# picture_id=19475, refs=[19474]
# frame_network_delay=0.503 ms, jitter_delay=0.114 ms, decoding_delay=4.072 ms, e2e_delay=32.321 ms
# --------------------------------
# Frame rtp_ts_capture = 3671194574
# rtp_ts=1479308563, frame_type=delta, frame_size=7461 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=22.131 ms, encoding_delay = 10.64 ms, pacing delay = 11.491 ms
# received encoded frame
# picture_id=19476, refs=[19475]
# frame_network_delay=0.865 ms, jitter_delay=0.069 ms, decoding_delay=3.399 ms, e2e_delay=26.464 ms
# --------------------------------
# Frame rtp_ts_capture = 3671197544
# rtp_ts=1479311533, frame_type=delta, frame_size=10259 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=28.518 ms, encoding_delay = 11.176 ms, pacing delay = 17.342 ms
# received encoded frame
# picture_id=19477, refs=[19476]
# frame_network_delay=0.597 ms, jitter_delay=0.058 ms, decoding_delay=3.903 ms, e2e_delay=33.076 ms
# --------------------------------
# Frame rtp_ts_capture = 3671200514
# rtp_ts=1479314503, frame_type=delta, frame_size=7533 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=21.876 ms, encoding_delay = 10.353 ms, pacing delay = 11.523 ms
# received encoded frame
# picture_id=19478, refs=[19477]
# frame_network_delay=0.821 ms, jitter_delay=0.061 ms, decoding_delay=3.773 ms, e2e_delay=26.531 ms
# --------------------------------
# Frame rtp_ts_capture = 3671203574
# rtp_ts=1479317563, frame_type=delta, frame_size=61400 bytes, packet_count=56
# num_media_packets=48, num_fec_packets=1
# sender_side_delay=134.493 ms, encoding_delay = 29.823 ms, pacing delay = 104.67 ms
# received encoded frame
# picture_id=19479, refs=[19478]
# frame_network_delay=0.519 ms, jitter_delay=0.158 ms, decoding_delay=12.547 ms, e2e_delay=147.717 ms
# --------------------------------
# Frame rtp_ts_capture = 3671206544
# rtp_ts=1479320533, frame_type=delta, frame_size=17386 bytes, packet_count=16
# num_media_packets=16, num_fec_packets=1
# sender_side_delay=134.542 ms, encoding_delay = 15.667 ms, pacing delay = 118.875 ms
# received encoded frame
# picture_id=19480, refs=[19479]
# frame_network_delay=1.256 ms, jitter_delay=0.034 ms, decoding_delay=6.481 ms, e2e_delay=142.313 ms
# --------------------------------
# Frame rtp_ts_capture = 3671209514
# rtp_ts=1479323503, frame_type=delta, frame_size=24239 bytes, packet_count=22
# num_media_packets=22, num_fec_packets=1
# sender_side_delay=143.305 ms, encoding_delay = 17.804 ms, pacing delay = 125.501 ms
# received encoded frame
# picture_id=19481, refs=[19480]
# frame_network_delay=0.488 ms, jitter_delay=0.093 ms, decoding_delay=7.348 ms, e2e_delay=151.234 ms
# --------------------------------
# Frame rtp_ts_capture = 3671212574
# rtp_ts=1479326563, frame_type=delta, frame_size=11006 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=134.456 ms, encoding_delay = 15.181 ms, pacing delay = 119.275 ms
# received encoded frame
# picture_id=19482, refs=[19481]
# frame_network_delay=1.014 ms, jitter_delay=0.143 ms, decoding_delay=6.128 ms, e2e_delay=141.741 ms
# --------------------------------
# Frame rtp_ts_capture = 3671215544
# rtp_ts=1479329533, frame_type=delta, frame_size=7399 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=111.004 ms, encoding_delay = 13.206 ms, pacing delay = 97.798 ms
# received encoded frame
# picture_id=19483, refs=[19482]
# frame_network_delay=0.871 ms, jitter_delay=0.021 ms, decoding_delay=5.831 ms, e2e_delay=117.727 ms
# --------------------------------
# Frame rtp_ts_capture = 3671218514
# rtp_ts=1479332503, frame_type=delta, frame_size=7463 bytes, packet_count=7
# num_media_packets=7, num_fec_packets=1
# sender_side_delay=92.135 ms, encoding_delay = 11.715 ms, pacing delay = 80.42 ms
# received encoded frame
# picture_id=19484, refs=[19483]
# frame_network_delay=0.543 ms, jitter_delay=0.089 ms, decoding_delay=4.706 ms, e2e_delay=97.473 ms
# --------------------------------
# Frame rtp_ts_capture = 3671221574
# rtp_ts=1479335563, frame_type=delta, frame_size=8348 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=76.258 ms, encoding_delay = 13.173 ms, pacing delay = 63.085 ms
# received encoded frame
# picture_id=19485, refs=[19484]
# frame_network_delay=0.514 ms, jitter_delay=0.105 ms, decoding_delay=4.852 ms, e2e_delay=81.729 ms
# --------------------------------
# Frame rtp_ts_capture = 3671224544
# rtp_ts=1479338533, frame_type=delta, frame_size=10751 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=62.583 ms, encoding_delay = 17.529 ms, pacing delay = 45.054 ms
# received encoded frame
# picture_id=19486, refs=[19485]
# frame_network_delay=0.562 ms, jitter_delay=0.063 ms, decoding_delay=6.165 ms, e2e_delay=69.373 ms
# --------------------------------
# Frame rtp_ts_capture = 3671227514
# rtp_ts=1479341503, frame_type=delta, frame_size=14040 bytes, packet_count=13
# num_media_packets=13, num_fec_packets=1
# sender_side_delay=55.872 ms, encoding_delay = 20.264 ms, pacing delay = 35.608 ms
# received encoded frame
# picture_id=19487, refs=[19486]
# frame_network_delay=0.68 ms, jitter_delay=0.108 ms, decoding_delay=6.422 ms, e2e_delay=63.082 ms
# --------------------------------
# Frame rtp_ts_capture = 3671230574
# rtp_ts=1479344563, frame_type=delta, frame_size=15274 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=49.704 ms, encoding_delay = 18.149 ms, pacing delay = 31.555 ms
# received encoded frame
# picture_id=19488, refs=[19487]
# frame_network_delay=0.612 ms, jitter_delay=0.126 ms, decoding_delay=6.782 ms, e2e_delay=57.224 ms
# --------------------------------
# Frame rtp_ts_capture = 3671233544
# rtp_ts=1479347533, frame_type=delta, frame_size=17353 bytes, packet_count=16
# num_media_packets=16, num_fec_packets=1
# sender_side_delay=61.045 ms, encoding_delay = 29.593 ms, pacing delay = 31.452 ms
# received encoded frame
# picture_id=19489, refs=[19488]
# frame_network_delay=0.823 ms, jitter_delay=0.088 ms, decoding_delay=8.342 ms, e2e_delay=70.298 ms
# --------------------------------
# Frame rtp_ts_capture = 3671236514
# rtp_ts=1479350503, frame_type=delta, frame_size=14590 bytes, packet_count=14
# num_media_packets=14, num_fec_packets=1
# sender_side_delay=54.437 ms, encoding_delay = 23.286 ms, pacing delay = 31.151 ms
# received encoded frame
# picture_id=19490, refs=[19489]
# frame_network_delay=0.853 ms, jitter_delay=0.178 ms, decoding_delay=7.124 ms, e2e_delay=62.592 ms
# --------------------------------
# Frame rtp_ts_capture = 3671239574
# rtp_ts=1479353563, frame_type=delta, frame_size=13670 bytes, packet_count=13
# num_media_packets=13, num_fec_packets=1
# sender_side_delay=46.58 ms, encoding_delay = 22.211 ms, pacing delay = 24.369 ms
# received encoded frame
# picture_id=19491, refs=[19490]
# frame_network_delay=0.644 ms, jitter_delay=0.101 ms, decoding_delay=7.837 ms, e2e_delay=55.162 ms
# --------------------------------
# Frame rtp_ts_capture = 3671242544
# rtp_ts=1479356533, frame_type=delta, frame_size=13115 bytes, packet_count=12
# num_media_packets=12, num_fec_packets=1
# sender_side_delay=51.312 ms, encoding_delay = 25.392 ms, pacing delay = 25.92 ms
# received encoded frame
# picture_id=19492, refs=[19491]
# frame_network_delay=0.837 ms, jitter_delay=0.212 ms, decoding_delay=7.457 ms, e2e_delay=59.818 ms
# --------------------------------
# Frame rtp_ts_capture = 3671245514
# rtp_ts=1479359503, frame_type=delta, frame_size=11562 bytes, packet_count=11
# num_media_packets=11, num_fec_packets=1
# sender_side_delay=43.473 ms, encoding_delay = 21.995 ms, pacing delay = 21.478 ms
# received encoded frame
# picture_id=19493, refs=[19492]
# frame_network_delay=0.688 ms, jitter_delay=0.11 ms, decoding_delay=5.745 ms, e2e_delay=50.016 ms
# --------------------------------
# Frame rtp_ts_capture = 3671248574
# rtp_ts=1479362563, frame_type=delta, frame_size=10534 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=45.65 ms, encoding_delay = 24.077 ms, pacing delay = 21.573 ms
# received encoded frame
# picture_id=19494, refs=[19493]
# frame_network_delay=0.892 ms, jitter_delay=0.177 ms, decoding_delay=6.321 ms, e2e_delay=53.04 ms
# --------------------------------
# Frame rtp_ts_capture = 3671251544
# rtp_ts=1479365533, frame_type=delta, frame_size=8804 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=35.156 ms, encoding_delay = 18.564 ms, pacing delay = 16.592 ms
# received encoded frame
# picture_id=19495, refs=[19494]
# frame_network_delay=1.012 ms, jitter_delay=0.108 ms, decoding_delay=6.158 ms, e2e_delay=42.434 ms
# --------------------------------
# Frame rtp_ts_capture = 3671254514
# rtp_ts=1479368503, frame_type=delta, frame_size=11481 bytes, packet_count=11
# num_media_packets=11, num_fec_packets=1
# sender_side_delay=43.062 ms, encoding_delay = 21.474 ms, pacing delay = 21.588 ms
# received encoded frame
# picture_id=19496, refs=[19495]
# frame_network_delay=0.841 ms, jitter_delay=0.117 ms, decoding_delay=7.21 ms, e2e_delay=51.23 ms
# --------------------------------
# Frame rtp_ts_capture = 3671257574
# rtp_ts=1479371563, frame_type=delta, frame_size=9020 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=36.711 ms, encoding_delay = 20.579 ms, pacing delay = 16.132 ms
# received encoded frame
# picture_id=19497, refs=[19496]
# frame_network_delay=0.907 ms, jitter_delay=0.218 ms, decoding_delay=6.625 ms, e2e_delay=44.461 ms
# --------------------------------
# Frame rtp_ts_capture = 3671260544
# rtp_ts=1479374533, frame_type=delta, frame_size=8905 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=34.32 ms, encoding_delay = 18.601 ms, pacing delay = 15.719 ms
# received encoded frame
# picture_id=19498, refs=[19497]
# frame_network_delay=1.031 ms, jitter_delay=0.141 ms, decoding_delay=6.685 ms, e2e_delay=42.177 ms
# --------------------------------
# Frame rtp_ts_capture = 3671263514
# rtp_ts=1479377503, frame_type=delta, frame_size=6285 bytes, packet_count=6
# num_media_packets=6, num_fec_packets=1
# sender_side_delay=28.781 ms, encoding_delay = 18.585 ms, pacing delay = 10.196 ms
# received encoded frame
# picture_id=19499, refs=[19498]
# frame_network_delay=0.836 ms, jitter_delay=0.161 ms, decoding_delay=6.129 ms, e2e_delay=35.907 ms
# --------------------------------
# Frame rtp_ts_capture = 3671266574
# rtp_ts=1479380563, frame_type=delta, frame_size=1613 bytes, packet_count=2
# num_media_packets=2, num_fec_packets=1
# sender_side_delay=19.106 ms, encoding_delay = 14.364 ms, pacing delay = 4.742 ms
# received encoded frame
# picture_id=19500, refs=[19499]
# frame_network_delay=0.737 ms, jitter_delay=0.145 ms, decoding_delay=4.476 ms, e2e_delay=24.464 ms
# --------------------------------
# Frame rtp_ts_capture = 3671269544
# rtp_ts=1479383533, frame_type=delta, frame_size=12401 bytes, packet_count=12
# num_media_packets=12, num_fec_packets=1
# sender_side_delay=45.207 ms, encoding_delay = 24.792 ms, pacing delay = 20.415 ms
# received encoded frame
# picture_id=19501, refs=[19500]
# frame_network_delay=0.908 ms, jitter_delay=0.204 ms, decoding_delay=7.14 ms, e2e_delay=53.459 ms
# --------------------------------
# Frame rtp_ts_capture = 3671272514
# rtp_ts=1479386503, frame_type=delta, frame_size=4078 bytes, packet_count=4
# num_media_packets=4, num_fec_packets=1
# sender_side_delay=22.57 ms, encoding_delay = 15.69 ms, pacing delay = 6.88 ms
# received encoded frame
# picture_id=19502, refs=[19501]
# frame_network_delay=0.816 ms, jitter_delay=0.096 ms, decoding_delay=4.536 ms, e2e_delay=28.018 ms
# --------------------------------
# Frame rtp_ts_capture = 3671275574
# rtp_ts=1479389563, frame_type=delta, frame_size=7845 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=40.083 ms, encoding_delay = 24.244 ms, pacing delay = 15.839 ms
# received encoded frame
# picture_id=19503, refs=[19502]
# frame_network_delay=0.674 ms, jitter_delay=0.094 ms, decoding_delay=6.651 ms, e2e_delay=47.502 ms
# --------------------------------
# Frame rtp_ts_capture = 3671278544
# rtp_ts=1479392533, frame_type=delta, frame_size=9117 bytes, packet_count=9
# num_media_packets=9, num_fec_packets=1
# sender_side_delay=36.159 ms, encoding_delay = 19.598 ms, pacing delay = 16.561 ms
# received encoded frame
# picture_id=19504, refs=[19503]
# frame_network_delay=0.991 ms, jitter_delay=0.084 ms, decoding_delay=7.088 ms, e2e_delay=44.322 ms
# --------------------------------
# Frame rtp_ts_capture = 3671281514
# rtp_ts=1479395503, frame_type=delta, frame_size=7789 bytes, packet_count=8
# num_media_packets=8, num_fec_packets=1
# sender_side_delay=34.993 ms, encoding_delay = 19.498 ms, pacing delay = 15.495 ms
# received encoded frame
# picture_id=19505, refs=[19504]
# frame_network_delay=0.94 ms, jitter_delay=0.112 ms, decoding_delay=6.744 ms, e2e_delay=42.789 ms
# --------------------------------
# Frame rtp_ts_capture = 3671284574
# rtp_ts=1479398563, frame_type=delta, frame_size=18224 bytes, packet_count=17
# num_media_packets=17, num_fec_packets=1
# sender_side_delay=49.125 ms, encoding_delay = 19.627 ms, pacing delay = 29.498 ms
# received encoded frame
# picture_id=19506, refs=[19505]
# frame_network_delay=0.657 ms, jitter_delay=0.158 ms, decoding_delay=6.555 ms, e2e_delay=56.495 ms
# --------------------------------
# Frame rtp_ts_capture = 3671287544
# rtp_ts=1479401533, frame_type=delta, frame_size=12793 bytes, packet_count=12
# num_media_packets=12, num_fec_packets=1
# sender_side_delay=37.373 ms, encoding_delay = 12.15 ms, pacing delay = 25.223 ms
# received encoded frame
# picture_id=19507, refs=[19506]
# frame_network_delay=1.024 ms, jitter_delay=0.028 ms, decoding_delay=6.344 ms, e2e_delay=44.769 ms
# --------------------------------
# Frame rtp_ts_capture = 3671290514
# rtp_ts=1479404503, frame_type=delta, frame_size=10246 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=27.423 ms, encoding_delay = 11.706 ms, pacing delay = 15.717 ms
# received encoded frame
# picture_id=19508, refs=[19507]
# frame_network_delay=0.732 ms, jitter_delay=0.025 ms, decoding_delay=5.441 ms, e2e_delay=33.621 ms
# --------------------------------
# Frame rtp_ts_capture = 3671293574
# rtp_ts=1479407563, frame_type=delta, frame_size=11099 bytes, packet_count=10
# num_media_packets=10, num_fec_packets=1
# sender_side_delay=41.708 ms, encoding_delay = 20.075 ms, pacing delay = 21.633 ms
# received encoded frame
# picture_id=19509, refs=[19508]
# frame_network_delay=0.864 ms, jitter_delay=0.075 ms, decoding_delay=7.642 ms, e2e_delay=50.289 ms
# --------------------------------
# Frame rtp_ts_capture = 3671296544
# rtp_ts=1479410533, frame_type=delta, frame_size=3132 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=18.896 ms, encoding_delay = 13.367 ms, pacing delay = 5.529 ms
# received encoded frame
# picture_id=19510, refs=[19509]
# frame_network_delay=0.71 ms, jitter_delay=0.067 ms, decoding_delay=4.597 ms, e2e_delay=24.27 ms
# --------------------------------
# Frame rtp_ts_capture = 3671299514
# rtp_ts=1479413503, frame_type=delta, frame_size=2642 bytes, packet_count=3
# num_media_packets=3, num_fec_packets=1
# sender_side_delay=17.183 ms, encoding_delay = 12.599 ms, pacing delay = 4.584 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 3671302574
# rtp_ts=1479416563, frame_type=delta, frame_size=12692 bytes, packet_count=12
#     During sending!
