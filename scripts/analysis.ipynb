# %%
import json
import pandas as pd
import numpy as np

def load_events(path):
    with open(path) as f:
        data = json.load(f)
    return data["traceEvents"]

def flatten_event(e, source):
    """展开 args，仅保留 name, ts, args.xxx，并增加 from 字段"""

    out = {
        "name": e.get("name"),
        "ts": e.get("ts"),
        "from": source, 
    }

    args = e.get("args", {})
    if isinstance(args, dict):
        for k, v in args.items():
            out[f"args.{k}"] = v

    return out

def preprocess_events(events):
    tmp = pd.DataFrame(events)
    args_uint64 = tmp.dtypes[tmp.dtypes == "float64"]
    print(args_uint64.index.tolist())
    for e in events:
        for arg in args_uint64.index.tolist():
            if arg not in e:
                e[arg] = 0

path_sender = "../expr/trace_sender.json"
path_receiver = "../expr/trace_receiver.json"

# 读取原始数据
events_sender = load_events(path_sender)
events_receiver = load_events(path_receiver)

# 展开 + 加 from 字段
flat_sender = [flatten_event(e, "sender") for e in events_sender]
flat_receiver = [flatten_event(e, "receiver") for e in events_receiver]

# 合并两个列表
all_events = flat_sender + flat_receiver

preprocess_events(all_events)

df = pd.DataFrame(all_events)

df.dtypes
df["name"].unique().tolist()
# Out:
# ['args.last_target_bps', 'args.last_stable_target_bps', 'args.last_fraction_loss_', 'args.last_rtt_ms', 'args.value', 'args.update_target_bitrate_bps', 'args.encoder_target_rate_bps', 'args.protection_bitrate_bps', 'args.encoder_overhead_rate_bps', 'args.post_encode_overhead_bps', 'args.rtp_ts_capture', 'args.rtp_ts', 'args.capture_time_ms', 'args.frame_size', 'args.packet_count', 'args.transport_seq', 'args.is_received', 'args.last_rtp_ts', 'args.num_media_packets', 'args.num_fec_packets', 'args.param_fec_rate', 'args.fec_payload_type', 'args.fec_ssrc', 'args.protected_frame_rtp_ts', 'args.rtt_ms', 'args.total_delta', 'args.lost_delta', 'args.payload_type', 'args.is_recovered', 'args.picture_id', 'args.render_time_ms', 'args.fec_seq', 'args.scheduled_decode_time_ms']
# ['BitrateAllocator:OnChanged',
#  'rtt_ms',
#  'loss',
#  'bwe_bps',
#  'Sender:AllocateBitrate',
#  'Frame:Captured',
#  'Frame:Start Encode',
#  'Frame:Encoded',
#  'Frame:Packetization',
#  'Frame:Dropped',
#  'Packet:Sent',
#  'RTCP:TransportPacketFeedback',
#  'RTCP:NACK',
#  'Frame:Generate FEC',
#  'FlexFEC:GetFecPackets',
#  'RTCP:Receive RTT',
#  'RTCP:ReportBlocksTransportLossReport',
#  'Packet:Received RTP',
#  'FlexFEC:Receive RTP Packet',
#  'RTCP:SendNack',
#  'Frame:Received EncodedFrame',
#  'Frame:ToFrameBuffer',
#  'Frame:ReadytoDecode',
#  'Frame:Start Decode',
#  'FlexFEC:Receive FEC Packet',
#  'FlexFEC:Recover Packet',
#  'Frame:Decoded',
#  'Frame:Scheduled for Decode']

# %%
all_frame_rtp_ts_capture = df[df["name"] == "Frame:Captured"]["args.rtp_ts_capture"].unique()
all_frame_rtp_ts_capture.sort()

for rtp_ts_capture in all_frame_rtp_ts_capture:
    print("--------------------------------")
    print("Frame rtp_ts_capture =", rtp_ts_capture)
    event_frame_captured = df[(df["name"] == "Frame:Captured") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    event_frame_start_encode = df[(df["name"] == "Frame:Start Encode") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
    
    if event_frame_start_encode.empty:
        event_frame_dropped = df[(df["name"] == "Frame:Dropped") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        reason = event_frame_dropped["args.reason"].values[0] 
        print(f"    dropped before encoding, reason={reason}!")
        continue
    else:
        event_frame_encoded = df[(df["name"] == "Frame:Encoded") & (df["args.rtp_ts_capture"] == rtp_ts_capture)]
        
        if event_frame_encoded.empty:
            print(f"    dropped by encoder!")
            continue
        
        ts_captured = event_frame_captured["ts"].values[0]
        ts_encoded = event_frame_encoded["ts"].values[0]
        rtp_ts = event_frame_encoded["args.rtp_ts"].values[0]
        frame_type = event_frame_encoded["args.frame_type"].values[0]
        frame_size = event_frame_encoded["args.frame_size"].values[0]
        event_frame_packetization = df[(df["name"] == "Frame:Packetization") & (df["args.rtp_ts"] == rtp_ts)]
        packet_count = event_frame_packetization["args.packet_count"].values[0]
        event_frame_generate_fec = df[(df["name"] == "Frame:Generate FEC") & (df["args.last_rtp_ts"] == rtp_ts)]
        num_media_packets = event_frame_generate_fec["args.num_media_packets"].values[0] if not event_frame_generate_fec.empty else 0 
        num_fec_packets = event_frame_generate_fec["args.num_fec_packets"].values[0] if not event_frame_generate_fec.empty else 0

        events_frame_all_packet_sent = df[(df["name"] == "Packet:Sent") & ((df["args.rtp_ts"] == rtp_ts) | (df["args.protected_frame_rtp_ts"] == rtp_ts))]
        events_frame_media_packet_sent = events_frame_all_packet_sent[events_frame_all_packet_sent["args.packet_type"] == "video"]
        
        
        events_frame_all_packet_sent = events_frame_all_packet_sent.sort_values(by="ts")
        events_frame_media_packet_sent = events_frame_media_packet_sent.sort_values(by="ts") 
        
        ts_first_packet_sent = events_frame_all_packet_sent["ts"].values[0] if not events_frame_all_packet_sent.empty else None 
        ts_last_media_packet_sent = events_frame_media_packet_sent["ts"].values[-1] if not events_frame_media_packet_sent.empty else None
        
        encoding_delay = ts_encoded - ts_captured
        pacing_delay = ts_last_media_packet_sent - ts_encoded if ts_last_media_packet_sent is not None else 0

        print(f"rtp_ts={rtp_ts}, frame_type={frame_type}, frame_size={frame_size} bytes, packet_count={packet_count}")
        
        print("all related packets sent:") 
        for _, event_packet_sent in events_frame_all_packet_sent.iterrows():
            seq = event_packet_sent["args.seq"]
            packet_type = event_packet_sent["args.packet_type"]
            transport_seq = event_packet_sent["args.transport_seq"]
            ts_packet_sent = event_packet_sent["ts"]
            print(f"    Packet seq={seq}, packet_type={packet_type}, transport_seq={transport_seq}, delay_since_capture={(ts_packet_sent - ts_captured)/1000} ms")
            
            if packet_type == "video": 
                event_packet_received = df[(df["name"] == "Packet:Received RTP") & (df["args.seq"] == seq) & (df["from"] == "receiver")]
                if not event_packet_received.empty:
                    ts_received = event_packet_received["ts"].values[0]
                    is_recovered = event_packet_received["args.is_recovered"].values[0]
                    print(f"    received at receiver, on-way-delay={(ts_received - ts_packet_sent)/1000} ms, is_recovered={is_recovered}")
                else:
                    print(f"    NOT received at receiver")
            elif packet_type == "fec":
                event_fec_packet_received = df[(df["name"] == "FlexFEC:Receive FEC Packet") & (df["args.fec_seq"] == seq) & (df["from"] == "receiver")]
                if not event_fec_packet_received.empty:
                    ts_received = event_fec_packet_received["ts"].values[0]
                    protected_seqs = event_fec_packet_received["args.protected_seqs"].values[0]
                    print(f"    recovered at receiver, on-way-delay={(ts_received - ts_packet_sent)/1000} ms")
                else:
                    print(f"    NOT received at receiver")
            elif packet_type == "rtx":
                event_rtx_packet_received = df[(df["name"] == "RtxReceiveStream:OnRtpPacket") & (df["args.rtx_seq"] == seq) & (df["from"] == "receiver")]
                if not event_rtx_packet_received.empty:
                    ts_received = event_rtx_packet_received["ts"].values[0]
                    protected_seq = event_rtx_packet_received["args.seq"].values[0]
                    print(f"    received at receiver, on-way-delay={(ts_received - ts_packet_sent)/1000} ms, retrans seq={protected_seq}")
                else:
                    print(f"    NOT received at receiver")
             
            
        if ts_last_media_packet_sent is None:
            print(f"    Not start sending!")
            continue 
        
        print(f"num_media_packets={num_media_packets}, num_fec_packets={num_fec_packets}")
        print(f"encoding_delay = {encoding_delay/1000} ms, pacing delay = {pacing_delay/1000} ms")
         
        event_frame_received_encoded = df[(df["name"] == "Frame:Received EncodedFrame") & (df["args.rtp_ts"] == rtp_ts)]
        if event_frame_received_encoded.empty:
            print(f"    Not received at receiver!")
            continue
        
        picture_id = event_frame_received_encoded["args.picture_id"].values[0]
        refs = event_frame_received_encoded["args.refs"].values[0]
        ts_received_encoded = event_frame_received_encoded["ts"].values[0]
        
        print(f"received encoded frame")
        
        event_frame_ready_to_decode = df[(df["name"] == "Frame:ReadytoDecode") & (df["args.rtp_ts"] == rtp_ts)] 
        event_frame_start_decode = df[(df["name"] == "Frame:Start Decode") & (df["args.rtp_ts"] == rtp_ts)]
        event_frame_decoded = df[(df["name"] == "Frame:Decoded") & (df["args.rtp_ts"] == rtp_ts)]
        
        if event_frame_decoded.empty:
            print(f"    Not decoded at receiver!")
            continue 
         
        ts_ready_to_decode = event_frame_ready_to_decode["ts"].values[0]
        ts_start_decode = event_frame_start_decode["ts"].values[0]
        ts_decoded = event_frame_decoded["ts"].values[0]
        
        frame_network_delay = ts_received_encoded - ts_last_media_packet_sent
        jitter_delay = ts_start_decode - ts_received_encoded
        decoding_delay = ts_decoded - ts_start_decode
        e2e_delay = ts_decoded - ts_captured
        print(f"picture_id={picture_id}, refs={refs}")
        
        print(f"frame_network_delay={frame_network_delay/1000} ms")
        print(f"jitter_delay={jitter_delay/1000} ms")
        print(f"decoding_delay={decoding_delay/1000} ms")
        print(f"e2e_delay={e2e_delay/1000} ms")
# Out:
# --------------------------------
# Frame rtp_ts_capture = 393975490
# rtp_ts=3844725266, frame_type=key, frame_size=52321 bytes, packet_count=48
# all related packets sent:
#     Packet seq=22310, packet_type=video, transport_seq=2, delay_since_capture=73.665 ms
#     received at receiver, on-way-delay=60.823 ms, is_recovered=0
#     Packet seq=22311, packet_type=video, transport_seq=3, delay_since_capture=83.415 ms
#     received at receiver, on-way-delay=60.578 ms, is_recovered=0
#     Packet seq=22312, packet_type=video, transport_seq=4, delay_since_capture=93.352 ms
#     received at receiver, on-way-delay=60.545 ms, is_recovered=0
#     Packet seq=22313, packet_type=video, transport_seq=5, delay_since_capture=103.954 ms
#     received at receiver, on-way-delay=234.232 ms, is_recovered=1
#     Packet seq=22314, packet_type=video, transport_seq=7, delay_since_capture=115.505 ms
#     received at receiver, on-way-delay=60.598 ms, is_recovered=0
#     Packet seq=22315, packet_type=video, transport_seq=8, delay_since_capture=122.087 ms
#     received at receiver, on-way-delay=60.628 ms, is_recovered=0
#     Packet seq=22316, packet_type=video, transport_seq=9, delay_since_capture=127.636 ms
#     received at receiver, on-way-delay=60.523 ms, is_recovered=0
#     Packet seq=22317, packet_type=video, transport_seq=10, delay_since_capture=132.268 ms
#     received at receiver, on-way-delay=60.444 ms, is_recovered=0
#     Packet seq=22318, packet_type=video, transport_seq=11, delay_since_capture=137.801 ms
#     received at receiver, on-way-delay=60.498 ms, is_recovered=0
#     Packet seq=22319, packet_type=video, transport_seq=13, delay_since_capture=146.823 ms
#     received at receiver, on-way-delay=60.598 ms, is_recovered=0
#     Packet seq=22320, packet_type=video, transport_seq=14, delay_since_capture=157.225 ms
#     received at receiver, on-way-delay=60.575 ms, is_recovered=0
#     Packet seq=22321, packet_type=video, transport_seq=15, delay_since_capture=167.55 ms
#     received at receiver, on-way-delay=60.688 ms, is_recovered=0
#     Packet seq=22322, packet_type=video, transport_seq=16, delay_since_capture=176.972 ms
#     received at receiver, on-way-delay=60.663 ms, is_recovered=0
#     Packet seq=22323, packet_type=video, transport_seq=18, delay_since_capture=187.785 ms
#     received at receiver, on-way-delay=60.546 ms, is_recovered=0
#     Packet seq=22324, packet_type=video, transport_seq=19, delay_since_capture=194.11 ms
#     received at receiver, on-way-delay=60.597 ms, is_recovered=0
#     Packet seq=22325, packet_type=video, transport_seq=20, delay_since_capture=199.419 ms
#     received at receiver, on-way-delay=60.635 ms, is_recovered=0
#     Packet seq=22326, packet_type=video, transport_seq=21, delay_since_capture=204.772 ms
#     received at receiver, on-way-delay=60.67 ms, is_recovered=0
#     Packet seq=22327, packet_type=video, transport_seq=22, delay_since_capture=210.12 ms
#     received at receiver, on-way-delay=60.625 ms, is_recovered=0
#     Packet seq=4915, packet_type=rtx, transport_seq=23, delay_since_capture=277.496 ms
#     NOT received at receiver
#     Packet seq=22328, packet_type=video, transport_seq=24, delay_since_capture=282.134 ms
#     received at receiver, on-way-delay=60.559 ms, is_recovered=0
#     Packet seq=22329, packet_type=video, transport_seq=25, delay_since_capture=287.617 ms
#     received at receiver, on-way-delay=60.539 ms, is_recovered=0
#     Packet seq=22330, packet_type=video, transport_seq=26, delay_since_capture=297.243 ms
#     received at receiver, on-way-delay=60.649 ms, is_recovered=0
#     Packet seq=22331, packet_type=video, transport_seq=27, delay_since_capture=306.914 ms
#     received at receiver, on-way-delay=60.541 ms, is_recovered=0
#     Packet seq=22332, packet_type=video, transport_seq=28, delay_since_capture=315.727 ms
#     received at receiver, on-way-delay=60.753 ms, is_recovered=0
#     Packet seq=22333, packet_type=video, transport_seq=29, delay_since_capture=325.258 ms
#     received at receiver, on-way-delay=60.584 ms, is_recovered=0
#     Packet seq=4916, packet_type=rtx, transport_seq=30, delay_since_capture=333.804 ms
#     NOT received at receiver
#     Packet seq=22334, packet_type=video, transport_seq=31, delay_since_capture=338.591 ms
#     received at receiver, on-way-delay=60.542 ms, is_recovered=0
#     Packet seq=22335, packet_type=video, transport_seq=32, delay_since_capture=343.956 ms
#     received at receiver, on-way-delay=60.661 ms, is_recovered=0
#     Packet seq=22336, packet_type=video, transport_seq=33, delay_since_capture=349.404 ms
#     received at receiver, on-way-delay=60.69 ms, is_recovered=0
#     Packet seq=22337, packet_type=video, transport_seq=34, delay_since_capture=353.958 ms
#     received at receiver, on-way-delay=60.575 ms, is_recovered=0
#     Packet seq=22338, packet_type=video, transport_seq=35, delay_since_capture=359.48 ms
#     received at receiver, on-way-delay=60.6 ms, is_recovered=0
#     Packet seq=22339, packet_type=video, transport_seq=36, delay_since_capture=361.863 ms
#     received at receiver, on-way-delay=60.588 ms, is_recovered=0
#     Packet seq=22340, packet_type=video, transport_seq=37, delay_since_capture=369.359 ms
#     received at receiver, on-way-delay=60.699 ms, is_recovered=0
#     Packet seq=22341, packet_type=video, transport_seq=38, delay_since_capture=374.694 ms
#     received at receiver, on-way-delay=60.692 ms, is_recovered=0
#     Packet seq=22342, packet_type=video, transport_seq=39, delay_since_capture=379.191 ms
#     received at receiver, on-way-delay=60.618 ms, is_recovered=0
#     Packet seq=22343, packet_type=video, transport_seq=40, delay_since_capture=384.557 ms
#     received at receiver, on-way-delay=60.614 ms, is_recovered=0
#     Packet seq=22344, packet_type=video, transport_seq=41, delay_since_capture=388.584 ms
#     received at receiver, on-way-delay=60.74 ms, is_recovered=0
#     Packet seq=22345, packet_type=video, transport_seq=42, delay_since_capture=394.239 ms
#     received at receiver, on-way-delay=60.552 ms, is_recovered=0
#     Packet seq=22346, packet_type=video, transport_seq=43, delay_since_capture=399.54 ms
#     received at receiver, on-way-delay=60.678 ms, is_recovered=0
#     Packet seq=22347, packet_type=video, transport_seq=44, delay_since_capture=399.585 ms
#     received at receiver, on-way-delay=60.85 ms, is_recovered=0
#     Packet seq=22348, packet_type=video, transport_seq=45, delay_since_capture=403.888 ms
#     received at receiver, on-way-delay=60.469 ms, is_recovered=0
#     Packet seq=22349, packet_type=video, transport_seq=46, delay_since_capture=409.122 ms
#     received at receiver, on-way-delay=60.51 ms, is_recovered=0
#     Packet seq=22350, packet_type=video, transport_seq=47, delay_since_capture=414.4 ms
#     received at receiver, on-way-delay=60.528 ms, is_recovered=0
#     Packet seq=22351, packet_type=video, transport_seq=48, delay_since_capture=419.679 ms
#     received at receiver, on-way-delay=60.572 ms, is_recovered=0
#     Packet seq=22352, packet_type=video, transport_seq=49, delay_since_capture=423.973 ms
#     received at receiver, on-way-delay=60.497 ms, is_recovered=0
#     Packet seq=22353, packet_type=video, transport_seq=50, delay_since_capture=429.324 ms
#     received at receiver, on-way-delay=60.535 ms, is_recovered=0
#     Packet seq=22354, packet_type=video, transport_seq=51, delay_since_capture=434.662 ms
#     received at receiver, on-way-delay=60.586 ms, is_recovered=0
#     Packet seq=22355, packet_type=video, transport_seq=52, delay_since_capture=439.191 ms
#     received at receiver, on-way-delay=60.539 ms, is_recovered=0
#     Packet seq=22356, packet_type=video, transport_seq=53, delay_since_capture=444.139 ms
#     received at receiver, on-way-delay=60.514 ms, is_recovered=0
#     Packet seq=22357, packet_type=video, transport_seq=54, delay_since_capture=446.218 ms
#     received at receiver, on-way-delay=60.592 ms, is_recovered=0
#     Packet seq=1225, packet_type=fec, transport_seq=56, delay_since_capture=459.303 ms
#     NOT received at receiver
# num_media_packets=48, num_fec_packets=1
# encoding_delay = 69.499 ms, pacing delay = 376.719 ms
# received encoded frame
# picture_id=5598, refs=[]
# frame_network_delay=61.049 ms
# jitter_delay=0.572 ms
# decoding_delay=35.505 ms
# e2e_delay=543.344 ms
# --------------------------------
# Frame rtp_ts_capture = 393978460
#     dropped before encoding, reason=encoder_blocked!
# --------------------------------
# Frame rtp_ts_capture = 393981430
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393984490
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393987460
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393990430
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393993490
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393996460
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 393999430
#     dropped before encoding, reason=cwnd_pushback!
# --------------------------------
# Frame rtp_ts_capture = 394002490
# rtp_ts=3844752266, frame_type=delta, frame_size=23856 bytes, packet_count=22
# all related packets sent:
#     Packet seq=22358, packet_type=video, transport_seq=55, delay_since_capture=153.731 ms
#     received at receiver, on-way-delay=60.637 ms, is_recovered=0
#     Packet seq=22359, packet_type=video, transport_seq=57, delay_since_capture=164.74 ms
#     received at receiver, on-way-delay=60.716 ms, is_recovered=0
#     Packet seq=22360, packet_type=video, transport_seq=58, delay_since_capture=164.805 ms
#     received at receiver, on-way-delay=60.908 ms, is_recovered=0
#     Packet seq=22361, packet_type=video, transport_seq=59, delay_since_capture=170.311 ms
#     received at receiver, on-way-delay=60.553 ms, is_recovered=0
#     Packet seq=22362, packet_type=video, transport_seq=60, delay_since_capture=175.73 ms
#     received at receiver, on-way-delay=60.565 ms, is_recovered=0
#     Packet seq=22363, packet_type=video, transport_seq=61, delay_since_capture=179.134 ms
#     received at receiver, on-way-delay=60.616 ms, is_recovered=0
#     Packet seq=22364, packet_type=video, transport_seq=62, delay_since_capture=186.579 ms
#     received at receiver, on-way-delay=60.603 ms, is_recovered=0
#     Packet seq=22365, packet_type=video, transport_seq=63, delay_since_capture=190.856 ms
#     received at receiver, on-way-delay=60.518 ms, is_recovered=0
#     Packet seq=22366, packet_type=video, transport_seq=64, delay_since_capture=196.093 ms
#     received at receiver, on-way-delay=60.494 ms, is_recovered=0
#     Packet seq=22367, packet_type=video, transport_seq=65, delay_since_capture=201.475 ms
#     received at receiver, on-way-delay=60.5 ms, is_recovered=0
#     Packet seq=22368, packet_type=video, transport_seq=66, delay_since_capture=204.006 ms
#     received at receiver, on-way-delay=60.537 ms, is_recovered=0
#     Packet seq=22369, packet_type=video, transport_seq=67, delay_since_capture=206.496 ms
#     received at receiver, on-way-delay=60.493 ms, is_recovered=0
#     Packet seq=22370, packet_type=video, transport_seq=68, delay_since_capture=211.951 ms
#     received at receiver, on-way-delay=60.455 ms, is_recovered=0
#     Packet seq=22371, packet_type=video, transport_seq=69, delay_since_capture=217.382 ms
#     received at receiver, on-way-delay=60.5 ms, is_recovered=0
#     Packet seq=22372, packet_type=video, transport_seq=70, delay_since_capture=222.856 ms
#     received at receiver, on-way-delay=60.476 ms, is_recovered=0
#     Packet seq=22373, packet_type=video, transport_seq=71, delay_since_capture=228.667 ms
#     received at receiver, on-way-delay=60.505 ms, is_recovered=0
#     Packet seq=22374, packet_type=video, transport_seq=72, delay_since_capture=234.114 ms
#     received at receiver, on-way-delay=60.478 ms, is_recovered=0
#     Packet seq=22375, packet_type=video, transport_seq=73, delay_since_capture=239.535 ms
#     received at receiver, on-way-delay=60.621 ms, is_recovered=0
#     Packet seq=22376, packet_type=video, transport_seq=74, delay_since_capture=239.602 ms
#     received at receiver, on-way-delay=60.853 ms, is_recovered=0
#     Packet seq=22377, packet_type=video, transport_seq=75, delay_since_capture=243.856 ms
#     received at receiver, on-way-delay=60.478 ms, is_recovered=0
#     Packet seq=22378, packet_type=video, transport_seq=76, delay_since_capture=249.32 ms
#     received at receiver, on-way-delay=60.419 ms, is_recovered=0
#     Packet seq=22379, packet_type=video, transport_seq=77, delay_since_capture=254.89 ms
#     received at receiver, on-way-delay=60.489 ms, is_recovered=0
#     Packet seq=1226, packet_type=fec, transport_seq=79, delay_since_capture=265.71 ms
#     NOT received at receiver
# num_media_packets=22, num_fec_packets=1
# encoding_delay = 15.44 ms, pacing delay = 239.45 ms
# received encoded frame
# picture_id=5599, refs=[5598]
# frame_network_delay=60.686 ms
# jitter_delay=0.453 ms
# decoding_delay=21.299 ms
# e2e_delay=337.328 ms
# --------------------------------
# Frame rtp_ts_capture = 394005460
# rtp_ts=3844755236, frame_type=delta, frame_size=31568 bytes, packet_count=29
# all related packets sent:
#     Packet seq=22380, packet_type=video, transport_seq=78, delay_since_capture=226.974 ms
#     received at receiver, on-way-delay=60.443 ms, is_recovered=0
#     Packet seq=22381, packet_type=video, transport_seq=80, delay_since_capture=238.211 ms
#     received at receiver, on-way-delay=60.509 ms, is_recovered=0
#     Packet seq=22382, packet_type=video, transport_seq=81, delay_since_capture=243.648 ms
#     received at receiver, on-way-delay=60.528 ms, is_recovered=0
#     Packet seq=22383, packet_type=video, transport_seq=82, delay_since_capture=243.707 ms
#     received at receiver, on-way-delay=60.865 ms, is_recovered=0
#     Packet seq=22384, packet_type=video, transport_seq=83, delay_since_capture=248.899 ms
#     received at receiver, on-way-delay=60.448 ms, is_recovered=0
#     Packet seq=22385, packet_type=video, transport_seq=84, delay_since_capture=254.363 ms
#     received at receiver, on-way-delay=60.498 ms, is_recovered=0
#     Packet seq=22386, packet_type=video, transport_seq=85, delay_since_capture=257.671 ms
#     received at receiver, on-way-delay=60.399 ms, is_recovered=0
#     Packet seq=22387, packet_type=video, transport_seq=86, delay_since_capture=265.21 ms
#     received at receiver, on-way-delay=60.514 ms, is_recovered=0
#     Packet seq=22388, packet_type=video, transport_seq=87, delay_since_capture=269.741 ms
#     received at receiver, on-way-delay=60.476 ms, is_recovered=0
#     Packet seq=22389, packet_type=video, transport_seq=88, delay_since_capture=275.137 ms
#     received at receiver, on-way-delay=60.423 ms, is_recovered=0
#     Packet seq=22390, packet_type=video, transport_seq=89, delay_since_capture=280.529 ms
#     received at receiver, on-way-delay=60.547 ms, is_recovered=0
#     Packet seq=22391, packet_type=video, transport_seq=90, delay_since_capture=280.594 ms
#     received at receiver, on-way-delay=60.771 ms, is_recovered=0
#     Packet seq=22392, packet_type=video, transport_seq=91, delay_since_capture=286.041 ms
#     received at receiver, on-way-delay=60.547 ms, is_recovered=0
#     Packet seq=22393, packet_type=video, transport_seq=92, delay_since_capture=291.385 ms
#     received at receiver, on-way-delay=60.449 ms, is_recovered=0
#     Packet seq=22394, packet_type=video, transport_seq=93, delay_since_capture=294.923 ms
#     received at receiver, on-way-delay=60.456 ms, is_recovered=0
#     Packet seq=22395, packet_type=video, transport_seq=94, delay_since_capture=302.616 ms
#     received at receiver, on-way-delay=60.453 ms, is_recovered=0
#     Packet seq=22396, packet_type=video, transport_seq=95, delay_since_capture=308.317 ms
#     received at receiver, on-way-delay=60.489 ms, is_recovered=0
#     Packet seq=22397, packet_type=video, transport_seq=96, delay_since_capture=308.369 ms
#     received at receiver, on-way-delay=60.737 ms, is_recovered=0
#     Packet seq=22398, packet_type=video, transport_seq=97, delay_since_capture=313.222 ms
#     received at receiver, on-way-delay=60.425 ms, is_recovered=0
#     Packet seq=22399, packet_type=video, transport_seq=98, delay_since_capture=319.822 ms
#     received at receiver, on-way-delay=60.434 ms, is_recovered=0
#     Packet seq=22400, packet_type=video, transport_seq=99, delay_since_capture=325.225 ms
#     received at receiver, on-way-delay=60.447 ms, is_recovered=0
#     Packet seq=22401, packet_type=video, transport_seq=100, delay_since_capture=330.588 ms
#     received at receiver, on-way-delay=60.447 ms, is_recovered=0
#     Packet seq=22402, packet_type=video, transport_seq=101, delay_since_capture=336.015 ms
#     received at receiver, on-way-delay=60.504 ms, is_recovered=0
#     Packet seq=22403, packet_type=video, transport_seq=102, delay_since_capture=336.071 ms
#     received at receiver, on-way-delay=60.757 ms, is_recovered=0
#     Packet seq=22404, packet_type=video, transport_seq=103, delay_since_capture=341.454 ms
#     received at receiver, on-way-delay=60.468 ms, is_recovered=0
#     Packet seq=22405, packet_type=video, transport_seq=104, delay_since_capture=346.999 ms
#     received at receiver, on-way-delay=60.434 ms, is_recovered=0
#     Packet seq=22406, packet_type=video, transport_seq=105, delay_since_capture=352.436 ms
#     received at receiver, on-way-delay=60.43 ms, is_recovered=0
#     Packet seq=22407, packet_type=video, transport_seq=106, delay_since_capture=357.847 ms
#     received at receiver, on-way-delay=60.416 ms, is_recovered=0
#     Packet seq=22408, packet_type=video, transport_seq=107, delay_since_capture=363.359 ms
#     received at receiver, on-way-delay=60.442 ms, is_recovered=0
#     Packet seq=1227, packet_type=fec, transport_seq=109, delay_since_capture=368.784 ms
#     NOT received at receiver
# num_media_packets=29, num_fec_packets=1
# encoding_delay = 28.177 ms, pacing delay = 335.182 ms
# received encoded frame
# picture_id=5600, refs=[5599]
# frame_network_delay=60.711 ms
# jitter_delay=0.465 ms
# decoding_delay=39.354 ms
# e2e_delay=463.889 ms
# --------------------------------
# Frame rtp_ts_capture = 394008430
# rtp_ts=3844758206, frame_type=delta, frame_size=13602 bytes, packet_count=13
# all related packets sent:
#     Packet seq=22409, packet_type=video, transport_seq=108, delay_since_capture=335.424 ms
#     received at receiver, on-way-delay=60.644 ms, is_recovered=0
#     Packet seq=22410, packet_type=video, transport_seq=110, delay_since_capture=341.204 ms
#     received at receiver, on-way-delay=60.541 ms, is_recovered=0
#     Packet seq=22411, packet_type=video, transport_seq=111, delay_since_capture=344.889 ms
#     received at receiver, on-way-delay=60.519 ms, is_recovered=0
#     Packet seq=22412, packet_type=video, transport_seq=112, delay_since_capture=351.579 ms
#     received at receiver, on-way-delay=60.544 ms, is_recovered=0
#     Packet seq=22413, packet_type=video, transport_seq=113, delay_since_capture=356.957 ms
#     received at receiver, on-way-delay=60.481 ms, is_recovered=0
#     Packet seq=22414, packet_type=video, transport_seq=114, delay_since_capture=362.242 ms
#     received at receiver, on-way-delay=60.592 ms, is_recovered=0
#     Packet seq=22415, packet_type=video, transport_seq=115, delay_since_capture=362.273 ms
#     received at receiver, on-way-delay=60.915 ms, is_recovered=0
#     Packet seq=22416, packet_type=video, transport_seq=116, delay_since_capture=367.858 ms
#     received at receiver, on-way-delay=60.497 ms, is_recovered=0
#     Packet seq=22417, packet_type=video, transport_seq=117, delay_since_capture=373.214 ms
#     received at receiver, on-way-delay=60.456 ms, is_recovered=0
#     Packet seq=22418, packet_type=video, transport_seq=118, delay_since_capture=375.327 ms
#     received at receiver, on-way-delay=60.568 ms, is_recovered=0
#     Packet seq=22419, packet_type=video, transport_seq=119, delay_since_capture=383.756 ms
#     received at receiver, on-way-delay=60.525 ms, is_recovered=0
#     Packet seq=22420, packet_type=video, transport_seq=120, delay_since_capture=383.785 ms
#     received at receiver, on-way-delay=60.826 ms, is_recovered=0
#     Packet seq=22421, packet_type=video, transport_seq=121, delay_since_capture=389.262 ms
#     received at receiver, on-way-delay=60.413 ms, is_recovered=0
#     Packet seq=1228, packet_type=fec, transport_seq=123, delay_since_capture=399.77 ms
#     NOT received at receiver
# num_media_packets=13, num_fec_packets=1
# encoding_delay = 21.738 ms, pacing delay = 367.524 ms
# received encoded frame
# picture_id=5601, refs=[5600]
# frame_network_delay=60.555 ms
# jitter_delay=0.461 ms
# decoding_delay=31.157 ms
# e2e_delay=481.435 ms
# --------------------------------
# Frame rtp_ts_capture = 394011490
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394014460
# rtp_ts=3844764236, frame_type=delta, frame_size=8376 bytes, packet_count=8
# all related packets sent:
#     Packet seq=22422, packet_type=video, transport_seq=122, delay_since_capture=327.927 ms
#     received at receiver, on-way-delay=60.525 ms, is_recovered=0
#     Packet seq=22423, packet_type=video, transport_seq=124, delay_since_capture=338.611 ms
#     received at receiver, on-way-delay=60.559 ms, is_recovered=0
#     Packet seq=22424, packet_type=video, transport_seq=125, delay_since_capture=343.714 ms
#     received at receiver, on-way-delay=60.473 ms, is_recovered=0
#     Packet seq=22425, packet_type=video, transport_seq=126, delay_since_capture=345.121 ms
#     received at receiver, on-way-delay=60.421 ms, is_recovered=0
#     Packet seq=22426, packet_type=video, transport_seq=127, delay_since_capture=348.716 ms
#     received at receiver, on-way-delay=60.429 ms, is_recovered=0
#     Packet seq=22427, packet_type=video, transport_seq=128, delay_since_capture=354.122 ms
#     received at receiver, on-way-delay=60.413 ms, is_recovered=0
#     Packet seq=22428, packet_type=video, transport_seq=129, delay_since_capture=358.874 ms
#     received at receiver, on-way-delay=60.413 ms, is_recovered=0
#     Packet seq=22429, packet_type=video, transport_seq=130, delay_since_capture=364.219 ms
#     received at receiver, on-way-delay=60.413 ms, is_recovered=0
#     Packet seq=1229, packet_type=fec, transport_seq=132, delay_since_capture=375.035 ms
#     NOT received at receiver
# num_media_packets=8, num_fec_packets=1
# encoding_delay = 12.598 ms, pacing delay = 351.621 ms
# received encoded frame
# picture_id=5602, refs=[5601]
# frame_network_delay=60.541 ms
# jitter_delay=0.458 ms
# decoding_delay=16.832 ms
# e2e_delay=442.05 ms
# --------------------------------
# Frame rtp_ts_capture = 394017430
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394020490
# rtp_ts=3844770266, frame_type=delta, frame_size=5136 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22430, packet_type=video, transport_seq=131, delay_since_capture=302.909 ms
#     received at receiver, on-way-delay=60.655 ms, is_recovered=0
#     Packet seq=22431, packet_type=video, transport_seq=133, delay_since_capture=308.416 ms
#     received at receiver, on-way-delay=60.695 ms, is_recovered=0
#     Packet seq=22432, packet_type=video, transport_seq=134, delay_since_capture=313.915 ms
#     received at receiver, on-way-delay=60.435 ms, is_recovered=0
#     Packet seq=22433, packet_type=video, transport_seq=135, delay_since_capture=319.378 ms
#     received at receiver, on-way-delay=60.435 ms, is_recovered=0
#     Packet seq=22434, packet_type=video, transport_seq=136, delay_since_capture=324.328 ms
#     received at receiver, on-way-delay=60.441 ms, is_recovered=0
#     Packet seq=1230, packet_type=fec, transport_seq=138, delay_since_capture=334.44 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 12.03 ms, pacing delay = 312.298 ms
# received encoded frame
# picture_id=5603, refs=[5602]
# frame_network_delay=60.546 ms
# jitter_delay=0.471 ms
# decoding_delay=14.969 ms
# e2e_delay=400.314 ms
# --------------------------------
# Frame rtp_ts_capture = 394023460
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394026430
# rtp_ts=3844776206, frame_type=delta, frame_size=5179 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22435, packet_type=video, transport_seq=137, delay_since_capture=263.037 ms
#     received at receiver, on-way-delay=86.935 ms, is_recovered=1
#     Packet seq=22436, packet_type=video, transport_seq=139, delay_since_capture=267.78 ms
#     received at receiver, on-way-delay=60.905 ms, is_recovered=0
#     Packet seq=22437, packet_type=video, transport_seq=140, delay_since_capture=272.995 ms
#     received at receiver, on-way-delay=60.74 ms, is_recovered=0
#     Packet seq=22438, packet_type=video, transport_seq=141, delay_since_capture=276.482 ms
#     received at receiver, on-way-delay=60.6 ms, is_recovered=0
#     Packet seq=22439, packet_type=video, transport_seq=142, delay_since_capture=283.089 ms
#     received at receiver, on-way-delay=60.396 ms, is_recovered=0
#     Packet seq=1231, packet_type=fec, transport_seq=144, delay_since_capture=288.95 ms
#     NOT received at receiver
#     Packet seq=4917, packet_type=rtx, transport_seq=163, delay_since_capture=372.909 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 13.08 ms, pacing delay = 270.009 ms
# received encoded frame
# picture_id=5604, refs=[5603]
# frame_network_delay=66.99 ms
# jitter_delay=0.295 ms
# decoding_delay=16.352 ms
# e2e_delay=366.726 ms
# --------------------------------
# Frame rtp_ts_capture = 394029490
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394032460
# rtp_ts=3844782236, frame_type=delta, frame_size=4561 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22440, packet_type=video, transport_seq=143, delay_since_capture=219.86 ms
#     received at receiver, on-way-delay=60.453 ms, is_recovered=0
#     Packet seq=22441, packet_type=video, transport_seq=145, delay_since_capture=227.666 ms
#     received at receiver, on-way-delay=60.864 ms, is_recovered=0
#     Packet seq=22442, packet_type=video, transport_seq=146, delay_since_capture=233.08 ms
#     received at receiver, on-way-delay=60.414 ms, is_recovered=0
#     Packet seq=22443, packet_type=video, transport_seq=147, delay_since_capture=238.396 ms
#     received at receiver, on-way-delay=60.456 ms, is_recovered=0
#     Packet seq=22444, packet_type=video, transport_seq=148, delay_since_capture=238.486 ms
#     received at receiver, on-way-delay=60.732 ms, is_recovered=0
#     Packet seq=1232, packet_type=fec, transport_seq=150, delay_since_capture=248.858 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 12.93 ms, pacing delay = 225.556 ms
# received encoded frame
# picture_id=5605, refs=[5604]
# frame_network_delay=60.829 ms
# jitter_delay=1.049 ms
# decoding_delay=15.3 ms
# e2e_delay=315.664 ms
# --------------------------------
# Frame rtp_ts_capture = 394035430
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394038490
# rtp_ts=3844788266, frame_type=delta, frame_size=5120 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22445, packet_type=video, transport_seq=149, delay_since_capture=176.484 ms
#     received at receiver, on-way-delay=60.386 ms, is_recovered=0
#     Packet seq=22446, packet_type=video, transport_seq=151, delay_since_capture=187.79 ms
#     received at receiver, on-way-delay=60.501 ms, is_recovered=0
#     Packet seq=22447, packet_type=video, transport_seq=152, delay_since_capture=193.177 ms
#     received at receiver, on-way-delay=60.67 ms, is_recovered=0
#     Packet seq=22448, packet_type=video, transport_seq=153, delay_since_capture=193.245 ms
#     received at receiver, on-way-delay=60.993 ms, is_recovered=0
#     Packet seq=22449, packet_type=video, transport_seq=154, delay_since_capture=198.724 ms
#     received at receiver, on-way-delay=60.402 ms, is_recovered=0
#     Packet seq=1233, packet_type=fec, transport_seq=156, delay_since_capture=208.673 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 11.576 ms, pacing delay = 187.148 ms
# received encoded frame
# picture_id=5606, refs=[5605]
# frame_network_delay=60.524 ms
# jitter_delay=0.517 ms
# decoding_delay=14.937 ms
# e2e_delay=274.702 ms
# --------------------------------
# Frame rtp_ts_capture = 394041460
#     dropped by encoder!
# --------------------------------
# Frame rtp_ts_capture = 394044430
# rtp_ts=3844794206, frame_type=delta, frame_size=5432 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22450, packet_type=video, transport_seq=155, delay_since_capture=136.42 ms
#     received at receiver, on-way-delay=60.42 ms, is_recovered=0
#     Packet seq=22451, packet_type=video, transport_seq=157, delay_since_capture=144.716 ms
#     received at receiver, on-way-delay=60.292 ms, is_recovered=0
#     Packet seq=22452, packet_type=video, transport_seq=158, delay_since_capture=152.209 ms
#     received at receiver, on-way-delay=60.334 ms, is_recovered=0
#     Packet seq=22453, packet_type=video, transport_seq=159, delay_since_capture=157.478 ms
#     received at receiver, on-way-delay=60.476 ms, is_recovered=0
#     Packet seq=22454, packet_type=video, transport_seq=160, delay_since_capture=157.566 ms
#     received at receiver, on-way-delay=60.747 ms, is_recovered=0
#     Packet seq=1234, packet_type=fec, transport_seq=162, delay_since_capture=167.846 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 10.231 ms, pacing delay = 147.335 ms
# received encoded frame
# picture_id=5607, refs=[5606]
# frame_network_delay=60.843 ms
# jitter_delay=0.533 ms
# decoding_delay=16.039 ms
# e2e_delay=234.981 ms
# --------------------------------
# Frame rtp_ts_capture = 394047490
# rtp_ts=3844797266, frame_type=delta, frame_size=5281 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22455, packet_type=video, transport_seq=161, delay_since_capture=128.453 ms
#     received at receiver, on-way-delay=60.347 ms, is_recovered=0
#     Packet seq=22456, packet_type=video, transport_seq=164, delay_since_capture=144.249 ms
#     received at receiver, on-way-delay=60.284 ms, is_recovered=0
#     Packet seq=22457, packet_type=video, transport_seq=165, delay_since_capture=149.669 ms
#     received at receiver, on-way-delay=60.352 ms, is_recovered=0
#     Packet seq=22458, packet_type=video, transport_seq=166, delay_since_capture=154.031 ms
#     received at receiver, on-way-delay=60.348 ms, is_recovered=0
#     Packet seq=22459, packet_type=video, transport_seq=167, delay_since_capture=159.34 ms
#     received at receiver, on-way-delay=60.362 ms, is_recovered=0
#     Packet seq=1235, packet_type=fec, transport_seq=169, delay_since_capture=164.753 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 20.017 ms, pacing delay = 139.323 ms
# received encoded frame
# picture_id=5608, refs=[5607]
# frame_network_delay=60.475 ms
# jitter_delay=0.911 ms
# decoding_delay=28.567 ms
# e2e_delay=249.293 ms
# --------------------------------
# Frame rtp_ts_capture = 394050460
# rtp_ts=3844800236, frame_type=delta, frame_size=9698 bytes, packet_count=9
# all related packets sent:
#     Packet seq=22460, packet_type=video, transport_seq=168, delay_since_capture=126.09 ms
#     received at receiver, on-way-delay=60.884 ms, is_recovered=0
#     Packet seq=22461, packet_type=video, transport_seq=170, delay_since_capture=135.764 ms
#     received at receiver, on-way-delay=60.291 ms, is_recovered=0
#     Packet seq=22462, packet_type=video, transport_seq=171, delay_since_capture=140.994 ms
#     received at receiver, on-way-delay=60.35 ms, is_recovered=0
#     Packet seq=22463, packet_type=video, transport_seq=172, delay_since_capture=144.223 ms
#     received at receiver, on-way-delay=60.65 ms, is_recovered=0
#     Packet seq=22464, packet_type=video, transport_seq=173, delay_since_capture=151.986 ms
#     received at receiver, on-way-delay=60.445 ms, is_recovered=0
#     Packet seq=22465, packet_type=video, transport_seq=174, delay_since_capture=157.328 ms
#     received at receiver, on-way-delay=60.455 ms, is_recovered=0
#     Packet seq=22466, packet_type=video, transport_seq=175, delay_since_capture=157.354 ms
#     received at receiver, on-way-delay=60.822 ms, is_recovered=0
#     Packet seq=22467, packet_type=video, transport_seq=176, delay_since_capture=162.699 ms
#     received at receiver, on-way-delay=60.24 ms, is_recovered=0
#     Packet seq=22468, packet_type=video, transport_seq=177, delay_since_capture=167.964 ms
#     received at receiver, on-way-delay=60.282 ms, is_recovered=0
#     Packet seq=1236, packet_type=fec, transport_seq=179, delay_since_capture=175.74 ms
#     NOT received at receiver
# num_media_packets=9, num_fec_packets=1
# encoding_delay = 22.116 ms, pacing delay = 145.848 ms
# received encoded frame
# picture_id=5609, refs=[5608]
# frame_network_delay=60.457 ms
# jitter_delay=0.561 ms
# decoding_delay=28.607 ms
# e2e_delay=257.589 ms
# --------------------------------
# Frame rtp_ts_capture = 394053430
# rtp_ts=3844803206, frame_type=delta, frame_size=7710 bytes, packet_count=7
# all related packets sent:
#     Packet seq=22469, packet_type=video, transport_seq=178, delay_since_capture=137.703 ms
#     received at receiver, on-way-delay=60.292 ms, is_recovered=0
#     Packet seq=22470, packet_type=video, transport_seq=180, delay_since_capture=149.503 ms
#     received at receiver, on-way-delay=60.251 ms, is_recovered=0
#     Packet seq=22471, packet_type=video, transport_seq=181, delay_since_capture=154.731 ms
#     received at receiver, on-way-delay=60.331 ms, is_recovered=0
#     Packet seq=22472, packet_type=video, transport_seq=182, delay_since_capture=160.036 ms
#     received at receiver, on-way-delay=60.354 ms, is_recovered=0
#     Packet seq=22473, packet_type=video, transport_seq=183, delay_since_capture=160.087 ms
#     received at receiver, on-way-delay=60.701 ms, is_recovered=0
#     Packet seq=22474, packet_type=video, transport_seq=184, delay_since_capture=165.33 ms
#     received at receiver, on-way-delay=60.283 ms, is_recovered=0
#     Packet seq=22475, packet_type=video, transport_seq=185, delay_since_capture=171.014 ms
#     received at receiver, on-way-delay=60.224 ms, is_recovered=0
#     Packet seq=1237, packet_type=fec, transport_seq=187, delay_since_capture=178.525 ms
#     NOT received at receiver
# num_media_packets=7, num_fec_packets=1
# encoding_delay = 9.385 ms, pacing delay = 161.629 ms
# received encoded frame
# picture_id=5610, refs=[5609]
# frame_network_delay=60.355 ms
# jitter_delay=0.537 ms
# decoding_delay=15.451 ms
# e2e_delay=247.357 ms
# --------------------------------
# Frame rtp_ts_capture = 394056490
# rtp_ts=3844806266, frame_type=delta, frame_size=6747 bytes, packet_count=7
# all related packets sent:
#     Packet seq=22476, packet_type=video, transport_seq=186, delay_since_capture=142.987 ms
#     received at receiver, on-way-delay=60.319 ms, is_recovered=0
#     Packet seq=22477, packet_type=video, transport_seq=188, delay_since_capture=153.66 ms
#     received at receiver, on-way-delay=60.381 ms, is_recovered=0
#     Packet seq=22478, packet_type=video, transport_seq=189, delay_since_capture=153.719 ms
#     received at receiver, on-way-delay=60.803 ms, is_recovered=0
#     Packet seq=22479, packet_type=video, transport_seq=190, delay_since_capture=158.138 ms
#     received at receiver, on-way-delay=60.271 ms, is_recovered=0
#     Packet seq=22480, packet_type=video, transport_seq=191, delay_since_capture=163.397 ms
#     received at receiver, on-way-delay=60.243 ms, is_recovered=0
#     Packet seq=22481, packet_type=video, transport_seq=192, delay_since_capture=168.721 ms
#     received at receiver, on-way-delay=60.287 ms, is_recovered=0
#     Packet seq=22482, packet_type=video, transport_seq=193, delay_since_capture=173.207 ms
#     received at receiver, on-way-delay=60.306 ms, is_recovered=0
#     Packet seq=1238, packet_type=fec, transport_seq=195, delay_since_capture=178.503 ms
#     NOT received at receiver
# num_media_packets=7, num_fec_packets=1
# encoding_delay = 11.057 ms, pacing delay = 162.15 ms
# received encoded frame
# picture_id=5611, refs=[5610]
# frame_network_delay=60.456 ms
# jitter_delay=0.985 ms
# decoding_delay=15.786 ms
# e2e_delay=250.434 ms
# --------------------------------
# Frame rtp_ts_capture = 394059460
# rtp_ts=3844809236, frame_type=delta, frame_size=5248 bytes, packet_count=5
# all related packets sent:
#     Packet seq=22483, packet_type=video, transport_seq=194, delay_since_capture=139.967 ms
#     received at receiver, on-way-delay=60.915 ms, is_recovered=0
#     Packet seq=22484, packet_type=video, transport_seq=196, delay_since_capture=149.763 ms
#     received at receiver, on-way-delay=60.357 ms, is_recovered=0
#     Packet seq=22485, packet_type=video, transport_seq=197, delay_since_capture=155.659 ms
#     received at receiver, on-way-delay=60.374 ms, is_recovered=0
#     Packet seq=22486, packet_type=video, transport_seq=198, delay_since_capture=161.169 ms
#     received at receiver, on-way-delay=60.272 ms, is_recovered=0
#     Packet seq=22487, packet_type=video, transport_seq=199, delay_since_capture=161.925 ms
#     received at receiver, on-way-delay=60.249 ms, is_recovered=0
#     Packet seq=1239, packet_type=fec, transport_seq=201, delay_since_capture=171.534 ms
#     NOT received at receiver
# num_media_packets=5, num_fec_packets=1
# encoding_delay = 10.776 ms, pacing delay = 151.149 ms
# received encoded frame
# picture_id=5612, refs=[5611]
# frame_network_delay=60.378 ms
# jitter_delay=0.58 ms
# decoding_delay=14.623 ms
# e2e_delay=237.506 ms
# --------------------------------
# Frame rtp_ts_capture = 394062430
# rtp_ts=3844812206, frame_type=delta, frame_size=2640 bytes, packet_count=3
# all related packets sent:
#     Packet seq=22488, packet_type=video, transport_seq=200, delay_since_capture=132.843 ms
#     received at receiver, on-way-delay=60.241 ms, is_recovered=0
#     Packet seq=22489, packet_type=video, transport_seq=202, delay_since_capture=143.666 ms
#     received at receiver, on-way-delay=60.35 ms, is_recovered=0
#     Packet seq=22490, packet_type=video, transport_seq=203, delay_since_capture=144.507 ms
#     received at receiver, on-way-delay=60.231 ms, is_recovered=0
#     Packet seq=1240, packet_type=fec, transport_seq=205, delay_since_capture=154.028 ms
#     NOT received at receiver
# num_media_packets=3, num_fec_packets=1
# encoding_delay = 10.594 ms, pacing delay = 133.913 ms
# received encoded frame
# picture_id=5613, refs=[5612]
# frame_network_delay=60.327 ms
# jitter_delay=0.55 ms
# decoding_delay=13.331 ms
# e2e_delay=218.715 ms
# --------------------------------
# Frame rtp_ts_capture = 394065490
# rtp_ts=3844815266, frame_type=delta, frame_size=2561 bytes, packet_count=3
# all related packets sent:
#     Packet seq=22491, packet_type=video, transport_seq=204, delay_since_capture=115.477 ms
#     received at receiver, on-way-delay=60.278 ms, is_recovered=0
#     Packet seq=22492, packet_type=video, transport_seq=206, delay_since_capture=125.05 ms
#     received at receiver, on-way-delay=60.339 ms, is_recovered=0
#     Packet seq=22493, packet_type=video, transport_seq=207, delay_since_capture=129.441 ms
#     received at receiver, on-way-delay=60.479 ms, is_recovered=0
#     Packet seq=1241, packet_type=fec, transport_seq=209, delay_since_capture=134.968 ms
#     NOT received at receiver
# num_media_packets=3, num_fec_packets=1
# encoding_delay = 8.851 ms, pacing delay = 120.59 ms
# received encoded frame
# picture_id=5614, refs=[5613]
# frame_network_delay=60.574 ms
# jitter_delay=1.055 ms
# decoding_delay=13.072 ms
# e2e_delay=204.142 ms
# --------------------------------
# Frame rtp_ts_capture = 394068460
# rtp_ts=3844818236, frame_type=delta, frame_size=4070 bytes, packet_count=4
# all related packets sent:
#     Packet seq=22494, packet_type=video, transport_seq=208, delay_since_capture=96.103 ms
#     received at receiver, on-way-delay=61.065 ms, is_recovered=0
#     Packet seq=22495, packet_type=video, transport_seq=210, delay_since_capture=106.855 ms
#     received at receiver, on-way-delay=60.354 ms, is_recovered=0
#     Packet seq=22496, packet_type=video, transport_seq=211, delay_since_capture=110.444 ms
#     received at receiver, on-way-delay=60.323 ms, is_recovered=0
#     Packet seq=22497, packet_type=video, transport_seq=212, delay_since_capture=112.517 ms
#     received at receiver, on-way-delay=60.311 ms, is_recovered=0
#     Packet seq=1242, packet_type=fec, transport_seq=214, delay_since_capture=122.127 ms
#     NOT received at receiver
# num_media_packets=4, num_fec_packets=1
# encoding_delay = 11.367 ms, pacing delay = 101.15 ms
# received encoded frame
# picture_id=5615, refs=[5614]
# frame_network_delay=60.445 ms
# jitter_delay=0.569 ms
# decoding_delay=15.578 ms
# e2e_delay=189.109 ms
# --------------------------------
# Frame rtp_ts_capture = 394071430
# rtp_ts=3844821206, frame_type=delta, frame_size=11635 bytes, packet_count=11
# all related packets sent:
#     Packet seq=22498, packet_type=video, transport_seq=213, delay_since_capture=83.487 ms
#     received at receiver, on-way-delay=60.417 ms, is_recovered=0
#     Packet seq=22499, packet_type=video, transport_seq=215, delay_since_capture=94.152 ms
#     received at receiver, on-way-delay=60.489 ms, is_recovered=0
#     Packet seq=22500, packet_type=video, transport_seq=216, delay_since_capture=99.432 ms
#     received at receiver, on-way-delay=60.458 ms, is_recovered=0
#     Packet seq=22501, packet_type=video, transport_seq=217, delay_since_capture=104.817 ms
#     received at receiver, on-way-delay=60.48 ms, is_recovered=0
#     Packet seq=22502, packet_type=video, transport_seq=218, delay_since_capture=104.876 ms
#     received at receiver, on-way-delay=60.896 ms, is_recovered=0
#     Packet seq=22503, packet_type=video, transport_seq=219, delay_since_capture=110.256 ms
#     received at receiver, on-way-delay=60.463 ms, is_recovered=0
#     Packet seq=22504, packet_type=video, transport_seq=220, delay_since_capture=115.852 ms
#     received at receiver, on-way-delay=60.451 ms, is_recovered=0
#     Packet seq=22505, packet_type=video, transport_seq=221, delay_since_capture=120.402 ms
#     received at receiver, on-way-delay=60.42 ms, is_recovered=0
#     Packet seq=22506, packet_type=video, transport_seq=222, delay_since_capture=125.645 ms
#     received at receiver, on-way-delay=60.409 ms, is_recovered=0
#     Packet seq=22507, packet_type=video, transport_seq=223, delay_since_capture=129.713 ms
#     received at receiver, on-way-delay=60.433 ms, is_recovered=0
#     Packet seq=22508, packet_type=video, transport_seq=224, delay_since_capture=131.01 ms
#     received at receiver, on-way-delay=60.404 ms, is_recovered=0
#     Packet seq=1243, packet_type=fec, transport_seq=226, delay_since_capture=140.376 ms
#     NOT received at receiver
# num_media_packets=11, num_fec_packets=1
# encoding_delay = 18.896 ms, pacing delay = 112.114 ms
# received encoded frame
# picture_id=5616, refs=[5615]
# frame_network_delay=60.583 ms
# jitter_delay=0.623 ms
# decoding_delay=22.536 ms
# e2e_delay=214.752 ms
# --------------------------------
# Frame rtp_ts_capture = 394074490
# rtp_ts=3844824266, frame_type=delta, frame_size=4139 bytes, packet_count=4
# all related packets sent:
#     Packet seq=22509, packet_type=video, transport_seq=225, delay_since_capture=102.477 ms
#     received at receiver, on-way-delay=60.392 ms, is_recovered=0
#     Packet seq=22510, packet_type=video, transport_seq=227, delay_since_capture=110.308 ms
#     received at receiver, on-way-delay=60.549 ms, is_recovered=0
#     Packet seq=22511, packet_type=video, transport_seq=228, delay_since_capture=117.953 ms
#     received at receiver, on-way-delay=60.502 ms, is_recovered=0
#     Packet seq=22512, packet_type=video, transport_seq=229, delay_since_capture=123.504 ms
#     received at receiver, on-way-delay=60.597 ms, is_recovered=0
#     Packet seq=1244, packet_type=fec, transport_seq=231, delay_since_capture=128.934 ms
#     NOT received at receiver
# num_media_packets=4, num_fec_packets=1
# encoding_delay = 10.991 ms, pacing delay = 112.513 ms
# received encoded frame
# picture_id=5617, refs=[5616]
# frame_network_delay=60.711 ms
# jitter_delay=1.037 ms
# decoding_delay=15.28 ms
# e2e_delay=200.532 ms
# --------------------------------
# Frame rtp_ts_capture = 394077460
# rtp_ts=3844827236, frame_type=delta, frame_size=6512 bytes, packet_count=6
# all related packets sent:
#     Packet seq=22513, packet_type=video, transport_seq=230, delay_since_capture=90.223 ms
#     received at receiver, on-way-delay=61.175 ms, is_recovered=0
#     Packet seq=22514, packet_type=video, transport_seq=232, delay_since_capture=101.087 ms
#     received at receiver, on-way-delay=60.498 ms, is_recovered=0
#     Packet seq=22515, packet_type=video, transport_seq=233, delay_since_capture=105.84 ms
#     received at receiver, on-way-delay=60.584 ms, is_recovered=0
#     Packet seq=22516, packet_type=video, transport_seq=234, delay_since_capture=111.308 ms
#     received at receiver, on-way-delay=60.472 ms, is_recovered=0
#     Packet seq=22517, packet_type=video, transport_seq=235, delay_since_capture=114.001 ms
#     received at receiver, on-way-delay=60.42 ms, is_recovered=0
#     Packet seq=22518, packet_type=video, transport_seq=236, delay_since_capture=116.416 ms
#     received at receiver, on-way-delay=60.981 ms, is_recovered=0
#     Packet seq=1245, packet_type=fec, transport_seq=238, delay_since_capture=127.697 ms
#     NOT received at receiver
# num_media_packets=6, num_fec_packets=1
# encoding_delay = 10.339 ms, pacing delay = 106.077 ms
# received encoded frame
# picture_id=5618, refs=[5617]
# frame_network_delay=61.085 ms
# jitter_delay=0.586 ms
# decoding_delay=15.274 ms
# e2e_delay=193.361 ms
# --------------------------------
# Frame rtp_ts_capture = 394080430
# rtp_ts=3844830206, frame_type=delta, frame_size=17499 bytes, packet_count=16
# all related packets sent:
#     Packet seq=22519, packet_type=video, transport_seq=237, delay_since_capture=87.664 ms
#     received at receiver, on-way-delay=60.718 ms, is_recovered=0
#     Packet seq=22520, packet_type=video, transport_seq=239, delay_since_capture=99.886 ms
#     received at receiver, on-way-delay=60.799 ms, is_recovered=0
#     Packet seq=22521, packet_type=video, transport_seq=240, delay_since_capture=104.622 ms
#     received at receiver, on-way-delay=60.708 ms, is_recovered=0
#     Packet seq=22522, packet_type=video, transport_seq=241, delay_since_capture=110.126 ms
#     received at receiver, on-way-delay=60.959 ms, is_recovered=0
#     Packet seq=22523, packet_type=video, transport_seq=242, delay_since_capture=110.177 ms
#     received at receiver, on-way-delay=61.345 ms, is_recovered=0
#     Packet seq=22524, packet_type=video, transport_seq=243, delay_since_capture=115.461 ms
#     received at receiver, on-way-delay=60.713 ms, is_recovered=0
#     Packet seq=22525, packet_type=video, transport_seq=244, delay_since_capture=121.362 ms
#     received at receiver, on-way-delay=60.724 ms, is_recovered=0
#     Packet seq=22526, packet_type=video, transport_seq=245, delay_since_capture=126.728 ms
#     received at receiver, on-way-delay=60.748 ms, is_recovered=0
#     Packet seq=22527, packet_type=video, transport_seq=246, delay_since_capture=131.208 ms
#     received at receiver, on-way-delay=60.52 ms, is_recovered=0
#     Packet seq=22528, packet_type=video, transport_seq=247, delay_since_capture=131.347 ms
#     received at receiver, on-way-delay=60.853 ms, is_recovered=0
#     Packet seq=22529, packet_type=video, transport_seq=248, delay_since_capture=136.522 ms
#     received at receiver, on-way-delay=60.466 ms, is_recovered=0
#     Packet seq=22530, packet_type=video, transport_seq=249, delay_since_capture=142.247 ms
#     received at receiver, on-way-delay=60.457 ms, is_recovered=0
#     Packet seq=22531, packet_type=video, transport_seq=250, delay_since_capture=147.761 ms
#     received at receiver, on-way-delay=60.525 ms, is_recovered=0
#     Packet seq=22532, packet_type=video, transport_seq=251, delay_since_capture=153.304 ms
#     received at receiver, on-way-delay=60.44 ms, is_recovered=0
#     Packet seq=22533, packet_type=video, transport_seq=252, delay_since_capture=158.831 ms
#     received at receiver, on-way-delay=60.443 ms, is_recovered=0
#     Packet seq=22534, packet_type=video, transport_seq=253, delay_since_capture=158.953 ms
#     received at receiver, on-way-delay=60.792 ms, is_recovered=0
#     Packet seq=1246, packet_type=fec, transport_seq=255, delay_since_capture=169.023 ms
#     NOT received at receiver
# num_media_packets=16, num_fec_packets=1
# ...
#     NOT received at receiver
#     Packet seq=28369, packet_type=video, transport_seq=8519, delay_since_capture=41.71 ms
#     NOT received at receiver
#     Packet seq=28370, packet_type=video, transport_seq=8521, delay_since_capture=45.668 ms
#     NOT received at receiver
#     Packet seq=28371, packet_type=video, transport_seq=8523, delay_since_capture=51.961 ms
#     NOT received at receiver
#     Packet seq=28372, packet_type=video, transport_seq=8524, delay_since_capture=56.292 ms
#     NOT received at receiver
#     Packet seq=28373, packet_type=video, transport_seq=8525, delay_since_capture=56.348 ms
#     NOT received at receiver
#     Packet seq=3554, packet_type=fec, transport_seq=8527, delay_since_capture=61.489 ms
#     NOT received at receiver
#     Packet seq=3555, packet_type=fec, transport_seq=8529, delay_since_capture=71.98 ms
#     NOT received at receiver
#     Packet seq=3556, packet_type=fec, transport_seq=8531, delay_since_capture=77.214 ms
#     NOT received at receiver
#     Packet seq=3557, packet_type=fec, transport_seq=8533, delay_since_capture=78.733 ms
#     NOT received at receiver
# num_media_packets=8, num_fec_packets=4
# encoding_delay = 11.215 ms, pacing delay = 45.133 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396885460
# rtp_ts=3847635236, frame_type=delta, frame_size=6948 bytes, packet_count=7
# all related packets sent:
#     Packet seq=28374, packet_type=video, transport_seq=8526, delay_since_capture=28.066 ms
#     NOT received at receiver
#     Packet seq=28375, packet_type=video, transport_seq=8528, delay_since_capture=33.331 ms
#     NOT received at receiver
#     Packet seq=28376, packet_type=video, transport_seq=8530, delay_since_capture=38.595 ms
#     NOT received at receiver
#     Packet seq=28377, packet_type=video, transport_seq=8532, delay_since_capture=43.83 ms
#     NOT received at receiver
#     Packet seq=28378, packet_type=video, transport_seq=8534, delay_since_capture=49.641 ms
#     NOT received at receiver
#     Packet seq=28379, packet_type=video, transport_seq=8535, delay_since_capture=53.88 ms
#     NOT received at receiver
#     Packet seq=28380, packet_type=video, transport_seq=8536, delay_since_capture=53.961 ms
#     NOT received at receiver
#     Packet seq=3558, packet_type=fec, transport_seq=8538, delay_since_capture=59.338 ms
#     NOT received at receiver
#     Packet seq=3559, packet_type=fec, transport_seq=8540, delay_since_capture=64.589 ms
#     NOT received at receiver
#     Packet seq=3560, packet_type=fec, transport_seq=8542, delay_since_capture=68.955 ms
#     NOT received at receiver
#     Packet seq=3561, packet_type=fec, transport_seq=8544, delay_since_capture=74.514 ms
#     NOT received at receiver
# num_media_packets=7, num_fec_packets=4
# encoding_delay = 12.151 ms, pacing delay = 41.81 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396888430
# rtp_ts=3847638206, frame_type=delta, frame_size=7714 bytes, packet_count=7
# all related packets sent:
#     Packet seq=28381, packet_type=video, transport_seq=8537, delay_since_capture=25.978 ms
#     NOT received at receiver
#     Packet seq=28382, packet_type=video, transport_seq=8539, delay_since_capture=31.232 ms
#     NOT received at receiver
#     Packet seq=28383, packet_type=video, transport_seq=8541, delay_since_capture=35.573 ms
#     NOT received at receiver
#     Packet seq=28384, packet_type=video, transport_seq=8543, delay_since_capture=41.13 ms
#     NOT received at receiver
#     Packet seq=28385, packet_type=video, transport_seq=8545, delay_since_capture=45.625 ms
#     NOT received at receiver
#     Packet seq=28386, packet_type=video, transport_seq=8546, delay_since_capture=50.883 ms
#     NOT received at receiver
#     Packet seq=28387, packet_type=video, transport_seq=8547, delay_since_capture=50.983 ms
#     NOT received at receiver
#     Packet seq=3562, packet_type=fec, transport_seq=8549, delay_since_capture=56.332 ms
#     NOT received at receiver
#     Packet seq=3563, packet_type=fec, transport_seq=8551, delay_since_capture=60.628 ms
#     NOT received at receiver
#     Packet seq=3564, packet_type=fec, transport_seq=8553, delay_since_capture=65.972 ms
#     NOT received at receiver
#     Packet seq=3565, packet_type=fec, transport_seq=8555, delay_since_capture=71.218 ms
#     NOT received at receiver
# num_media_packets=7, num_fec_packets=4
# encoding_delay = 11.894 ms, pacing delay = 39.089 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396891400
# rtp_ts=3847641176, frame_type=delta, frame_size=8574 bytes, packet_count=8
# all related packets sent:
#     Packet seq=28388, packet_type=video, transport_seq=8548, delay_since_capture=23.042 ms
#     NOT received at receiver
#     Packet seq=28389, packet_type=video, transport_seq=8550, delay_since_capture=27.341 ms
#     NOT received at receiver
#     Packet seq=28390, packet_type=video, transport_seq=8552, delay_since_capture=32.685 ms
#     NOT received at receiver
#     Packet seq=28391, packet_type=video, transport_seq=8554, delay_since_capture=37.923 ms
#     NOT received at receiver
#     Packet seq=28392, packet_type=video, transport_seq=8556, delay_since_capture=42.286 ms
#     NOT received at receiver
#     Packet seq=28393, packet_type=video, transport_seq=8557, delay_since_capture=47.629 ms
#     NOT received at receiver
#     Packet seq=28394, packet_type=video, transport_seq=8558, delay_since_capture=47.681 ms
#     NOT received at receiver
#     Packet seq=28395, packet_type=video, transport_seq=8559, delay_since_capture=52.345 ms
#     NOT received at receiver
#     Packet seq=3566, packet_type=fec, transport_seq=8560, delay_since_capture=57.722 ms
#     NOT received at receiver
#     Packet seq=3567, packet_type=fec, transport_seq=8562, delay_since_capture=62.971 ms
#     NOT received at receiver
#     Packet seq=3568, packet_type=fec, transport_seq=8564, delay_since_capture=67.209 ms
#     NOT received at receiver
#     Packet seq=3569, packet_type=fec, transport_seq=8566, delay_since_capture=72.422 ms
#     NOT received at receiver
# num_media_packets=8, num_fec_packets=4
# encoding_delay = 12.278 ms, pacing delay = 40.067 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396894460
# rtp_ts=3847644236, frame_type=delta, frame_size=10136 bytes, packet_count=10
# all related packets sent:
#     Packet seq=28396, packet_type=video, transport_seq=8561, delay_since_capture=29.59 ms
#     NOT received at receiver
#     Packet seq=28397, packet_type=video, transport_seq=8563, delay_since_capture=33.831 ms
#     NOT received at receiver
#     Packet seq=28398, packet_type=video, transport_seq=8565, delay_since_capture=39.042 ms
#     NOT received at receiver
#     Packet seq=28399, packet_type=video, transport_seq=8567, delay_since_capture=44.257 ms
#     NOT received at receiver
#     Packet seq=28400, packet_type=video, transport_seq=8568, delay_since_capture=44.302 ms
#     NOT received at receiver
#     Packet seq=28401, packet_type=video, transport_seq=8569, delay_since_capture=49.089 ms
#     NOT received at receiver
#     Packet seq=28402, packet_type=video, transport_seq=8570, delay_since_capture=49.138 ms
#     NOT received at receiver
#     Packet seq=28403, packet_type=video, transport_seq=8571, delay_since_capture=54.44 ms
#     NOT received at receiver
#     Packet seq=28404, packet_type=video, transport_seq=8572, delay_since_capture=54.485 ms
#     NOT received at receiver
#     Packet seq=28405, packet_type=video, transport_seq=8573, delay_since_capture=59.694 ms
#     NOT received at receiver
#     Packet seq=3570, packet_type=fec, transport_seq=8575, delay_since_capture=65.14 ms
#     NOT received at receiver
#     Packet seq=3571, packet_type=fec, transport_seq=8577, delay_since_capture=68.334 ms
#     NOT received at receiver
#     Packet seq=3572, packet_type=fec, transport_seq=8579, delay_since_capture=75.709 ms
#     NOT received at receiver
#     Packet seq=3573, packet_type=fec, transport_seq=8581, delay_since_capture=79.894 ms
#     NOT received at receiver
#     Packet seq=3574, packet_type=fec, transport_seq=8583, delay_since_capture=83.558 ms
#     NOT received at receiver
# num_media_packets=10, num_fec_packets=5
# encoding_delay = 18.902 ms, pacing delay = 40.792 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396897430
# rtp_ts=3847647206, frame_type=delta, frame_size=8590 bytes, packet_count=8
# all related packets sent:
#     Packet seq=28406, packet_type=video, transport_seq=8574, delay_since_capture=26.513 ms
#     NOT received at receiver
#     Packet seq=28407, packet_type=video, transport_seq=8576, delay_since_capture=31.897 ms
#     NOT received at receiver
#     Packet seq=28408, packet_type=video, transport_seq=8578, delay_since_capture=37.248 ms
#     NOT received at receiver
#     Packet seq=28409, packet_type=video, transport_seq=8580, delay_since_capture=42.453 ms
#     NOT received at receiver
#     Packet seq=28410, packet_type=video, transport_seq=8582, delay_since_capture=50.226 ms
#     NOT received at receiver
#     Packet seq=28411, packet_type=video, transport_seq=8584, delay_since_capture=57.578 ms
#     NOT received at receiver
#     Packet seq=28412, packet_type=video, transport_seq=8585, delay_since_capture=57.621 ms
#     NOT received at receiver
#     Packet seq=28413, packet_type=video, transport_seq=8586, delay_since_capture=62.964 ms
#     NOT received at receiver
#     Packet seq=3575, packet_type=fec, transport_seq=8588, delay_since_capture=68.278 ms
#     NOT received at receiver
#     Packet seq=3576, packet_type=fec, transport_seq=8590, delay_since_capture=72.468 ms
#     NOT received at receiver
#     Packet seq=3577, packet_type=fec, transport_seq=8592, delay_since_capture=77.664 ms
#     NOT received at receiver
#     Packet seq=3578, packet_type=fec, transport_seq=8594, delay_since_capture=82.403 ms
#     NOT received at receiver
# num_media_packets=8, num_fec_packets=4
# encoding_delay = 15.753 ms, pacing delay = 47.211 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396900400
# rtp_ts=3847650176, frame_type=delta, frame_size=9295 bytes, packet_count=9
# all related packets sent:
#     Packet seq=28414, packet_type=video, transport_seq=8587, delay_since_capture=29.605 ms
#     NOT received at receiver
#     Packet seq=28415, packet_type=video, transport_seq=8589, delay_since_capture=34.858 ms
#     NOT received at receiver
#     Packet seq=28416, packet_type=video, transport_seq=8591, delay_since_capture=39.045 ms
#     NOT received at receiver
#     Packet seq=28417, packet_type=video, transport_seq=8593, delay_since_capture=44.248 ms
#     NOT received at receiver
#     Packet seq=28418, packet_type=video, transport_seq=8595, delay_since_capture=50.106 ms
#     NOT received at receiver
#     Packet seq=28419, packet_type=video, transport_seq=8596, delay_since_capture=55.432 ms
#     NOT received at receiver
#     Packet seq=28420, packet_type=video, transport_seq=8597, delay_since_capture=55.476 ms
#     NOT received at receiver
#     Packet seq=28421, packet_type=video, transport_seq=8598, delay_since_capture=60.62 ms
#     NOT received at receiver
#     Packet seq=28422, packet_type=video, transport_seq=8599, delay_since_capture=60.734 ms
#     NOT received at receiver
#     Packet seq=3579, packet_type=fec, transport_seq=8601, delay_since_capture=66.026 ms
#     NOT received at receiver
#     Packet seq=3580, packet_type=fec, transport_seq=8603, delay_since_capture=71.218 ms
#     NOT received at receiver
#     Packet seq=3581, packet_type=fec, transport_seq=8605, delay_since_capture=76.423 ms
#     NOT received at receiver
#     Packet seq=3582, packet_type=fec, transport_seq=8607, delay_since_capture=81.932 ms
#     NOT received at receiver
#     Packet seq=3583, packet_type=fec, transport_seq=8609, delay_since_capture=91.972 ms
#     NOT received at receiver
# num_media_packets=9, num_fec_packets=5
# encoding_delay = 16.596 ms, pacing delay = 44.138 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396903460
# rtp_ts=3847653236, frame_type=delta, frame_size=11627 bytes, packet_count=11
# all related packets sent:
#     Packet seq=28423, packet_type=video, transport_seq=8600, delay_since_capture=32.663 ms
#     NOT received at receiver
#     Packet seq=28424, packet_type=video, transport_seq=8602, delay_since_capture=37.859 ms
#     NOT received at receiver
#     Packet seq=28425, packet_type=video, transport_seq=8604, delay_since_capture=43.058 ms
#     NOT received at receiver
#     Packet seq=28426, packet_type=video, transport_seq=8606, delay_since_capture=46.416 ms
#     NOT received at receiver
#     Packet seq=28427, packet_type=video, transport_seq=8608, delay_since_capture=53.253 ms
#     NOT received at receiver
#     Packet seq=28428, packet_type=video, transport_seq=8610, delay_since_capture=58.676 ms
#     NOT received at receiver
#     Packet seq=28429, packet_type=video, transport_seq=8611, delay_since_capture=64.248 ms
#     NOT received at receiver
#     Packet seq=28430, packet_type=video, transport_seq=8612, delay_since_capture=64.275 ms
#     NOT received at receiver
#     Packet seq=28431, packet_type=video, transport_seq=8613, delay_since_capture=64.292 ms
#     NOT received at receiver
#     Packet seq=28432, packet_type=video, transport_seq=8614, delay_since_capture=69.705 ms
#     NOT received at receiver
#     Packet seq=28433, packet_type=video, transport_seq=8615, delay_since_capture=69.849 ms
#     NOT received at receiver
#     Packet seq=3584, packet_type=fec, transport_seq=8617, delay_since_capture=75.201 ms
#     NOT received at receiver
#     Packet seq=3585, packet_type=fec, transport_seq=8619, delay_since_capture=80.52 ms
#     NOT received at receiver
#     Packet seq=3586, packet_type=fec, transport_seq=8621, delay_since_capture=91.196 ms
#     NOT received at receiver
#     Packet seq=3587, packet_type=fec, transport_seq=8623, delay_since_capture=96.772 ms
#     NOT received at receiver
#     Packet seq=3588, packet_type=fec, transport_seq=8625, delay_since_capture=102.197 ms
#     NOT received at receiver
#     Packet seq=3589, packet_type=fec, transport_seq=8627, delay_since_capture=107.559 ms
#     NOT received at receiver
# num_media_packets=11, num_fec_packets=6
# encoding_delay = 15.471 ms, pacing delay = 54.378 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396906430
# rtp_ts=3847656206, frame_type=delta, frame_size=10781 bytes, packet_count=10
# all related packets sent:
#     Packet seq=28434, packet_type=video, transport_seq=8616, delay_since_capture=41.877 ms
#     NOT received at receiver
#     Packet seq=28435, packet_type=video, transport_seq=8618, delay_since_capture=45.865 ms
#     NOT received at receiver
#     Packet seq=28436, packet_type=video, transport_seq=8620, delay_since_capture=52.631 ms
#     NOT received at receiver
#     Packet seq=28437, packet_type=video, transport_seq=8622, delay_since_capture=57.968 ms
#     NOT received at receiver
#     Packet seq=28438, packet_type=video, transport_seq=8624, delay_since_capture=63.544 ms
#     NOT received at receiver
#     Packet seq=28439, packet_type=video, transport_seq=8626, delay_since_capture=68.974 ms
#     NOT received at receiver
#     Packet seq=28440, packet_type=video, transport_seq=8628, delay_since_capture=74.338 ms
#     NOT received at receiver
#     Packet seq=28441, packet_type=video, transport_seq=8629, delay_since_capture=78.749 ms
#     NOT received at receiver
#     Packet seq=28442, packet_type=video, transport_seq=8630, delay_since_capture=78.8 ms
#     NOT received at receiver
# num_media_packets=0, num_fec_packets=0
# encoding_delay = 12.962 ms, pacing delay = 65.838 ms
#     Not received at receiver!
# --------------------------------
# Frame rtp_ts_capture = 396909400
# rtp_ts=3847659176, frame_type=delta, frame_size=9450 bytes, packet_count=9
# all related packets sent:
#     Not start sending!
# --------------------------------
# Frame rtp_ts_capture = 396912460
# rtp_ts=3847662236, frame_type=delta, frame_size=7740 bytes, packet_count=7
# all related packets sent:
#     Not start sending!
